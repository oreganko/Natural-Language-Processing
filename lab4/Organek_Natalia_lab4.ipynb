# %% [markdown]
# # Natalia Organek - lab4

# %%
import os
import requests
import spacy
import regex as re
import nltk
from collections import Counter
import math

# %%
directory = '../lab1/ustawy'
filenames = os.listdir(directory)

# %% [markdown]
# # Task 1
# Use SpaCy tokenizer API to tokenize the text from the law corpus.

# %%
polish_spacy = spacy.load('pl_core_news_sm')
tokenizer = polish_spacy.tokenizer

# %%
corpus = ''
html_regex = r'<[\s\S]*?>'


for filename in filenames[:100]:
    with open(os.path.join(directory, filename), encoding="UTF-8") as f:
        bill = f.read()
        bill = bill.lower()
        bill = re.sub(html_regex, '', bill)
        bill = bill.replace('\xad', '').replace('\xa0', ' ')
        
        corpus += bill

# %%
tokens = [token.text for token in tokenizer(corpus)]

# %%
tokens
# Out:
# ['\n\n\n\n',
#  'dz.u',
#  '.',
#  'z',
#  '1998',
#  'r',
#  '.',
#  'nr',
#  '75',
#  ',',
#  'poz',
#  '.',
#  '486',
#  '\n                                                                          \n                                                                          \n                                                                          \n                                     \n                                  ',
#  'ustawa',
#  '\n                           ',
#  'z',
#  'dnia',
#  '7',
#  'maja',
#  '1998',
#  'r',
#  '.',
#  '\n                                     \n        ',
#  'o',
#  'zmianie',
#  'ustawy',
#  'o',
#  'zakładowym',
#  'funduszu',
#  'świadczeń',
#  'socjalnych',
#  '\n                                     \n                                  ',
#  'art',
#  '.',
#  '1',
#  '.',
#  '\n',
#  'w',
#  'ustawie',
#  'z',
#  'dnia',
#  '4',
#  'marca',
#  '1994',
#  'r',
#  '.',
#  'o',
#  'zakładowym',
#  'funduszu',
#  'świadczeń',
#  '\n',
#  'socjalnych',
#  '(',
#  'dz.u',
#  '.',
#  'z',
#  '1996',
#  'r',
#  '.',
#  'nr',
#  '70',
#  ',',
#  'poz',
#  '.',
#  '335',
#  ',',
#  'nr',
#  '118',
#  ',',
#  'poz',
#  '.',
#  '561',
#  ',',
#  'nr',
#  '139',
#  ',',
#  '\n',
#  'poz',
#  '.',
#  '647',
#  ',',
#  'nr',
#  '147',
#  ',',
#  'poz',
#  '.',
#  '686',
#  ',',
#  'z',
#  '1997',
#  'r',
#  '.',
#  'nr',
#  '82',
#  ',',
#  'poz',
#  '.',
#  '518',
#  ',',
#  'nr',
#  '121',
#  ',',
#  'poz',
#  '.',
#  '770',
#  ')',
#  '\n',
#  'wprowadza',
#  'się',
#  'następujące',
#  'zmiany',
#  ':',
#  '\n',
#  '1',
#  ')',
#  'w',
#  'art',
#  '.',
#  '1',
#  'w',
#  'ust',
#  '.',
#  '2',
#  'po',
#  'wyrazach',
#  '"',
#  'minister',
#  'spraw',
#  'wewnętrznych',
#  '"',
#  'dodaje',
#  'się',
#  '\n  ',
#  'wyrazy',
#  '"',
#  'i',
#  'administracji',
#  '"',
#  ';',
#  '\n',
#  '2',
#  ')',
#  'w',
#  'art',
#  '.',
#  '5',
#  'ust',
#  '.',
#  '4',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '\n         ',
#  '"',
#  '4',
#  '.',
#  'wysokość',
#  'odpisu',
#  'podstawowego',
#  'może',
#  'być',
#  'zwiększona',
#  'o',
#  '6,25',
#  '%',
#  '\n           ',
#  'przeciętnego',
#  'wynagrodzenia',
#  'miesięcznego',
#  ',',
#  'o',
#  'którym',
#  'mowa',
#  'w',
#  'ust',
#  '.',
#  '\n           ',
#  '2',
#  ',',
#  'na',
#  'każdą',
#  'zatrudnioną',
#  'osobę',
#  ',',
#  'w',
#  'stosunku',
#  'do',
#  'której',
#  'orzeczono',
#  '\n           ',
#  'znaczny',
#  'lub',
#  'umiarkowany',
#  'stopień',
#  'niepełnosprawności',
#  '.',
#  '"',
#  ';',
#  '\n',
#  '3',
#  ')',
#  'w',
#  'art',
#  '.',
#  '7',
#  ':',
#  '\n   ',
#  'a',
#  ')',
#  'ust',
#  '.',
#  '2',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '\n         ',
#  '"',
#  '2',
#  '.',
#  'zwiększenia',
#  ',',
#  'o',
#  'których',
#  'mowa',
#  'w',
#  'ust',
#  '.',
#  '1',
#  'pkt',
#  '7',
#  'i',
#  '8',
#  ',',
#  'nie',
#  'dotyczą',
#  '\n           ',
#  'pracodawców',
#  'postawionych',
#  'w',
#  'stan',
#  'upadłości',
#  'lub',
#  'likwidacji',
#  ',',
#  'z',
#  '\n           ',
#  'wyłączeniem',
#  'przedsiębiorstw',
#  'państwowych',
#  'likwidowanych',
#  'w',
#  'celu',
#  '\n           ',
#  'prywatyzacji',
#  '.',
#  '"',
#  ',',
#  '\n   ',
#  'b',
#  ')',
#  'ust',
#  '.',
#  '3',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '\n         ',
#  '"',
#  '3',
#  '.',
#  'w',
#  'razie',
#  'przejścia',
#  'zakładu',
#  'pracy',
#  'w',
#  'trybie',
#  'art',
#  '.',
#  '231',
#  'kodeksu',
#  '\n           ',
#  'pracy',
#  'na',
#  'pracodawcę',
#  'zobowiązanego',
#  'do',
#  'tworzenia',
#  'funduszu',
#  ',',
#  '\n           ',
#  'fundusz',
#  'pracodawcy',
#  'przejmującego',
#  'przejmuje',
#  'środki',
#  'pieniężne',
#  ',',
#  '\n           ',
#  'należności',
#  'i',
#  'zobowiązania',
#  'funduszu',
#  'pracodawcy',
#  'przekazującego',
#  '.',
#  '"',
#  ',',
#  '\n   ',
#  'c',
#  ')',
#  'dodaje',
#  'się',
#  'ust',
#  '.',
#  '3a',
#  '-',
#  '3d',
#  'w',
#  'brzmieniu',
#  ':',
#  '\n        ',
#  '"',
#  '3a',
#  '.',
#  'w',
#  'razie',
#  'przejścia',
#  'zakładu',
#  'pracy',
#  'w',
#  'trybie',
#  'art',
#  '.',
#  '231',
#  'kodeksu',
#  '\n           ',
#  'pracy',
#  'na',
#  'pracodawcę',
#  ',',
#  'który',
#  'nie',
#  'jest',
#  'zobowiązany',
#  'do',
#  'tworzenia',
#  '\n           ',
#  'funduszu',
#  ',',
#  'pracodawca',
#  'przejmujący',
#  'przejmuje',
#  'środki',
#  'pieniężne',
#  ',',
#  '\n           ',
#  'należności',
#  'i',
#  'zobowiązania',
#  'funduszu',
#  'pracodawcy',
#  'przekazującego',
#  '.',
#  '\n           ',
#  'nadwyżka',
#  'przejętych',
#  'środków',
#  'pieniężnych',
#  'wraz',
#  'z',
#  'odsetkami',
#  'oraz',
#  '\n           ',
#  'przejętych',
#  'należności',
#  'wraz',
#  'z',
#  'odsetkami',
#  'nad',
#  'przejętymi',
#  '\n           ',
#  'zobowiązaniami',
#  'wraz',
#  'z',
#  'odsetkami',
#  'nie',
#  'stanowi',
#  'przychodu',
#  '\n           ',
#  'pracodawcy',
#  'przejmującego',
#  ',',
#  'jest',
#  'gromadzona',
#  'na',
#  'odrębnym',
#  'rachunku',
#  '\n           ',
#  'bankowym',
#  'lub',
#  'wydzielonym',
#  'subkoncie',
#  'i',
#  'podlega',
#  'wydatkowaniu',
#  'na',
#  '\n           ',
#  'zasadach',
#  'określonych',
#  'ustawą',
#  'dla',
#  'dokonywania',
#  'wydatków',
#  'z',
#  '\n           ',
#  'funduszu',
#  '.',
#  'art',
#  '.',
#  '8',
#  'ust',
#  '.',
#  '2',
#  'stosuje',
#  'się',
#  'odpowiednio',
#  '.',
#  '\n         ',
#  '3b',
#  '.',
#  'w',
#  'razie',
#  'przejścia',
#  'części',
#  'zakładu',
#  'pracy',
#  'w',
#  'trybie',
#  'art',
#  '.',
#  '231',
#  '\n           ',
#  'kodeksu',
#  'pracy',
#  'na',
#  'pracodawcę',
#  'zobowiązanego',
#  'do',
#  'tworzenia',
#  '\n           ',
#  'funduszu',
#  ',',
#  'fundusz',
#  'pracodawcy',
#  'przejmującego',
#  'zwiększa',
#  'się',
#  ',',
#  'w',
#  '\n           ',
#  'części',
#  'przypadającej',
#  'na',
#  'liczbę',
#  'przejmowanych',
#  'pracowników',
#  ',',
#  'o',
#  '\n           ',
#  'równowartość',
#  'środków',
#  'pieniężnych',
#  'funduszu',
#  'pracodawcy',
#  '\n           ',
#  'przekazującego',
#  ',',
#  'skorygowanych',
#  'odpowiednio',
#  'o',
#  'należności',
#  'i',
#  '\n           ',
#  'zobowiązania',
#  'funduszu',
#  '-',
#  'według',
#  'stanu',
#  'na',
#  'ostatni',
#  'dzień',
#  'miesiąca',
#  ',',
#  '\n           ',
#  'w',
#  'którym',
#  'następuje',
#  'przejście',
#  '.',
#  '\n         ',
#  '3c',
#  '.',
#  'zasady',
#  'podziału',
#  'środków',
#  'pieniężnych',
#  'stanowiących',
#  'równowartość',
#  '\n           ',
#  'odpisu',
#  'podstawowego',
#  ',',
#  'obciążającego',
#  'koszty',
#  'pracodawcy',
#  '\n           ',
#  'przekazującego',
#  ',',
#  'dotyczącego',
#  'roku',
#  ',',
#  'w',
#  'którym',
#  'następuje',
#  'przejście',
#  '\n           ',
#  'części',
#  'zakładu',
#  'pracy',
#  ',',
#  'określa',
#  'porozumienie',
#  'między',
#  'pracodawcami',
#  '.',
#  '\n         ',
#  '3d',
#  '.',
#  'przekazanie',
#  'środków',
#  ',',
#  'o',
#  'których',
#  'mowa',
#  'w',
#  'ust',
#  '.',
#  '3b',
#  'i',
#  '3c',
#  ',',
#  'następuje',
#  '\n           ',
#  'w',
#  'terminie',
#  'trzydziestu',
#  'dni',
#  'od',
#  'daty',
#  'przejścia',
#  'części',
#  'zakładu',
#  '\n           ',
#  'pracy',
#  ',',
#  'chyba',
#  'że',
#  'porozumienie',
#  ',',
#  'o',
#  'którym',
#  'mowa',
#  'w',
#  'ust',
#  '.',
#  '3c',
#  'stanowi',
#  '\n           ',
#  'inaczej',
#  '.',
#  '"',
#  '.',
#  '\n     \n                                  ',
#  'art',
#  '.',
#  '2',
#  '.',
#  '\n',
#  'ustawa',
#  'wchodzi',
#  'w',
#  'życie',
#  'w',
#  'terminie',
#  '14',
#  'dni',
#  'od',
#  'dnia',
#  'ogłoszenia',
#  '.',
#  '\n\n\n\n\n',
#  'dz.u',
#  '.',
#  'z',
#  '2004',
#  'r',
#  '.',
#  'nr',
#  '238',
#  ',',
#  'poz',
#  '.',
#  '2387',
#  '\n                                        \n               \n                                        \n                                        \n                                        \n                                   ',
#  'u',
#  's',
#  't',
#  'a',
#  'w',
#  'a',
#  '\n                           ',
#  'z',
#  'dnia',
#  '27',
#  'sierpnia',
#  '2004',
#  'r',
#  '.',
#  '\n                                        \n    ',
#  'o',
#  'ratyfikacji',
#  'konwencji',
#  'o',
#  'pozbawianiu',
#  'uprawnień',
#  'do',
#  'kierowania',
#  'pojazdami',
#  ',',
#  '\n               ',
#  'sporządzonej',
#  'w',
#  'luksemburgu',
#  'dnia',
#  '17',
#  'czerwca',
#  '1998',
#  'r',
#  '.',
#  '\n                                        \n                                        \n                                     ',
#  'art',
#  '.',
#  '1',
#  '.',
#  '\n',
#  'wyraża',
#  'się',
#  'zgodę',
#  'na',
#  'dokonanie',
#  'przez',
#  'prezydenta',
#  'rzeczypospolitej',
#  'polskiej',
#  '\n',
#  'ratyfikacji',
#  'konwencji',
#  'o',
#  'pozbawianiu',
#  'uprawnień',
#  'do',
#  'kierowania',
#  'pojazdami',
#  ',',
#  '\n',
#  'sporządzonej',
#  'w',
#  'luksemburgu',
#  'dnia',
#  '17',
#  'czerwca',
#  '1998',
#  'r',
#  '.',
#  '\n                                        \n                                     ',
#  'art',
#  '.',
#  '2',
#  '.',
#  '\n',
#  'ustawa',
#  'wchodzi',
#  'w',
#  'życie',
#  'po',
#  'upływie',
#  '14',
#  'dni',
#  'od',
#  'dnia',
#  'ogłoszenia',
#  '.',
#  '\n\n\n\n\n',
#  'dz.u',
#  '.',
#  'z',
#  '1998',
#  'r',
#  '.',
#  'nr',
#  '160',
#  ',',
#  'poz',
#  '.',
#  '1058',
#  '\n                                                                              \n                                                                              \n                                       \n                                    ',
#  'ustawa',
#  '\n                           ',
#  'z',
#  'dnia',
#  '3',
#  'grudnia',
#  '1998',
#  'r',
#  '.',
#  '\n                                       \n               ',
#  'o',
#  'zmianie',
#  'ustawy',
#  'o',
#  'podatkach',
#  'i',
#  'opłatach',
#  'lokalnych',
#  '\n                                       \n                                       \n                                    ',
#  'art',
#  '.',
#  '1',
#  '.',
#  '\n',
#  'w',
#  'ustawie',
#  'z',
#  'dnia',
#  '12',
#  'stycznia',
#  '1991',
#  'r',
#  '.',
#  'o',
#  'podatkach',
#  'i',
#  'opłatach',
#  'lokalnych',
#  '(',
#  'dz.u',
#  '.',
#  '\n',
#  'nr',
#  '9',
#  ',',
#  'poz',
#  '.',
#  '31',
#  'i',
#  'nr',
#  '101',
#  ',',
#  'poz',
#  '.',
#  '444',
#  ',',
#  'z',
#  '1992',
#  'r',
#  '.',
#  'nr',
#  '21',
#  ',',
#  'poz',
#  '.',
#  '86',
#  ',',
#  'z',
#  '1994',
#  'r',
#  '.',
#  'nr',
#  '123',
#  ',',
#  '\n',
#  'poz',
#  '.',
#  '600',
#  ',',
#  'z',
#  '1996',
#  'r',
#  '.',
#  'nr',
#  '91',
#  ',',
#  'poz',
#  '.',
#  '409',
#  'i',
#  'nr',
#  '149',
#  ',',
#  'poz',
#  '.',
#  '704',
#  ',',
#  'z',
#  '1997',
#  'r',
#  '.',
#  'nr',
#  '5',
#  ',',
#  'poz',
#  '.',
#  '\n',
#  '24',
#  ',',
#  'nr',
#  '107',
#  ',',
#  'poz',
#  '.',
#  '689',
#  ',',
#  'nr',
#  '121',
#  ',',
#  'poz',
#  '.',
#  '770',
#  'i',
#  'nr',
#  '123',
#  ',',
#  'poz',
#  '.',
#  '780',
#  'oraz',
#  'z',
#  '1998',
#  'r',
#  '.',
#  'nr',
#  '\n',
#  '106',
#  'poz',
#  '.',
#  '668',
#  ')',
#  'wprowadza',
#  'się',
#  'następujące',
#  'zmiany',
#  ':',
#  '\n',
#  '1',
#  ')',
#  'w',
#  'art',
#  '.',
#  '8',
#  'pkt',
#  '4',
#  'otrzymuje',
#  'brzmienie',
#  ':',
#  '\n     ',
#  '"',
#  '4',
#  ')',
#  'przyczepy',
#  'i',
#  'naczepy',
#  'o',
#  'ładowności',
#  'powyżej',
#  '5',
#  'ton',
#  ',',
#  'z',
#  'wyjątkiem',
#  '\n       ',
#  'wykorzystywanych',
#  'na',
#  'cele',
#  'rolnicze',
#  'przez',
#  'podatnika',
#  'podatku',
#  'rolnego',
#  ',',
#  '"',
#  ';',
#  '\n',
#  '2',
#  ')',
#  'w',
#  'art',
#  '.',
#  '10',
#  'dotychczasową',
#  'treść',
#  'oznacza',
#  'się',
#  'jako',
#  'ust',
#  '.',
#  '1',
#  'i',
#  'dodaje',
#  'się',
#  'ust',
#  '.',
#  '2',
#  '\n  ',
#  'w',
#  'brzmieniu',
#  ':',
#  '\n     ',
#  '"',
#  '2',
#  '.',
#  'przy',
#  'określaniu',
#  'stawek',
#  ',',
#  'o',
#  'których',
#  'mowa',
#  'w',
#  'ust',
#  '.',
#  '1',
#  ',',
#  'rada',
#  'gminy',
#  'może',
#  '\n       ',
#  'uwzględniać',
#  'rodzaj',
#  'środka',
#  'transportowego',
#  ',',
#  'ładowność',
#  ',',
#  'masę',
#  'całkowitą',
#  ',',
#  '\n       ',
#  'wiek',
#  ',',
#  'nacisk',
#  'na',
#  'siodło',
#  'ciągnika',
#  'albo',
#  'liczbę',
#  'miejsc',
#  'do',
#  'siedzenia',
#  '.',
#  '"',
#  '.',
#  '\n                                       \n                                       \n                                    ',
#  'art',
#  '.',
#  '2',
#  '.',
#  '\n ',
#  'ustawa',
#  'wchodzi',
#  'w',
#  'życie',
#  'z',
#  'dniem',
#  '1',
#  'stycznia',
#  '1999',
#  'r',
#  '.',
#  '\n\n\n\n\n',
#  'dz.u',
#  '.',
#  'z',
#  '1998',
#  'r',
#  '.',
#  'nr',
#  '137',
#  ',',
#  ...]

# %% [markdown]
# # Task 2
# Compute bigram counts of downcased tokens.

# %%
bigrams = [b for b in nltk.bigrams(tokens)]

# %%
bigrams
# Out:
# [('\n\n\n\n', 'dz.u'),
#  ('dz.u', '.'),
#  ('.', 'z'),
#  ('z', '1998'),
#  ('1998', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '75'),
#  ('75', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '486'),
#  ('486',
#   '\n                                                                          \n                                                                          \n                                                                          \n                                     \n                                  '),
#  ('\n                                                                          \n                                                                          \n                                                                          \n                                     \n                                  ',
#   'ustawa'),
#  ('ustawa', '\n                           '),
#  ('\n                           ', 'z'),
#  ('z', 'dnia'),
#  ('dnia', '7'),
#  ('7', 'maja'),
#  ('maja', '1998'),
#  ('1998', 'r'),
#  ('r', '.'),
#  ('.', '\n                                     \n        '),
#  ('\n                                     \n        ', 'o'),
#  ('o', 'zmianie'),
#  ('zmianie', 'ustawy'),
#  ('ustawy', 'o'),
#  ('o', 'zakładowym'),
#  ('zakładowym', 'funduszu'),
#  ('funduszu', 'świadczeń'),
#  ('świadczeń', 'socjalnych'),
#  ('socjalnych',
#   '\n                                     \n                                  '),
#  ('\n                                     \n                                  ',
#   'art'),
#  ('art', '.'),
#  ('.', '1'),
#  ('1', '.'),
#  ('.', '\n'),
#  ('\n', 'w'),
#  ('w', 'ustawie'),
#  ('ustawie', 'z'),
#  ('z', 'dnia'),
#  ('dnia', '4'),
#  ('4', 'marca'),
#  ('marca', '1994'),
#  ('1994', 'r'),
#  ('r', '.'),
#  ('.', 'o'),
#  ('o', 'zakładowym'),
#  ('zakładowym', 'funduszu'),
#  ('funduszu', 'świadczeń'),
#  ('świadczeń', '\n'),
#  ('\n', 'socjalnych'),
#  ('socjalnych', '('),
#  ('(', 'dz.u'),
#  ('dz.u', '.'),
#  ('.', 'z'),
#  ('z', '1996'),
#  ('1996', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '70'),
#  ('70', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '335'),
#  ('335', ','),
#  (',', 'nr'),
#  ('nr', '118'),
#  ('118', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '561'),
#  ('561', ','),
#  (',', 'nr'),
#  ('nr', '139'),
#  ('139', ','),
#  (',', '\n'),
#  ('\n', 'poz'),
#  ('poz', '.'),
#  ('.', '647'),
#  ('647', ','),
#  (',', 'nr'),
#  ('nr', '147'),
#  ('147', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '686'),
#  ('686', ','),
#  (',', 'z'),
#  ('z', '1997'),
#  ('1997', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '82'),
#  ('82', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '518'),
#  ('518', ','),
#  (',', 'nr'),
#  ('nr', '121'),
#  ('121', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '770'),
#  ('770', ')'),
#  (')', '\n'),
#  ('\n', 'wprowadza'),
#  ('wprowadza', 'się'),
#  ('się', 'następujące'),
#  ('następujące', 'zmiany'),
#  ('zmiany', ':'),
#  (':', '\n'),
#  ('\n', '1'),
#  ('1', ')'),
#  (')', 'w'),
#  ('w', 'art'),
#  ('art', '.'),
#  ('.', '1'),
#  ('1', 'w'),
#  ('w', 'ust'),
#  ('ust', '.'),
#  ('.', '2'),
#  ('2', 'po'),
#  ('po', 'wyrazach'),
#  ('wyrazach', '"'),
#  ('"', 'minister'),
#  ('minister', 'spraw'),
#  ('spraw', 'wewnętrznych'),
#  ('wewnętrznych', '"'),
#  ('"', 'dodaje'),
#  ('dodaje', 'się'),
#  ('się', '\n  '),
#  ('\n  ', 'wyrazy'),
#  ('wyrazy', '"'),
#  ('"', 'i'),
#  ('i', 'administracji'),
#  ('administracji', '"'),
#  ('"', ';'),
#  (';', '\n'),
#  ('\n', '2'),
#  ('2', ')'),
#  (')', 'w'),
#  ('w', 'art'),
#  ('art', '.'),
#  ('.', '5'),
#  ('5', 'ust'),
#  ('ust', '.'),
#  ('.', '4'),
#  ('4', 'otrzymuje'),
#  ('otrzymuje', 'brzmienie'),
#  ('brzmienie', ':'),
#  (':', '\n         '),
#  ('\n         ', '"'),
#  ('"', '4'),
#  ('4', '.'),
#  ('.', 'wysokość'),
#  ('wysokość', 'odpisu'),
#  ('odpisu', 'podstawowego'),
#  ('podstawowego', 'może'),
#  ('może', 'być'),
#  ('być', 'zwiększona'),
#  ('zwiększona', 'o'),
#  ('o', '6,25'),
#  ('6,25', '%'),
#  ('%', '\n           '),
#  ('\n           ', 'przeciętnego'),
#  ('przeciętnego', 'wynagrodzenia'),
#  ('wynagrodzenia', 'miesięcznego'),
#  ('miesięcznego', ','),
#  (',', 'o'),
#  ('o', 'którym'),
#  ('którym', 'mowa'),
#  ('mowa', 'w'),
#  ('w', 'ust'),
#  ('ust', '.'),
#  ('.', '\n           '),
#  ('\n           ', '2'),
#  ('2', ','),
#  (',', 'na'),
#  ('na', 'każdą'),
#  ('każdą', 'zatrudnioną'),
#  ('zatrudnioną', 'osobę'),
#  ('osobę', ','),
#  (',', 'w'),
#  ('w', 'stosunku'),
#  ('stosunku', 'do'),
#  ('do', 'której'),
#  ('której', 'orzeczono'),
#  ('orzeczono', '\n           '),
#  ('\n           ', 'znaczny'),
#  ('znaczny', 'lub'),
#  ('lub', 'umiarkowany'),
#  ('umiarkowany', 'stopień'),
#  ('stopień', 'niepełnosprawności'),
#  ('niepełnosprawności', '.'),
#  ('.', '"'),
#  ('"', ';'),
#  (';', '\n'),
#  ('\n', '3'),
#  ('3', ')'),
#  (')', 'w'),
#  ('w', 'art'),
#  ('art', '.'),
#  ('.', '7'),
#  ('7', ':'),
#  (':', '\n   '),
#  ('\n   ', 'a'),
#  ('a', ')'),
#  (')', 'ust'),
#  ('ust', '.'),
#  ('.', '2'),
#  ('2', 'otrzymuje'),
#  ('otrzymuje', 'brzmienie'),
#  ('brzmienie', ':'),
#  (':', '\n         '),
#  ('\n         ', '"'),
#  ('"', '2'),
#  ('2', '.'),
#  ('.', 'zwiększenia'),
#  ('zwiększenia', ','),
#  (',', 'o'),
#  ('o', 'których'),
#  ('których', 'mowa'),
#  ('mowa', 'w'),
#  ('w', 'ust'),
#  ('ust', '.'),
#  ('.', '1'),
#  ('1', 'pkt'),
#  ('pkt', '7'),
#  ('7', 'i'),
#  ('i', '8'),
#  ('8', ','),
#  (',', 'nie'),
#  ('nie', 'dotyczą'),
#  ('dotyczą', '\n           '),
#  ('\n           ', 'pracodawców'),
#  ('pracodawców', 'postawionych'),
#  ('postawionych', 'w'),
#  ('w', 'stan'),
#  ('stan', 'upadłości'),
#  ('upadłości', 'lub'),
#  ('lub', 'likwidacji'),
#  ('likwidacji', ','),
#  (',', 'z'),
#  ('z', '\n           '),
#  ('\n           ', 'wyłączeniem'),
#  ('wyłączeniem', 'przedsiębiorstw'),
#  ('przedsiębiorstw', 'państwowych'),
#  ('państwowych', 'likwidowanych'),
#  ('likwidowanych', 'w'),
#  ('w', 'celu'),
#  ('celu', '\n           '),
#  ('\n           ', 'prywatyzacji'),
#  ('prywatyzacji', '.'),
#  ('.', '"'),
#  ('"', ','),
#  (',', '\n   '),
#  ('\n   ', 'b'),
#  ('b', ')'),
#  (')', 'ust'),
#  ('ust', '.'),
#  ('.', '3'),
#  ('3', 'otrzymuje'),
#  ('otrzymuje', 'brzmienie'),
#  ('brzmienie', ':'),
#  (':', '\n         '),
#  ('\n         ', '"'),
#  ('"', '3'),
#  ('3', '.'),
#  ('.', 'w'),
#  ('w', 'razie'),
#  ('razie', 'przejścia'),
#  ('przejścia', 'zakładu'),
#  ('zakładu', 'pracy'),
#  ('pracy', 'w'),
#  ('w', 'trybie'),
#  ('trybie', 'art'),
#  ('art', '.'),
#  ('.', '231'),
#  ('231', 'kodeksu'),
#  ('kodeksu', '\n           '),
#  ('\n           ', 'pracy'),
#  ('pracy', 'na'),
#  ('na', 'pracodawcę'),
#  ('pracodawcę', 'zobowiązanego'),
#  ('zobowiązanego', 'do'),
#  ('do', 'tworzenia'),
#  ('tworzenia', 'funduszu'),
#  ('funduszu', ','),
#  (',', '\n           '),
#  ('\n           ', 'fundusz'),
#  ('fundusz', 'pracodawcy'),
#  ('pracodawcy', 'przejmującego'),
#  ('przejmującego', 'przejmuje'),
#  ('przejmuje', 'środki'),
#  ('środki', 'pieniężne'),
#  ('pieniężne', ','),
#  (',', '\n           '),
#  ('\n           ', 'należności'),
#  ('należności', 'i'),
#  ('i', 'zobowiązania'),
#  ('zobowiązania', 'funduszu'),
#  ('funduszu', 'pracodawcy'),
#  ('pracodawcy', 'przekazującego'),
#  ('przekazującego', '.'),
#  ('.', '"'),
#  ('"', ','),
#  (',', '\n   '),
#  ('\n   ', 'c'),
#  ('c', ')'),
#  (')', 'dodaje'),
#  ('dodaje', 'się'),
#  ('się', 'ust'),
#  ('ust', '.'),
#  ('.', '3a'),
#  ('3a', '-'),
#  ('-', '3d'),
#  ('3d', 'w'),
#  ('w', 'brzmieniu'),
#  ('brzmieniu', ':'),
#  (':', '\n        '),
#  ('\n        ', '"'),
#  ('"', '3a'),
#  ('3a', '.'),
#  ('.', 'w'),
#  ('w', 'razie'),
#  ('razie', 'przejścia'),
#  ('przejścia', 'zakładu'),
#  ('zakładu', 'pracy'),
#  ('pracy', 'w'),
#  ('w', 'trybie'),
#  ('trybie', 'art'),
#  ('art', '.'),
#  ('.', '231'),
#  ('231', 'kodeksu'),
#  ('kodeksu', '\n           '),
#  ('\n           ', 'pracy'),
#  ('pracy', 'na'),
#  ('na', 'pracodawcę'),
#  ('pracodawcę', ','),
#  (',', 'który'),
#  ('który', 'nie'),
#  ('nie', 'jest'),
#  ('jest', 'zobowiązany'),
#  ('zobowiązany', 'do'),
#  ('do', 'tworzenia'),
#  ('tworzenia', '\n           '),
#  ('\n           ', 'funduszu'),
#  ('funduszu', ','),
#  (',', 'pracodawca'),
#  ('pracodawca', 'przejmujący'),
#  ('przejmujący', 'przejmuje'),
#  ('przejmuje', 'środki'),
#  ('środki', 'pieniężne'),
#  ('pieniężne', ','),
#  (',', '\n           '),
#  ('\n           ', 'należności'),
#  ('należności', 'i'),
#  ('i', 'zobowiązania'),
#  ('zobowiązania', 'funduszu'),
#  ('funduszu', 'pracodawcy'),
#  ('pracodawcy', 'przekazującego'),
#  ('przekazującego', '.'),
#  ('.', '\n           '),
#  ('\n           ', 'nadwyżka'),
#  ('nadwyżka', 'przejętych'),
#  ('przejętych', 'środków'),
#  ('środków', 'pieniężnych'),
#  ('pieniężnych', 'wraz'),
#  ('wraz', 'z'),
#  ('z', 'odsetkami'),
#  ('odsetkami', 'oraz'),
#  ('oraz', '\n           '),
#  ('\n           ', 'przejętych'),
#  ('przejętych', 'należności'),
#  ('należności', 'wraz'),
#  ('wraz', 'z'),
#  ('z', 'odsetkami'),
#  ('odsetkami', 'nad'),
#  ('nad', 'przejętymi'),
#  ('przejętymi', '\n           '),
#  ('\n           ', 'zobowiązaniami'),
#  ('zobowiązaniami', 'wraz'),
#  ('wraz', 'z'),
#  ('z', 'odsetkami'),
#  ('odsetkami', 'nie'),
#  ('nie', 'stanowi'),
#  ('stanowi', 'przychodu'),
#  ('przychodu', '\n           '),
#  ('\n           ', 'pracodawcy'),
#  ('pracodawcy', 'przejmującego'),
#  ('przejmującego', ','),
#  (',', 'jest'),
#  ('jest', 'gromadzona'),
#  ('gromadzona', 'na'),
#  ('na', 'odrębnym'),
#  ('odrębnym', 'rachunku'),
#  ('rachunku', '\n           '),
#  ('\n           ', 'bankowym'),
#  ('bankowym', 'lub'),
#  ('lub', 'wydzielonym'),
#  ('wydzielonym', 'subkoncie'),
#  ('subkoncie', 'i'),
#  ('i', 'podlega'),
#  ('podlega', 'wydatkowaniu'),
#  ('wydatkowaniu', 'na'),
#  ('na', '\n           '),
#  ('\n           ', 'zasadach'),
#  ('zasadach', 'określonych'),
#  ('określonych', 'ustawą'),
#  ('ustawą', 'dla'),
#  ('dla', 'dokonywania'),
#  ('dokonywania', 'wydatków'),
#  ('wydatków', 'z'),
#  ('z', '\n           '),
#  ('\n           ', 'funduszu'),
#  ('funduszu', '.'),
#  ('.', 'art'),
#  ('art', '.'),
#  ('.', '8'),
#  ('8', 'ust'),
#  ('ust', '.'),
#  ('.', '2'),
#  ('2', 'stosuje'),
#  ('stosuje', 'się'),
#  ('się', 'odpowiednio'),
#  ('odpowiednio', '.'),
#  ('.', '\n         '),
#  ('\n         ', '3b'),
#  ('3b', '.'),
#  ('.', 'w'),
#  ('w', 'razie'),
#  ('razie', 'przejścia'),
#  ('przejścia', 'części'),
#  ('części', 'zakładu'),
#  ('zakładu', 'pracy'),
#  ('pracy', 'w'),
#  ('w', 'trybie'),
#  ('trybie', 'art'),
#  ('art', '.'),
#  ('.', '231'),
#  ('231', '\n           '),
#  ('\n           ', 'kodeksu'),
#  ('kodeksu', 'pracy'),
#  ('pracy', 'na'),
#  ('na', 'pracodawcę'),
#  ('pracodawcę', 'zobowiązanego'),
#  ('zobowiązanego', 'do'),
#  ('do', 'tworzenia'),
#  ('tworzenia', '\n           '),
#  ('\n           ', 'funduszu'),
#  ('funduszu', ','),
#  (',', 'fundusz'),
#  ('fundusz', 'pracodawcy'),
#  ('pracodawcy', 'przejmującego'),
#  ('przejmującego', 'zwiększa'),
#  ('zwiększa', 'się'),
#  ('się', ','),
#  (',', 'w'),
#  ('w', '\n           '),
#  ('\n           ', 'części'),
#  ('części', 'przypadającej'),
#  ('przypadającej', 'na'),
#  ('na', 'liczbę'),
#  ('liczbę', 'przejmowanych'),
#  ('przejmowanych', 'pracowników'),
#  ('pracowników', ','),
#  (',', 'o'),
#  ('o', '\n           '),
#  ('\n           ', 'równowartość'),
#  ('równowartość', 'środków'),
#  ('środków', 'pieniężnych'),
#  ('pieniężnych', 'funduszu'),
#  ('funduszu', 'pracodawcy'),
#  ('pracodawcy', '\n           '),
#  ('\n           ', 'przekazującego'),
#  ('przekazującego', ','),
#  (',', 'skorygowanych'),
#  ('skorygowanych', 'odpowiednio'),
#  ('odpowiednio', 'o'),
#  ('o', 'należności'),
#  ('należności', 'i'),
#  ('i', '\n           '),
#  ('\n           ', 'zobowiązania'),
#  ('zobowiązania', 'funduszu'),
#  ('funduszu', '-'),
#  ('-', 'według'),
#  ('według', 'stanu'),
#  ('stanu', 'na'),
#  ('na', 'ostatni'),
#  ('ostatni', 'dzień'),
#  ('dzień', 'miesiąca'),
#  ('miesiąca', ','),
#  (',', '\n           '),
#  ('\n           ', 'w'),
#  ('w', 'którym'),
#  ('którym', 'następuje'),
#  ('następuje', 'przejście'),
#  ('przejście', '.'),
#  ('.', '\n         '),
#  ('\n         ', '3c'),
#  ('3c', '.'),
#  ('.', 'zasady'),
#  ('zasady', 'podziału'),
#  ('podziału', 'środków'),
#  ('środków', 'pieniężnych'),
#  ('pieniężnych', 'stanowiących'),
#  ('stanowiących', 'równowartość'),
#  ('równowartość', '\n           '),
#  ('\n           ', 'odpisu'),
#  ('odpisu', 'podstawowego'),
#  ('podstawowego', ','),
#  (',', 'obciążającego'),
#  ('obciążającego', 'koszty'),
#  ('koszty', 'pracodawcy'),
#  ('pracodawcy', '\n           '),
#  ('\n           ', 'przekazującego'),
#  ('przekazującego', ','),
#  (',', 'dotyczącego'),
#  ('dotyczącego', 'roku'),
#  ('roku', ','),
#  (',', 'w'),
#  ('w', 'którym'),
#  ('którym', 'następuje'),
#  ('następuje', 'przejście'),
#  ('przejście', '\n           '),
#  ('\n           ', 'części'),
#  ('części', 'zakładu'),
#  ('zakładu', 'pracy'),
#  ('pracy', ','),
#  (',', 'określa'),
#  ('określa', 'porozumienie'),
#  ('porozumienie', 'między'),
#  ('między', 'pracodawcami'),
#  ('pracodawcami', '.'),
#  ('.', '\n         '),
#  ('\n         ', '3d'),
#  ('3d', '.'),
#  ('.', 'przekazanie'),
#  ('przekazanie', 'środków'),
#  ('środków', ','),
#  (',', 'o'),
#  ('o', 'których'),
#  ('których', 'mowa'),
#  ('mowa', 'w'),
#  ('w', 'ust'),
#  ('ust', '.'),
#  ('.', '3b'),
#  ('3b', 'i'),
#  ('i', '3c'),
#  ('3c', ','),
#  (',', 'następuje'),
#  ('następuje', '\n           '),
#  ('\n           ', 'w'),
#  ('w', 'terminie'),
#  ('terminie', 'trzydziestu'),
#  ('trzydziestu', 'dni'),
#  ('dni', 'od'),
#  ('od', 'daty'),
#  ('daty', 'przejścia'),
#  ('przejścia', 'części'),
#  ('części', 'zakładu'),
#  ('zakładu', '\n           '),
#  ('\n           ', 'pracy'),
#  ('pracy', ','),
#  (',', 'chyba'),
#  ('chyba', 'że'),
#  ('że', 'porozumienie'),
#  ('porozumienie', ','),
#  (',', 'o'),
#  ('o', 'którym'),
#  ('którym', 'mowa'),
#  ('mowa', 'w'),
#  ('w', 'ust'),
#  ('ust', '.'),
#  ('.', '3c'),
#  ('3c', 'stanowi'),
#  ('stanowi', '\n           '),
#  ('\n           ', 'inaczej'),
#  ('inaczej', '.'),
#  ('.', '"'),
#  ('"', '.'),
#  ('.', '\n     \n                                  '),
#  ('\n     \n                                  ', 'art'),
#  ('art', '.'),
#  ('.', '2'),
#  ('2', '.'),
#  ('.', '\n'),
#  ('\n', 'ustawa'),
#  ('ustawa', 'wchodzi'),
#  ('wchodzi', 'w'),
#  ('w', 'życie'),
#  ('życie', 'w'),
#  ('w', 'terminie'),
#  ('terminie', '14'),
#  ('14', 'dni'),
#  ('dni', 'od'),
#  ('od', 'dnia'),
#  ('dnia', 'ogłoszenia'),
#  ('ogłoszenia', '.'),
#  ('.', '\n\n\n\n\n'),
#  ('\n\n\n\n\n', 'dz.u'),
#  ('dz.u', '.'),
#  ('.', 'z'),
#  ('z', '2004'),
#  ('2004', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '238'),
#  ('238', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '2387'),
#  ('2387',
#   '\n                                        \n               \n                                        \n                                        \n                                        \n                                   '),
#  ('\n                                        \n               \n                                        \n                                        \n                                        \n                                   ',
#   'u'),
#  ('u', 's'),
#  ('s', 't'),
#  ('t', 'a'),
#  ('a', 'w'),
#  ('w', 'a'),
#  ('a', '\n                           '),
#  ('\n                           ', 'z'),
#  ('z', 'dnia'),
#  ('dnia', '27'),
#  ('27', 'sierpnia'),
#  ('sierpnia', '2004'),
#  ('2004', 'r'),
#  ('r', '.'),
#  ('.', '\n                                        \n    '),
#  ('\n                                        \n    ', 'o'),
#  ('o', 'ratyfikacji'),
#  ('ratyfikacji', 'konwencji'),
#  ('konwencji', 'o'),
#  ('o', 'pozbawianiu'),
#  ('pozbawianiu', 'uprawnień'),
#  ('uprawnień', 'do'),
#  ('do', 'kierowania'),
#  ('kierowania', 'pojazdami'),
#  ('pojazdami', ','),
#  (',', '\n               '),
#  ('\n               ', 'sporządzonej'),
#  ('sporządzonej', 'w'),
#  ('w', 'luksemburgu'),
#  ('luksemburgu', 'dnia'),
#  ('dnia', '17'),
#  ('17', 'czerwca'),
#  ('czerwca', '1998'),
#  ('1998', 'r'),
#  ('r', '.'),
#  ('.',
#   '\n                                        \n                                        \n                                     '),
#  ('\n                                        \n                                        \n                                     ',
#   'art'),
#  ('art', '.'),
#  ('.', '1'),
#  ('1', '.'),
#  ('.', '\n'),
#  ('\n', 'wyraża'),
#  ('wyraża', 'się'),
#  ('się', 'zgodę'),
#  ('zgodę', 'na'),
#  ('na', 'dokonanie'),
#  ('dokonanie', 'przez'),
#  ('przez', 'prezydenta'),
#  ('prezydenta', 'rzeczypospolitej'),
#  ('rzeczypospolitej', 'polskiej'),
#  ('polskiej', '\n'),
#  ('\n', 'ratyfikacji'),
#  ('ratyfikacji', 'konwencji'),
#  ('konwencji', 'o'),
#  ('o', 'pozbawianiu'),
#  ('pozbawianiu', 'uprawnień'),
#  ('uprawnień', 'do'),
#  ('do', 'kierowania'),
#  ('kierowania', 'pojazdami'),
#  ('pojazdami', ','),
#  (',', '\n'),
#  ('\n', 'sporządzonej'),
#  ('sporządzonej', 'w'),
#  ('w', 'luksemburgu'),
#  ('luksemburgu', 'dnia'),
#  ('dnia', '17'),
#  ('17', 'czerwca'),
#  ('czerwca', '1998'),
#  ('1998', 'r'),
#  ('r', '.'),
#  ('.',
#   '\n                                        \n                                     '),
#  ('\n                                        \n                                     ',
#   'art'),
#  ('art', '.'),
#  ('.', '2'),
#  ('2', '.'),
#  ('.', '\n'),
#  ('\n', 'ustawa'),
#  ('ustawa', 'wchodzi'),
#  ('wchodzi', 'w'),
#  ('w', 'życie'),
#  ('życie', 'po'),
#  ('po', 'upływie'),
#  ('upływie', '14'),
#  ('14', 'dni'),
#  ('dni', 'od'),
#  ('od', 'dnia'),
#  ('dnia', 'ogłoszenia'),
#  ('ogłoszenia', '.'),
#  ('.', '\n\n\n\n\n'),
#  ('\n\n\n\n\n', 'dz.u'),
#  ('dz.u', '.'),
#  ('.', 'z'),
#  ('z', '1998'),
#  ('1998', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '160'),
#  ('160', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '1058'),
#  ('1058',
#   '\n                                                                              \n                                                                              \n                                       \n                                    '),
#  ('\n                                                                              \n                                                                              \n                                       \n                                    ',
#   'ustawa'),
#  ('ustawa', '\n                           '),
#  ('\n                           ', 'z'),
#  ('z', 'dnia'),
#  ('dnia', '3'),
#  ('3', 'grudnia'),
#  ('grudnia', '1998'),
#  ('1998', 'r'),
#  ('r', '.'),
#  ('.', '\n                                       \n               '),
#  ('\n                                       \n               ', 'o'),
#  ('o', 'zmianie'),
#  ('zmianie', 'ustawy'),
#  ('ustawy', 'o'),
#  ('o', 'podatkach'),
#  ('podatkach', 'i'),
#  ('i', 'opłatach'),
#  ('opłatach', 'lokalnych'),
#  ('lokalnych',
#   '\n                                       \n                                       \n                                    '),
#  ('\n                                       \n                                       \n                                    ',
#   'art'),
#  ('art', '.'),
#  ('.', '1'),
#  ('1', '.'),
#  ('.', '\n'),
#  ('\n', 'w'),
#  ('w', 'ustawie'),
#  ('ustawie', 'z'),
#  ('z', 'dnia'),
#  ('dnia', '12'),
#  ('12', 'stycznia'),
#  ('stycznia', '1991'),
#  ('1991', 'r'),
#  ('r', '.'),
#  ('.', 'o'),
#  ('o', 'podatkach'),
#  ('podatkach', 'i'),
#  ('i', 'opłatach'),
#  ('opłatach', 'lokalnych'),
#  ('lokalnych', '('),
#  ('(', 'dz.u'),
#  ('dz.u', '.'),
#  ('.', '\n'),
#  ('\n', 'nr'),
#  ('nr', '9'),
#  ('9', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '31'),
#  ('31', 'i'),
#  ('i', 'nr'),
#  ('nr', '101'),
#  ('101', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '444'),
#  ('444', ','),
#  (',', 'z'),
#  ('z', '1992'),
#  ('1992', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '21'),
#  ('21', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '86'),
#  ('86', ','),
#  (',', 'z'),
#  ('z', '1994'),
#  ('1994', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '123'),
#  ('123', ','),
#  (',', '\n'),
#  ('\n', 'poz'),
#  ('poz', '.'),
#  ('.', '600'),
#  ('600', ','),
#  (',', 'z'),
#  ('z', '1996'),
#  ('1996', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '91'),
#  ('91', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '409'),
#  ('409', 'i'),
#  ('i', 'nr'),
#  ('nr', '149'),
#  ('149', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '704'),
#  ('704', ','),
#  (',', 'z'),
#  ('z', '1997'),
#  ('1997', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '5'),
#  ('5', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '\n'),
#  ('\n', '24'),
#  ('24', ','),
#  (',', 'nr'),
#  ('nr', '107'),
#  ('107', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '689'),
#  ('689', ','),
#  (',', 'nr'),
#  ('nr', '121'),
#  ('121', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '770'),
#  ('770', 'i'),
#  ('i', 'nr'),
#  ('nr', '123'),
#  ('123', ','),
#  (',', 'poz'),
#  ('poz', '.'),
#  ('.', '780'),
#  ('780', 'oraz'),
#  ('oraz', 'z'),
#  ('z', '1998'),
#  ('1998', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '\n'),
#  ('\n', '106'),
#  ('106', 'poz'),
#  ('poz', '.'),
#  ('.', '668'),
#  ('668', ')'),
#  (')', 'wprowadza'),
#  ('wprowadza', 'się'),
#  ('się', 'następujące'),
#  ('następujące', 'zmiany'),
#  ('zmiany', ':'),
#  (':', '\n'),
#  ('\n', '1'),
#  ('1', ')'),
#  (')', 'w'),
#  ('w', 'art'),
#  ('art', '.'),
#  ('.', '8'),
#  ('8', 'pkt'),
#  ('pkt', '4'),
#  ('4', 'otrzymuje'),
#  ('otrzymuje', 'brzmienie'),
#  ('brzmienie', ':'),
#  (':', '\n     '),
#  ('\n     ', '"'),
#  ('"', '4'),
#  ('4', ')'),
#  (')', 'przyczepy'),
#  ('przyczepy', 'i'),
#  ('i', 'naczepy'),
#  ('naczepy', 'o'),
#  ('o', 'ładowności'),
#  ('ładowności', 'powyżej'),
#  ('powyżej', '5'),
#  ('5', 'ton'),
#  ('ton', ','),
#  (',', 'z'),
#  ('z', 'wyjątkiem'),
#  ('wyjątkiem', '\n       '),
#  ('\n       ', 'wykorzystywanych'),
#  ('wykorzystywanych', 'na'),
#  ('na', 'cele'),
#  ('cele', 'rolnicze'),
#  ('rolnicze', 'przez'),
#  ('przez', 'podatnika'),
#  ('podatnika', 'podatku'),
#  ('podatku', 'rolnego'),
#  ('rolnego', ','),
#  (',', '"'),
#  ('"', ';'),
#  (';', '\n'),
#  ('\n', '2'),
#  ('2', ')'),
#  (')', 'w'),
#  ('w', 'art'),
#  ('art', '.'),
#  ('.', '10'),
#  ('10', 'dotychczasową'),
#  ('dotychczasową', 'treść'),
#  ('treść', 'oznacza'),
#  ('oznacza', 'się'),
#  ('się', 'jako'),
#  ('jako', 'ust'),
#  ('ust', '.'),
#  ('.', '1'),
#  ('1', 'i'),
#  ('i', 'dodaje'),
#  ('dodaje', 'się'),
#  ('się', 'ust'),
#  ('ust', '.'),
#  ('.', '2'),
#  ('2', '\n  '),
#  ('\n  ', 'w'),
#  ('w', 'brzmieniu'),
#  ('brzmieniu', ':'),
#  (':', '\n     '),
#  ('\n     ', '"'),
#  ('"', '2'),
#  ('2', '.'),
#  ('.', 'przy'),
#  ('przy', 'określaniu'),
#  ('określaniu', 'stawek'),
#  ('stawek', ','),
#  (',', 'o'),
#  ('o', 'których'),
#  ('których', 'mowa'),
#  ('mowa', 'w'),
#  ('w', 'ust'),
#  ('ust', '.'),
#  ('.', '1'),
#  ('1', ','),
#  (',', 'rada'),
#  ('rada', 'gminy'),
#  ('gminy', 'może'),
#  ('może', '\n       '),
#  ('\n       ', 'uwzględniać'),
#  ('uwzględniać', 'rodzaj'),
#  ('rodzaj', 'środka'),
#  ('środka', 'transportowego'),
#  ('transportowego', ','),
#  (',', 'ładowność'),
#  ('ładowność', ','),
#  (',', 'masę'),
#  ('masę', 'całkowitą'),
#  ('całkowitą', ','),
#  (',', '\n       '),
#  ('\n       ', 'wiek'),
#  ('wiek', ','),
#  (',', 'nacisk'),
#  ('nacisk', 'na'),
#  ('na', 'siodło'),
#  ('siodło', 'ciągnika'),
#  ('ciągnika', 'albo'),
#  ('albo', 'liczbę'),
#  ('liczbę', 'miejsc'),
#  ('miejsc', 'do'),
#  ('do', 'siedzenia'),
#  ('siedzenia', '.'),
#  ('.', '"'),
#  ('"', '.'),
#  ('.',
#   '\n                                       \n                                       \n                                    '),
#  ('\n                                       \n                                       \n                                    ',
#   'art'),
#  ('art', '.'),
#  ('.', '2'),
#  ('2', '.'),
#  ('.', '\n '),
#  ('\n ', 'ustawa'),
#  ('ustawa', 'wchodzi'),
#  ('wchodzi', 'w'),
#  ('w', 'życie'),
#  ('życie', 'z'),
#  ('z', 'dniem'),
#  ('dniem', '1'),
#  ('1', 'stycznia'),
#  ('stycznia', '1999'),
#  ('1999', 'r'),
#  ('r', '.'),
#  ('.', '\n\n\n\n\n'),
#  ('\n\n\n\n\n', 'dz.u'),
#  ('dz.u', '.'),
#  ('.', 'z'),
#  ('z', '1998'),
#  ('1998', 'r'),
#  ('r', '.'),
#  ('.', 'nr'),
#  ('nr', '137'),
#  ('137', ','),
#  (',', 'poz'),
#  ...]

# %%
bigrams_count = Counter(bigrams)

# %%
bigrams_count
# Out:
# Counter({('\n\n\n\n', 'dz.u'): 1,
#          ('dz.u', '.'): 5752,
#          ('.', 'z'): 5028,
#          ('z', '1998'): 1375,
#          ('1998', 'r'): 2235,
#          ('r', '.'): 33010,
#          ('.', 'nr'): 20315,
#          ('nr', '75'): 346,
#          ('75', ','): 392,
#          (',', 'poz'): 39659,
#          ('poz', '.'): 45198,
#          ('.', '486'): 59,
#          ('486',
#           '\n                                                                          \n                                                                          \n                                                                          \n                                     \n                                  '): 1,
#          ('\n                                                                          \n                                                                          \n                                                                          \n                                     \n                                  ',
#           'ustawa'): 1,
#          ('ustawa', '\n                           '): 149,
#          ('\n                           ', 'z'): 204,
#          ('z', 'dnia'): 9098,
#          ('dnia', '7'): 271,
#          ('7', 'maja'): 21,
#          ('maja', '1998'): 8,
#          ('.', '\n                                     \n        '): 1,
#          ('\n                                     \n        ', 'o'): 1,
#          ('o', 'zmianie'): 1181,
#          ('zmianie', 'ustawy'): 829,
#          ('ustawy', 'o'): 1394,
#          ('o', 'zakładowym'): 24,
#          ('zakładowym', 'funduszu'): 21,
#          ('funduszu', 'świadczeń'): 43,
#          ('świadczeń', 'socjalnych'): 64,
#          ('socjalnych',
#           '\n                                     \n                                  '): 1,
#          ('\n                                     \n                                  ',
#           'art'): 14,
#          ('art', '.'): 83778,
#          ('.', '1'): 30062,
#          ('1', '.'): 21111,
#          ('.', '\n'): 49163,
#          ('\n', 'w'): 5925,
#          ('w', 'ustawie'): 4792,
#          ('ustawie', 'z'): 3624,
#          ('dnia', '4'): 198,
#          ('4', 'marca'): 40,
#          ('marca', '1994'): 32,
#          ('1994', 'r'): 1612,
#          ('.', 'o'): 6336,
#          ('świadczeń', '\n'): 46,
#          ('\n', 'socjalnych'): 6,
#          ('socjalnych', '('): 12,
#          ('(', 'dz.u'): 4536,
#          ('z', '1996'): 1234,
#          ('1996', 'r'): 1782,
#          ('nr', '70'): 300,
#          ('70', ','): 366,
#          ('.', '335'): 85,
#          ('335', ','): 57,
#          (',', 'nr'): 12589,
#          ('nr', '118'): 181,
#          ('118', ','): 286,
#          ('.', '561'): 63,
#          ('561', ','): 15,
#          ('nr', '139'): 222,
#          ('139', ','): 262,
#          (',', '\n'): 13037,
#          ('\n', 'poz'): 2344,
#          ('.', '647'): 62,
#          ('647', ','): 22,
#          ('nr', '147'): 140,
#          ('147', ','): 159,
#          ('.', '686'): 84,
#          ('686', ','): 49,
#          (',', 'z'): 18660,
#          ('z', '1997'): 1519,
#          ('1997', 'r'): 2897,
#          ('nr', '82'): 96,
#          ('82', ','): 112,
#          ('.', '518'): 34,
#          ('518', ','): 13,
#          ('nr', '121'): 782,
#          ('121', ','): 871,
#          ('.', '770'): 392,
#          ('770', ')'): 75,
#          (')', '\n'): 1873,
#          ('\n', 'wprowadza'): 332,
#          ('wprowadza', 'się'): 1742,
#          ('się', 'następujące'): 1637,
#          ('następujące', 'zmiany'): 1607,
#          ('zmiany', ':'): 1811,
#          (':', '\n'): 9673,
#          ('\n', '1'): 11018,
#          ('1', ')'): 14073,
#          (')', 'w'): 16007,
#          ('w', 'art'): 30470,
#          ('1', 'w'): 997,
#          ('w', 'ust'): 22400,
#          ('ust', '.'): 53552,
#          ('.', '2'): 13260,
#          ('2', 'po'): 338,
#          ('po', 'wyrazach'): 925,
#          ('wyrazach', '"'): 905,
#          ('"', 'minister'): 599,
#          ('minister', 'spraw'): 245,
#          ('spraw', 'wewnętrznych'): 1391,
#          ('wewnętrznych', '"'): 91,
#          ('"', 'dodaje'): 1269,
#          ('dodaje', 'się'): 7960,
#          ('się', '\n  '): 681,
#          ('\n  ', 'wyrazy'): 98,
#          ('wyrazy', '"'): 5306,
#          ('"', 'i'): 487,
#          ('i', 'administracji'): 404,
#          ('administracji', '"'): 72,
#          ('"', ';'): 11037,
#          (';', '\n'): 18151,
#          ('\n', '2'): 11795,
#          ('2', ')'): 14028,
#          ('.', '5'): 3868,
#          ('5', 'ust'): 445,
#          ('.', '4'): 5395,
#          ('4', 'otrzymuje'): 665,
#          ('otrzymuje', 'brzmienie'): 9169,
#          ('brzmienie', ':'): 10503,
#          (':', '\n         '): 953,
#          ('\n         ', '"'): 552,
#          ('"', '4'): 798,
#          ('4', '.'): 8500,
#          ('.', 'wysokość'): 303,
#          ('wysokość', 'odpisu'): 17,
#          ('odpisu', 'podstawowego'): 5,
#          ('podstawowego', 'może'): 1,
#          ('może', 'być'): 2556,
#          ('być', 'zwiększona'): 4,
#          ('zwiększona', 'o'): 1,
#          ('o', '6,25'): 1,
#          ('6,25', '%'): 1,
#          ('%', '\n           '): 33,
#          ('\n           ', 'przeciętnego'): 7,
#          ('przeciętnego', 'wynagrodzenia'): 142,
#          ('wynagrodzenia', 'miesięcznego'): 87,
#          ('miesięcznego', ','): 52,
#          (',', 'o'): 28741,
#          ('o', 'którym'): 8616,
#          ('którym', 'mowa'): 8689,
#          ('mowa', 'w'): 27649,
#          ('.', '\n           '): 1174,
#          ('\n           ', '2'): 1987,
#          ('2', ','): 6130,
#          (',', 'na'): 4181,
#          ('na', 'każdą'): 25,
#          ('każdą', 'zatrudnioną'): 2,
#          ('zatrudnioną', 'osobę'): 2,
#          ('osobę', ','): 236,
#          (',', 'w'): 21529,
#          ('w', 'stosunku'): 1228,
#          ('stosunku', 'do'): 1134,
#          ('do', 'której'): 184,
#          ('której', 'orzeczono'): 9,
#          ('orzeczono', '\n           '): 2,
#          ('\n           ', 'znaczny'): 1,
#          ('znaczny', 'lub'): 1,
#          ('lub', 'umiarkowany'): 2,
#          ('umiarkowany', 'stopień'): 3,
#          ('stopień', 'niepełnosprawności'): 12,
#          ('niepełnosprawności', '.'): 14,
#          ('.', '"'): 11413,
#          ('\n', '3'): 7520,
#          ('3', ')'): 9182,
#          ('.', '7'): 2224,
#          ('7', ':'): 83,
#          (':', '\n   '): 9703,
#          ('\n   ', 'a'): 2878,
#          ('a', ')'): 6448,
#          (')', 'ust'): 1998,
#          ('2', 'otrzymuje'): 1377,
#          ('"', '2'): 1304,
#          ('2', '.'): 21274,
#          ('.', 'zwiększenia'): 4,
#          ('zwiększenia', ','): 9,
#          ('o', 'których'): 12785,
#          ('których', 'mowa'): 12974,
#          ('1', 'pkt'): 5310,
#          ('pkt', '7'): 567,
#          ('7', 'i'): 239,
#          ('i', '8'): 213,
#          ('8', ','): 634,
#          (',', 'nie'): 3244,
#          ('nie', 'dotyczą'): 63,
#          ('dotyczą', '\n           '): 3,
#          ('\n           ', 'pracodawców'): 3,
#          ('pracodawców', 'postawionych'): 1,
#          ('postawionych', 'w'): 5,
#          ('w', 'stan'): 114,
#          ('stan', 'upadłości'): 4,
#          ('upadłości', 'lub'): 27,
#          ('lub', 'likwidacji'): 44,
#          ('likwidacji', ','): 90,
#          ('z', '\n           '): 576,
#          ('\n           ', 'wyłączeniem'): 17,
#          ('wyłączeniem', 'przedsiębiorstw'): 2,
#          ('przedsiębiorstw', 'państwowych'): 141,
#          ('państwowych', 'likwidowanych'): 1,
#          ('likwidowanych', 'w'): 2,
#          ('w', 'celu'): 2498,
#          ('celu', '\n           '): 33,
#          ('\n           ', 'prywatyzacji'): 2,
#          ('prywatyzacji', '.'): 12,
#          ('"', ','): 6856,
#          (',', '\n   '): 19629,
#          ('\n   ', 'b'): 2817,
#          ('b', ')'): 6352,
#          ('.', '3'): 8665,
#          ('3', 'otrzymuje'): 1027,
#          ('"', '3'): 1186,
#          ('3', '.'): 13907,
#          ('.', 'w'): 9550,
#          ('w', 'razie'): 3016,
#          ('razie', 'przejścia'): 8,
#          ('przejścia', 'zakładu'): 12,
#          ('zakładu', 'pracy'): 127,
#          ('pracy', 'w'): 610,
#          ('w', 'trybie'): 1219,
#          ('trybie', 'art'): 130,
#          ('.', '231'): 110,
#          ('231', 'kodeksu'): 17,
#          ('kodeksu', '\n           '): 20,
#          ('\n           ', 'pracy'): 63,
#          ('pracy', 'na'): 213,
#          ('na', 'pracodawcę'): 3,
#          ('pracodawcę', 'zobowiązanego'): 2,
#          ('zobowiązanego', 'do'): 30,
#          ('do', 'tworzenia'): 32,
#          ('tworzenia', 'funduszu'): 13,
#          ('funduszu', ','): 275,
#          (',', '\n           '): 6363,
#          ('\n           ', 'fundusz'): 3,
#          ('fundusz', 'pracodawcy'): 2,
#          ('pracodawcy', 'przejmującego'): 3,
#          ('przejmującego', 'przejmuje'): 1,
#          ('przejmuje', 'środki'): 2,
#          ('środki', 'pieniężne'): 90,
#          ('pieniężne', ','): 117,
#          ('\n           ', 'należności'): 38,
#          ('należności', 'i'): 96,
#          ('i', 'zobowiązania'): 47,
#          ('zobowiązania', 'funduszu'): 11,
#          ('funduszu', 'pracodawcy'): 3,
#          ('pracodawcy', 'przekazującego'): 2,
#          ('przekazującego', '.'): 3,
#          ('\n   ', 'c'): 1084,
#          ('c', ')'): 2939,
#          (')', 'dodaje'): 1130,
#          ('się', 'ust'): 3405,
#          ('.', '3a'): 424,
#          ('3a', '-'): 26,
#          ('-', '3d'): 8,
#          ('3d', 'w'): 12,
#          ('w', 'brzmieniu'): 6753,
#          ('brzmieniu', ':'): 6626,
#          (':', '\n        '): 552,
#          ('\n        ', '"'): 393,
#          ('"', '3a'): 205,
#          ('3a', '.'): 288,
#          ('pracodawcę', ','): 38,
#          (',', 'który'): 2467,
#          ('który', 'nie'): 212,
#          ('nie', 'jest'): 844,
#          ('jest', 'zobowiązany'): 96,
#          ('zobowiązany', 'do'): 79,
#          ('tworzenia', '\n           '): 5,
#          ('\n           ', 'funduszu'): 27,
#          (',', 'pracodawca'): 54,
#          ('pracodawca', 'przejmujący'): 1,
#          ('przejmujący', 'przejmuje'): 1,
#          ('\n           ', 'nadwyżka'): 1,
#          ('nadwyżka', 'przejętych'): 1,
#          ('przejętych', 'środków'): 1,
#          ('środków', 'pieniężnych'): 146,
#          ('pieniężnych', 'wraz'): 3,
#          ('wraz', 'z'): 1375,
#          ('z', 'odsetkami'): 149,
#          ('odsetkami', 'oraz'): 4,
#          ('oraz', '\n           '): 296,
#          ('\n           ', 'przejętych'): 3,
#          ('przejętych', 'należności'): 1,
#          ('należności', 'wraz'): 10,
#          ('odsetkami', 'nad'): 1,
#          ('nad', 'przejętymi'): 1,
#          ('przejętymi', '\n           '): 1,
#          ('\n           ', 'zobowiązaniami'): 2,
#          ('zobowiązaniami', 'wraz'): 1,
#          ('odsetkami', 'nie'): 2,
#          ('nie', 'stanowi'): 278,
#          ('stanowi', 'przychodu'): 5,
#          ('przychodu', '\n           '): 1,
#          ('\n           ', 'pracodawcy'): 15,
#          ('przejmującego', ','): 1,
#          (',', 'jest'): 1156,
#          ('jest', 'gromadzona'): 1,
#          ('gromadzona', 'na'): 1,
#          ('na', 'odrębnym'): 15,
#          ('odrębnym', 'rachunku'): 10,
#          ('rachunku', '\n           '): 15,
#          ('\n           ', 'bankowym'): 5,
#          ('bankowym', 'lub'): 2,
#          ('lub', 'wydzielonym'): 1,
#          ('wydzielonym', 'subkoncie'): 2,
#          ('subkoncie', 'i'): 1,
#          ('i', 'podlega'): 33,
#          ('podlega', 'wydatkowaniu'): 1,
#          ('wydatkowaniu', 'na'): 1,
#          ('na', '\n           '): 488,
#          ('\n           ', 'zasadach'): 14,
#          ('zasadach', 'określonych'): 860,
#          ('określonych', 'ustawą'): 59,
#          ('ustawą', 'dla'): 1,
#          ('dla', 'dokonywania'): 4,
#          ('dokonywania', 'wydatków'): 17,
#          ('wydatków', 'z'): 21,
#          ('funduszu', '.'): 201,
#          ('.', 'art'): 40,
#          ('.', '8'): 1974,
#          ('8', 'ust'): 330,
#          ('2', 'stosuje'): 371,
#          ('stosuje', 'się'): 6233,
#          ('się', 'odpowiednio'): 2770,
#          ('odpowiednio', '.'): 1163,
#          ('.', '\n         '): 6266,
#          ('\n         ', '3b'): 3,
#          ('3b', '.'): 96,
#          ('przejścia', 'części'): 2,
#          ('części', 'zakładu'): 8,
#          ('231', '\n           '): 1,
#          ('\n           ', 'kodeksu'): 18,
#          ('kodeksu', 'pracy'): 206,
#          (',', 'fundusz'): 65,
#          ('przejmującego', 'zwiększa'): 1,
#          ('zwiększa', 'się'): 26,
#          ('się', ','): 988,
#          ('w', '\n           '): 1321,
#          ('\n           ', 'części'): 16,
#          ('części', 'przypadającej'): 12,
#          ('przypadającej', 'na'): 23,
#          ('na', 'liczbę'): 19,
#          ('liczbę', 'przejmowanych'): 1,
#          ('przejmowanych', 'pracowników'): 1,
#          ('pracowników', ','): 268,
#          ('o', '\n           '): 460,
#          ('\n           ', 'równowartość'): 6,
#          ('równowartość', 'środków'): 1,
#          ('pieniężnych', 'funduszu'): 1,
#          ('pracodawcy', '\n           '): 8,
#          ('\n           ', 'przekazującego'): 2,
#          ('przekazującego', ','): 2,
#          (',', 'skorygowanych'): 2,
#          ('skorygowanych', 'odpowiednio'): 1,
#          ('odpowiednio', 'o'): 13,
#          ('o', 'należności'): 1,
#          ('i', '\n           '): 576,
#          ('\n           ', 'zobowiązania'): 13,
#          ('funduszu', '-'): 11,
#          ('-', 'według'): 43,
#          ('według', 'stanu'): 138,
#          ('stanu', 'na'): 100,
#          ('na', 'ostatni'): 47,
#          ('ostatni', 'dzień'): 57,
#          ('dzień', 'miesiąca'): 10,
#          ('miesiąca', ','): 181,
#          ('\n           ', 'w'): 341,
#          ('w', 'którym'): 1668,
#          ('którym', 'następuje'): 21,
#          ('następuje', 'przejście'): 2,
#          ('przejście', '.'): 2,
#          ('\n         ', '3c'): 2,
#          ('3c', '.'): 48,
#          ('.', 'zasady'): 200,
#          ('zasady', 'podziału'): 18,
#          ('podziału', 'środków'): 26,
#          ('pieniężnych', 'stanowiących'): 1,
#          ('stanowiących', 'równowartość'): 5,
#          ('równowartość', '\n           '): 6,
#          ('\n           ', 'odpisu'): 2,
#          ('podstawowego', ','): 15,
#          (',', 'obciążającego'): 1,
#          ('obciążającego', 'koszty'): 1,
#          ('koszty', 'pracodawcy'): 1,
#          (',', 'dotyczącego'): 19,
#          ('dotyczącego', 'roku'): 1,
#          ('roku', ','): 541,
#          ('przejście', '\n           '): 1,
#          ('pracy', ','): 1589,
#          (',', 'określa'): 353,
#          ('określa', 'porozumienie'): 5,
#          ('porozumienie', 'między'): 2,
#          ('między', 'pracodawcami'): 2,
#          ('pracodawcami', '.'): 2,
#          ('\n         ', '3d'): 1,
#          ('3d', '.'): 22,
#          ('.', 'przekazanie'): 49,
#          ('przekazanie', 'środków'): 9,
#          ('środków', ','): 262,
#          ('.', '3b'): 70,
#          ('3b', 'i'): 10,
#          ('i', '3c'): 9,
#          ('3c', ','): 13,
#          (',', 'następuje'): 249,
#          ('następuje', '\n           '): 10,
#          ('w', 'terminie'): 3668,
#          ('terminie', 'trzydziestu'): 9,
#          ('trzydziestu', 'dni'): 15,
#          ('dni', 'od'): 2397,
#          ('od', 'daty'): 430,
#          ('daty', 'przejścia'): 1,
#          ('zakładu', '\n           '): 12,
#          (',', 'chyba'): 1159,
#          ('chyba', 'że'): 1240,
#          ('że', 'porozumienie'): 3,
#          ('porozumienie', ','): 24,
#          ('.', '3c'): 38,
#          ('3c', 'stanowi'): 1,
#          ('stanowi', '\n           '): 21,
#          ('\n           ', 'inaczej'): 14,
#          ('inaczej', '.'): 540,
#          ('"', '.'): 3012,
#          ('.', '\n     \n                                  '): 5,
#          ('\n     \n                                  ', 'art'): 4,
#          ('\n', 'ustawa'): 1249,
#          ('ustawa', 'wchodzi'): 1095,
#          ('wchodzi', 'w'): 1456,
#          ('w', 'życie'): 4000,
#          ('życie', 'w'): 42,
#          ('terminie', '14'): 418,
#          ('14', 'dni'): 1167,
#          ('od', 'dnia'): 4972,
#          ('dnia', 'ogłoszenia'): 912,
#          ('ogłoszenia', '.'): 790,
#          ('.', '\n\n\n\n\n'): 503,
#          ('\n\n\n\n\n', 'dz.u'): 528,
#          ('z', '2004'): 560,
#          ('2004', 'r'): 1161,
#          ('nr', '238'): 37,
#          ('238', ','): 69,
#          ('.', '2387'): 1,
#          ('2387',
#           '\n                                        \n               \n                                        \n                                        \n                                        \n                                   '): 1,
#          ('\n                                        \n               \n                                        \n                                        \n                                        \n                                   ',
#           'u'): 3,
#          ('u', 's'): 141,
#          ('s', 't'): 141,
#          ('t', 'a'): 141,
#          ('a', 'w'): 2125,
#          ('w', 'a'): 142,
#          ('a', '\n                           '): 54,
#          ('dnia', '27'): 448,
#          ('27', 'sierpnia'): 113,
#          ('sierpnia', '2004'): 41,
#          ('.', '\n                                        \n    '): 26,
#          ('\n                                        \n    ', 'o'): 22,
#          ('o', 'ratyfikacji'): 104,
#          ('ratyfikacji', 'konwencji'): 57,
#          ('konwencji', 'o'): 123,
#          ('o', 'pozbawianiu'): 2,
#          ('pozbawianiu', 'uprawnień'): 2,
#          ('uprawnień', 'do'): 218,
#          ('do', 'kierowania'): 89,
#          ('kierowania', 'pojazdami'): 26,
#          ('pojazdami', ','): 17,
#          (',', '\n               '): 307,
#          ('\n               ', 'sporządzonej'): 1,
#          ('sporządzonej', 'w'): 115,
#          ('w', 'luksemburgu'): 6,
#          ('luksemburgu', 'dnia'): 6,
#          ('dnia', '17'): 367,
#          ('17', 'czerwca'): 56,
#          ('czerwca', '1998'): 65,
#          ('.',
#           '\n                                        \n                                        \n                                     '): 37,
#          ('\n                                        \n                                        \n                                     ',
#           'art'): 209,
#          ('\n', 'wyraża'): 99,
#          ('wyraża', 'się'): 116,
#          ('się', 'zgodę'): 110,
#          ('zgodę', 'na'): 332,
#          ('na', 'dokonanie'): 156,
#          ('dokonanie', 'przez'): 114,
#          ('przez', 'prezydenta'): 140,
#          ('prezydenta', 'rzeczypospolitej'): 325,
#          ('rzeczypospolitej', 'polskiej'): 2877,
#          ('polskiej', '\n'): 176,
#          ('\n', 'ratyfikacji'): 91,
#          ('\n', 'sporządzonej'): 18,
#          ('.',
#           '\n                                        \n                                     '): 898,
#          ('\n                                        \n                                     ',
#           'art'): 1131,
#          ('życie', 'po'): 810,
#          ('po', 'upływie'): 1548,
#          ('upływie', '14'): 548,
#          ('nr', '160'): 304,
#          ('160', ','): 329,
#          ('.', '1058'): 15,
#          ('1058',
#           '\n                                                                              \n                                                                              \n                                       \n                                    '): 1,
#          ('\n                                                                              \n                                                                              \n                                       \n                                    ',
#           'ustawa'): 2,
#          ('dnia', '3'): 147,
#          ('3', 'grudnia'): 17,
#          ('grudnia', '1998'): 276,
#          ('.',
#           '\n                                       \n               '): 11,
#          ('\n                                       \n               ',
#           'o'): 10,
#          ('o', 'podatkach'): 33,
#          ('podatkach', 'i'): 35,
#          ('i', 'opłatach'): 33,
#          ('opłatach', 'lokalnych'): 34,
#          ('lokalnych',
#           '\n                                       \n                                       \n                                    '): 1,
#          ('\n                                       \n                                       \n                                    ',
#           'art'): 134,
#          ('dnia', '12'): 270,
#          ('12', 'stycznia'): 35,
#          ('stycznia', '1991'): 94,
#          ('1991', 'r'): 1289,
#          ('lokalnych', '('): 24,
#          ('\n', 'nr'): 1433,
#          ('nr', '9'): 240,
#          ('9', ','): 607,
#          ('.', '31'): 785,
#          ('31', 'i'): 46,
#          ('i', 'nr'): 7976,
#          ('nr', '101'): 240,
#          ('101', ','): 325,
#          ('.', '444'): 66,
#          ('444', ','): 38,
#          ('z', '1992'): 434,
#          ('1992', 'r'): 677,
#          ('nr', '21'): 279,
#          ('21', ','): 377,
#          ('.', '86'): 254,
#          ('86', ','): 410,
#          ('z', '1994'): 925,
#          ('nr', '123'): 433,
#          ('123', ','): 539,
#          ('.', '600'): 57,
#          ('600', ','): 48,
#          ('nr', '91'): 269,
#          ('91', ','): 328,
#          ('.', '409'): 54,
#          ('409', 'i'): 14,
#          ('nr', '149'): 174,
#          ('149', ','): 214,
#          ('.', '704'): 105,
#          ('704', ','): 53,
#          ('nr', '5'): 366,
#          ('5', ','): 1767,
#          ('\n', '24'): 221,
#          ('24', ','): 436,
#          ('nr', '107'): 386,
#          ('107', ','): 417,
#          ('.', '689'): 23,
#          ('689', ','): 11,
#          ('770', 'i'): 154,
#          ('.', '780'): 25,
#          ('780', 'oraz'): 10,
#          ('oraz', 'z'): 4095,
#          ('nr', '\n'): 1685,
#          ('\n', '106'): 74,
#          ('106', 'poz'): 11,
#          ('.', '668'): 744,
#          ('668', ')'): 152,
#          (')', 'wprowadza'): 1318,
#          ('8', 'pkt'): 166,
#          ('pkt', '4'): 1411,
#          (':', '\n     '): 5103,
#          ('\n     ', '"'): 4459,
#          ('4', ')'): 6040,
#          (')', 'przyczepy'): 4,
#          ('przyczepy', 'i'): 10,
#          ('i', 'naczepy'): 6,
#          ('naczepy', 'o'): 3,
#          ('o', 'ładowności'): 14,
#          ('ładowności', 'powyżej'): 6,
#          ('powyżej', '5'): 24,
#          ('5', 'ton'): 10,
#          ('ton', ','): 14,
#          ('z', 'wyjątkiem'): 1469,
#          ('wyjątkiem', '\n       '): 17,
#          ('\n       ', 'wykorzystywanych'): 2,
#          ('wykorzystywanych', 'na'): 13,
#          ('na', 'cele'): 504,
#          ('cele', 'rolnicze'): 15,
#          ('rolnicze', 'przez'): 1,
#          ('przez', 'podatnika'): 134,
#          ('podatnika', 'podatku'): 23,
#          ('podatku', 'rolnego'): 39,
#          ('rolnego', ','): 105,
#          (',', '"'): 2070,
#          ('.', '10'): 1563,
#          ('10', 'dotychczasową'): 4,
#          ('dotychczasową', 'treść'): 222,
#          ('treść', 'oznacza'): 211,
#          ('oznacza', 'się'): 275,
#          ('się', 'jako'): 327,
#          ('jako', 'ust'): 205,
#          ('1', 'i'): 3576,
#          ('i', 'dodaje'): 851,
#          ('2', '\n  '): 104,
#          ('\n  ', 'w'): 820,
#          ('.', 'przy'): 466,
#          ('przy', 'określaniu'): 37,
#          ('określaniu', 'stawek'): 3,
#          ('stawek', ','): 19,
#          ('1', ','): 12507,
#          (',', 'rada'): 102,
#          ('rada', 'gminy'): 173,
#          ('gminy', 'może'): 57,
#          ('może', '\n       '): 44,
#          ('\n       ', 'uwzględniać'): 2,
#          ('uwzględniać', 'rodzaj'): 4,
#          ('rodzaj', 'środka'): 10,
#          ('środka', 'transportowego'): 7,
#          ('transportowego', ','): 2,
#          (',', 'ładowność'): 2,
#          ('ładowność', ','): 2,
#          (',', 'masę'): 4,
#          ('masę', 'całkowitą'): 7,
#          ('całkowitą', ','): 3,
#          (',', '\n       '): 2533,
#          ('\n       ', 'wiek'): 1,
#          ('wiek', ','): 40,
#          (',', 'nacisk'): 2,
#          ('nacisk', 'na'): 2,
#          ('na', 'siodło'): 2,
#          ('siodło', 'ciągnika'): 2,
#          ('ciągnika', 'albo'): 2,
#          ('albo', 'liczbę'): 3,
#          ('liczbę', 'miejsc'): 5,
#          ('miejsc', 'do'): 8,
#          ('do', 'siedzenia'): 3,
#          ('siedzenia', '.'): 2,
#          ('.',
#           '\n                                       \n                                       \n                                    '): 31,
#          ('.', '\n '): 14090,
#          ('\n ', 'ustawa'): 14,
#          ('życie', 'z'): 824,
#          ('z', 'dniem'): 1737,
#          ('dniem', '1'): 971,
#          ('1', 'stycznia'): 1099,
#          ('stycznia', '1999'): 301,
#          ('1999', 'r'): 1937,
#          ('nr', '137'): 451,
#          ('137', ','): 517,
#          ('.', '887'): 149,
#          ('887',
#           '\n                                      \n                                      \n                                      \n                                   '): 1,
#          ('\n                                      \n                                      \n                                      \n                                   ',
#           'ustawa'): 3,
#          ('ustawa', '\n                       '): 142,
#          ('\n                       ', 'z'): 152,
#          ('dnia', '13'): 292,
#          ('13', 'października'): 129,
#          ('października', '1998'): 105,
#          ('.',
#           '\n                                      \n                     '): 1,
#          ('\n                                      \n                     ',
#           'o'): 1,
#          ('o', 'systemie'): 279,
#          ('systemie', 'ubezpieczeń'): 152,
#          ('ubezpieczeń', 'społecznych'): 727,
#          ('społecznych',
#           '\n                                      \n                                      \n                                 '): 1,
#          ('\n                                      \n                                      \n                                 ',
#           'rozdział'): 3,
#          ('rozdział', '1'): 291,
#          ('1', '\n                               '): 11,
#          ('\n                               ', 'przepisy'): 22,
#          ('przepisy', 'ogólne'): 247,
#          ('ogólne',
#           '\n                                      \n                                   '): 8,
#          ('\n                                      \n                                   ',
#           'art'): 96,
#          ('\n', 'ubezpieczenia'): 47,
#          ('ubezpieczenia', 'społeczne'): 93,
#          ('społeczne', 'obejmują'): 1,
#          ('obejmują', ':'): 38,
#          ('\n   ', '1'): 5563,
#          (')', 'ubezpieczenie'): 7,
#          ('ubezpieczenie', 'emerytalne'): 51,
#          ('emerytalne', ','): 70,
#          ('\n   ', '2'): 5572,
#          (')', 'ubezpieczenia'): 21,
#          ('ubezpieczenia', 'rentowe'): 3,
#          ('rentowe', ','): 48,
#          ('\n   ', '3'): 3671,
#          ('ubezpieczenie', 'w'): 4,
#          ('razie', 'choroby'): 39,
#          ('choroby', 'i'): 42,
#          ('i', 'macierzyństwa'): 31,
#          ('macierzyństwa', ','): 9,
#          (',', 'zwane'): 200,
#          ('zwane', 'dalej'): 224,
#          ('dalej', '\n     '): 23,
#          ('"', 'ubezpieczeniem'): 6,
#          ('ubezpieczeniem', 'chorobowym'): 5,
#          ('chorobowym', '"'): 2,
#          ('\n   ', '4'): 2402,
#          ('ubezpieczenie', 'z'): 3,
#          ('z', 'tytułu'): 2244,
#          ('tytułu', 'wypadków'): 45,
#          ('wypadków', 'przy'): 47,
#          ('przy', 'pracy'): 95,
#          ('pracy', 'i'): 548,
#          ('i', 'chorób'): 64,
#          ('chorób', 'zawodowych'): 54,
#          ('zawodowych', ','): 226,
#          ('zwane', '\n     '): 3,
#          ('\n     ', 'dalej'): 17,
#          ('dalej', '"'): 964,
#          ('ubezpieczeniem', 'wypadkowym'): 1,
#          ('wypadkowym', '"'): 1,
#          ('.', '\n   \n                                   '): 121,
#          ('\n   \n                                   ', 'art'): 100,
#          ('.', 'ustawa'): 247,
#          ('ustawa', 'określa'): 199,
#          ('określa', ':'): 86,
#          (')', 'zasady'): 250,
#          ('zasady', 'podlegania'): 4,
#          ('podlegania', 'ubezpieczeniom'): 9,
#          ('ubezpieczeniom', 'społecznym'): 12,
#          ('społecznym', ','): 17,
#          ('zasady', 'ustalania'): 80,
#          ('ustalania', 'składek'): 3,
#          ('składek', 'na'): 422,
#          ('na', 'ubezpieczenia'): 205,
#          ('społeczne', 'oraz'): 13,
#          ('oraz', 'podstaw'): 3,
#          ('podstaw', 'ich'): 2,
#          ('ich', '\n     '): 182,
#          ('\n     ', 'wymiaru'): 6,
#          ('wymiaru', ','): 13,
#          ('zasady', ','): 120,
#          (',', 'tryb'): 381,
#          ('tryb', 'i'): 213,
#          ('i', 'terminy'): 133,
#          ('terminy', ':'): 2,
#          ('\n     ', 'a'): 818,
#          (')', 'zgłoszeń'): 6,
#          ('zgłoszeń', 'do'): 7,
#          ('do', 'ubezpieczeń'): 35,
#          ('społecznych', ','): 276,
#          (',', '\n     '): 5846,
#          ('\n     ', 'b'): 701,
#          (')', 'prowadzenia'): 82,
#          ('prowadzenia', 'ewidencji'): 94,
#          ('ewidencji', 'ubezpieczonych'): 1,
#          ('ubezpieczonych', 'i'): 23,
#          ('i', 'płatników'): 18,
#          ('płatników', 'składek'): 55,
#          ('składek', ','): 172,
#          ('\n     ', 'c'): 443,
#          (')', 'rozliczania'): 5,
#          ('rozliczania', 'składek'): 5,
#          ('oraz', 'zasiłków'): 13,
#          ('zasiłków', 'z'): 15,
#          ('z', '\n       '): 440,
#          ('\n       ', 'ubezpieczeń'): 19,
#          ('ubezpieczeń', 'chorobowego'): 1,
#          ('chorobowego', 'i'): 5,
#          ('i', 'wypadkowego'): 3,
#          ('wypadkowego', ','): 5,
#          ('\n     ', 'd'): 248,
#          ('d', ')'): 1466,
#          (')', 'opłacania'): 2,
#          ('opłacania', 'składek'): 54,
#          ('społeczne', ','): 119,
#          ('zasady', 'prowadzenia'): 52,
#          ('prowadzenia', 'kont'): 6,
#          ('kont', 'ubezpieczonych'): 4,
#          ('ubezpieczonych', 'oraz'): 13,
#          ('oraz', 'kont'): 1,
#          ('kont', 'płatników'): 5,
#          ('\n   ', '5'): 1629,
#          ('5', ')'): 4228,
#          ('zasady', 'działania'): 60,
#          ('działania', 'funduszu'): 9,
#          ('funduszu', 'ubezpieczeń'): 136,
#          (',', 'zwanego'): 181,
#          ('zwanego', 'dalej'): 189,
#          ('"', 'fus'): 1,
#          ('fus', '"'): 1,
#          ('\n   ', '6'): 1112,
#          ('6', ')'): 3012,
#          (')', 'organizację'): 31,
#          ('organizację', ','): 51,
#          (',', 'zasady'): 212,
#          ('działania', 'i'): 53,
#          ('i', 'finansowania'): 17,
#          ('finansowania', 'zakładu'): 2,
#          ('zakładu', 'ubezpieczeń'): 286,
#          ('ubezpieczeń', '\n     '): 31,
#          ('\n     ', 'społecznych'): 35,
#          ('"', 'zakładem'): 8,
#          ('zakładem', '"'): 5,
#          ('\n   ', '7'): 754,
#          ('7', ')'): 2214,
#          ('funduszu', 'rezerwy'): 1,
#          ('rezerwy', 'demograficznej'): 3,
#          ('demograficznej', ','): 2,
#          ('"', 'frd'): 1,
#          ('frd', '"'): 1,
#          ('\n     ', 'oraz'): 484,
#          ('oraz', 'zasady'): 216,
#          ('zasady', 'zarządzania'): 6,
#          ('zarządzania', 'tym'): 3,
#          ('tym', 'funduszem'): 10,
#          ('funduszem', ','): 15,
#          ('\n   ', '8)'): 513,
#          ('8)', 'zasady'): 8,
#          ('zasady', 'kontroli'): 10,
#          ('kontroli', 'wykonywania'): 8,
#          ('wykonywania', 'zadań'): 277,
#          ('zadań', 'z'): 114,
#          ('z', 'zakresu'): 734,
#          ('zakresu', 'ubezpieczeń'): 14,
#          ('społecznych', '.'): 146,
#          ('.', 'rodzaje'): 5,
#          ('rodzaje', 'świadczeń'): 6,
#          ('świadczeń', 'z'): 105,
#          ('z', 'ubezpieczeń'): 33,
#          (',', 'warunki'): 349,
#          ('warunki', 'nabywania'): 8,
#          ('nabywania', 'prawa'): 8,
#          ('prawa', 'do'): 804,
#          ('do', '\n  '): 1092,
#          ('\n  ', 'nich'): 11,
#          ('nich', 'oraz'): 12,
#          ('zasady', 'i'): 551,
#          ('i', 'tryb'): 1082,
#          ('tryb', 'ich'): 95,
#          ('ich', 'przyznawania'): 17,
#          ('przyznawania', 'określają'): 1,
#          ('określają', 'odrębne'): 74,
#          ('odrębne', 'przepisy'): 151,
#          ('przepisy', '.'): 138,
#          ('.', 'wypłacalność'): 1,
#          ('wypłacalność', 'świadczeń'): 1,
#          ('społecznych', 'gwarantowana'): 1,
#          ('gwarantowana', 'jest'): 2,
#          ('jest', 'przez'): 71,
#          ('przez', '\n  '): 382,
#          ('\n  ', 'państwo'): 3,
#          ('państwo', '.'): 12,
#          ('.', '\n                                   '): 1098,
#          ('\n                                   ', 'art'): 906,
#          ('.', 'zadania'): 178,
#          ('zadania', 'z'): 108,
#          ('społecznych', 'określone'): 2,
#          ('określone', 'ustawą'): 22,
#          ('ustawą', 'wykonują'): 1,
#          ('wykonują', ':'): 14,
#          (')', 'zakład'): 39,
#          ('zakład', 'ubezpieczeń'): 239,
#          (')', 'otwarte'): 1,
#          ('otwarte', 'fundusze'): 11,
#          ('fundusze', 'emerytalne'): 10,
#          (',', 'określone'): 187,
#          ('określone', 'w'): 2039,
#          ('w', 'przepisach'): 1461,
#          ('przepisach', 'o'): 555,
#          ('o', 'organizacji'): 87,
#          ('organizacji', 'i'): 136,
#          ('i', '\n     '): 1148,
#          ('\n     ', 'funkcjonowaniu'): 2,
#          ('funkcjonowaniu', 'funduszy'): 32,
#          ('funduszy', 'emerytalnych'): 47,
#          ('emerytalnych', ','): 45,
#          (')', 'zakłady'): 18,
#          ('zakłady', 'emerytalne'): 2,
#          ('o', 'zakładach'): 72,
#          ('zakładach', 'emerytalnych'): 5,
#          (')', 'płatnicy'): 4,
#          ('płatnicy', 'składek'): 43,
#          ('składek', '.'): 64,
#          ('zadania', 'związane'): 38,
#          ('związane', 'z'): 906,
#          ('z', 'ustalaniem'): 6,
#          ('ustalaniem', 'prawa'): 3,
#          ('do', 'świadczeń'): 229,
#          ('świadczeń', 'i'): 30,
#          ('i', 'ich'): 691,
#          ('ich', 'wysokości'): 46,
#          ('wysokości', 'oraz'): 18,
#          ('oraz', '\n  '): 536,
#          ('\n  ', 'wypłatą'): 1,
#          ('wypłatą', 'świadczeń'): 7,
#          ('z', 'ubezpieczenia'): 103,
#          ('ubezpieczenia', 'chorobowego'): 40,
#          ('chorobowego', 'płatnicy'): 2,
#          ('składek', 'wykonują'): 1,
#          ('wykonują', '\n  '): 14,
#          ('\n  ', 'odpłatnie'): 2,
#          ('odpłatnie', '.'): 11,
#          ('.', 'wynagrodzenia'): 16,
#          ('wynagrodzenia', 'płatników'): 4,
#          ('składek', 'określa'): 1,
#          ('określa', 'się'): 271,
#          ('jako', 'procent'): 3,
#          ('procent', 'kwoty'): 4,
#          ('kwoty', '\n  '): 40,
#          ('\n  ', 'tych'): 61,
#          ('tych', 'świadczeń'): 85,
#          ('świadczeń', '.'): 73,
#          ('wysokość', 'stopy'): 8,
#          ('stopy', 'procentowej'): 16,
#          ('procentowej', 'oraz'): 3,
#          ('oraz', 'tryb'): 240,
#          ('tryb', 'rozliczenia'): 2,
#          ('rozliczenia', 'tego'): 3,
#          ('tego', '\n  '): 83,
#          ('\n  ', 'wynagrodzenia'): 55,
#          ('wynagrodzenia', 'określi'): 1,
#          ('określi', ','): 3112,
#          ('w', 'drodze'): 6669,
#          ('drodze', 'rozporządzenia'): 3677,
#          ('rozporządzenia', ','): 4052,
#          (',', 'minister'): 500,
#          ('minister', 'właściwy'): 4166,
#          ('właściwy', 'do'): 4773,
#          ('do', 'spraw'): 8218,
#          ('spraw', '\n  '): 272,
#          ('\n  ', 'zabezpieczenia'): 26,
#          ('zabezpieczenia', 'społecznego'): 210,
#          ('społecznego', '.'): 66,
#          ('.', 'pozostałe'): 179,
#          ('pozostałe', 'zadania'): 1,
#          ('ubezpieczeń', '\n  '): 23,
#          ('\n  ', 'społecznych'): 25,
#          ('społecznych', 'płatnicy'): 1,
#          ('składek', 'są'): 17,
#          ('są', 'zobowiązani'): 20,
#          ('zobowiązani', 'wykonywać'): 1,
#          ('wykonywać', 'nieodpłatnie'): 1,
#          ('nieodpłatnie', '.'): 27,
#          ('.', 'zakres'): 62,
#          ('zakres', 'zadań'): 54,
#          ('społecznych', 'wykonywanych'): 1,
#          ('wykonywanych', 'przez'): 72,
#          ('przez', 'otwarte'): 4,
#          ('otwarte', '\n  '): 1,
#          ('\n  ', 'fundusze'): 2,
#          ('emerytalne', 'i'): 136,
#          ('i', 'zakłady'): 27,
#          ('emerytalne', 'określają'): 1,
#          ('określają', 'przepisy'): 98,
#          ('przepisy', 'o'): 451,
#          ('i', '\n  '): 1170,
#          ('\n  ', 'funkcjonowaniu'): 2,
#          ('emerytalnych', 'oraz'): 4,
#          ('oraz', 'o'): 905,
#          ('emerytalnych', '.'): 17,
#          ('\n', 'użyte'): 70,
#          ('użyte', 'w'): 371,
#          ('ustawie', 'określenia'): 75,
#          ('określenia', 'oznaczają'): 84,
#          ('oznaczają', ':'): 97,
#          (')', 'ubezpieczeni'): 1,
#          ('ubezpieczeni', '"'): 1,
#          ('"', 'osoby'): 19,
#          ('osoby', 'fizyczne'): 211,
#          ('fizyczne', 'podlegające'): 1,
#          ('podlegające', 'chociaż'): 1,
#          ('chociaż', 'jednemu'): 1,
#          ('jednemu', 'z'): 51,
#          (')', 'płatnik'): 4,
#          ('płatnik', 'składek'): 89,
#          ('składek', ':'): 4,
#          (')', 'pracodawca'): 8,
#          ('pracodawca', '-'): 5,
#          ('-', 'w'): 1764,
#          ('do', 'pracowników'): 114,
#          ('pracowników', 'oraz'): 32,
#          ('oraz', 'jednostka'): 9,
#          ('jednostka', 'organizacyjna'): 120,
#          ('organizacyjna', '\n       '): 3,
#          ('\n       ', 'lub'): 146,
#          ('lub', 'osoba'): 97,
#          ('osoba', 'fizyczna'): 137,
#          ('fizyczna', 'pozostająca'): 3,
#          ('pozostająca', 'z'): 5,
#          ('z', 'inną'): 44,
#          ('inną', 'osobą'): 24,
#          ('osobą', 'fizyczną'): 73,
#          ('fizyczną', 'w'): 8,
#          ('stosunku', '\n       '): 7,
#          ('\n       ', 'prawnym'): 4,
#          ('prawnym', 'uzasadniającym'): 3,
#          ('uzasadniającym', 'objęcie'): 3,
#          ('objęcie', 'tej'): 4,
#          ('tej', 'osoby'): 151,
#          ('osoby', 'ubezpieczeniami'): 3,
#          ('ubezpieczeniami', 'społecznymi'): 19,
#          ('społecznymi', ','): 21,
#          (')', 'jednostka'): 19,
#          ('jednostka', 'wypłacająca'): 5,
#          ('wypłacająca', 'świadczenia'): 1,
#          ('świadczenia', 'socjalne'): 10,
#          ('socjalne', 'i'): 13,
#          ('i', 'zasiłki'): 5,
#          ('zasiłki', 'socjalne'): 1,
#          ('socjalne', '-'): 1,
#          ('w', '\n       '): 821,
#          ('\n       ', 'stosunku'): 20,
#          ('do', 'osób'): 263,
#          ('osób', 'pobierających'): 40,
#          ('pobierających', 'świadczenia'): 3,
#          ('socjalne', 'wypłacane'): 4,
#          ('wypłacane', 'w'): 13,
#          ('\n       ', 'okresie'): 9,
#          ('okresie', 'urlopu'): 12,
#          ('urlopu', 'oraz'): 5,
#          ('oraz', 'osób'): 123,
#          ('pobierających', 'zasiłek'): 19,
#          ('zasiłek', 'socjalny'): 9,
#          ('socjalny', 'wypłacany'): 4,
#          ...})

# %% [markdown]
# # Task 3
# Discard bigrams containing characters other than letters. Make sure that you discard the invalid entries after computing the bigram counts.

# %%
letters_reg = r'^\p{Letter}+$'

def token_valid(token):
    return re.match(letters_reg, token)

# %%
valid_bigrams = Counter({
    (t1, t2): count for (t1, t2), count in bigrams_count.items() if token_valid(t1) and token_valid(t2)
})

# %%
valid_bigrams.most_common()
# Out:
# [(('w', 'art'), 2620),
#  (('mowa', 'w'), 2310),
#  (('w', 'ust'), 1876),
#  (('których', 'mowa'), 1168),
#  (('o', 'których'), 1158),
#  (('do', 'spraw'), 1085),
#  (('w', 'drodze'), 969),
#  (('otrzymuje', 'brzmienie'), 932),
#  (('z', 'dnia'), 761),
#  (('właściwy', 'do'), 688),
#  (('i', 'nr'), 685),
#  (('o', 'którym'), 674),
#  (('którym', 'mowa'), 670),
#  (('drodze', 'rozporządzenia'), 655),
#  (('minister', 'właściwy'), 641),
#  (('dodaje', 'się'), 578),
#  (('stosuje', 'się'), 508),
#  (('na', 'podstawie'), 496),
#  (('w', 'brzmieniu'), 485),
#  (('w', 'ustawie'), 470),
#  (('w', 'zakresie'), 431),
#  (('od', 'dnia'), 418),
#  (('w', 'szczególności'), 402),
#  (('oraz', 'z'), 391),
#  (('której', 'mowa'), 384),
#  (('o', 'której'), 380),
#  (('co', 'najmniej'), 372),
#  (('a', 'także'), 371),
#  (('ustawie', 'z'), 363),
#  (('w', 'przypadku'), 359),
#  (('w', 'tym'), 353),
#  (('określonych', 'w'), 343),
#  (('w', 'życie'), 337),
#  (('w', 'terminie'), 312),
#  (('się', 'ust'), 310),
#  (('zastępuje', 'się'), 307),
#  (('w', 'razie'), 287),
#  (('w', 'porozumieniu'), 271),
#  (('w', 'pkt'), 269),
#  (('skreśla', 'się'), 267),
#  (('porozumieniu', 'z'), 262),
#  (('w', 'sprawach'), 258),
#  (('spraw', 'wewnętrznych'), 254),
#  (('z', 'dniem'), 252),
#  (('służby', 'cywilnej'), 247),
#  (('się', 'odpowiednio'), 229),
#  (('dni', 'od'), 226),
#  (('w', 'celu'), 221),
#  (('ustawy', 'z'), 221),
#  (('właściwym', 'do'), 221),
#  (('się', 'w'), 212),
#  (('z', 'ministrem'), 208),
#  (('może', 'być'), 207),
#  (('na', 'wniosek'), 207),
#  (('a', 'w'), 204),
#  (('z', 'tytułu'), 199),
#  (('do', 'dnia'), 197),
#  (('z', 'zastrzeżeniem'), 194),
#  (('rzeczypospolitej', 'polskiej'), 192),
#  (('rady', 'ministrów'), 192),
#  (('nie', 'może'), 186),
#  (('się', 'wyrazami'), 183),
#  (('wejścia', 'w'), 181),
#  (('zgodnie', 'z'), 178),
#  (('w', 'sprawie'), 178),
#  (('określone', 'w'), 176),
#  (('podlega', 'karze'), 174),
#  (('i', 'tryb'), 173),
#  (('się', 'art'), 166),
#  (('wprowadza', 'się'), 161),
#  (('karze', 'grzywny'), 161),
#  (('ministrem', 'właściwym'), 159),
#  (('się', 'następujące'), 151),
#  (('mogą', 'być'), 151),
#  (('minister', 'sprawiedliwości'), 150),
#  (('następujące', 'zmiany'), 149),
#  (('się', 'wyrazy'), 149),
#  (('szczegółowe', 'zasady'), 147),
#  (('w', 'trybie'), 144),
#  (('w', 'wysokości'), 144),
#  (('z', 'uwzględnieniem'), 144),
#  (('spraw', 'zdrowia'), 144),
#  (('samorządu', 'terytorialnego'), 143),
#  (('na', 'środowisko'), 143),
#  (('w', 'związku'), 140),
#  (('w', 'sposób'), 137),
#  (('po', 'upływie'), 136),
#  (('oraz', 'w'), 135),
#  (('właściwego', 'do'), 135),
#  (('ustawy', 'o'), 133),
#  (('w', 'okresie'), 133),
#  (('związku', 'z'), 133),
#  (('lub', 'w'), 132),
#  (('się', 'do'), 130),
#  (('prezes', 'rady'), 128),
#  (('przez', 'to'), 127),
#  (('wchodzi', 'w'), 126),
#  (('zastrzeżeniem', 'ust'), 125),
#  (('w', 'stosunku'), 124),
#  (('w', 'których'), 124),
#  (('spraw', 'gospodarki'), 124),
#  (('w', 'którym'), 123),
#  (('ochrony', 'państwa'), 123),
#  (('na', 'zasadach'), 123),
#  (('do', 'czasu'), 123),
#  (('w', 'rozumieniu'), 122),
#  (('określonym', 'w'), 121),
#  (('przepisów', 'o'), 120),
#  (('uwzględniając', 'w'), 119),
#  (('określonego', 'w'), 118),
#  (('nie', 'stosuje'), 118),
#  (('chyba', 'że'), 117),
#  (('z', 'wyjątkiem'), 117),
#  (('rada', 'ministrów'), 117),
#  (('z', 'zagranicą'), 117),
#  (('stosunku', 'do'), 114),
#  (('w', 'ciągu'), 114),
#  (('i', 'innych'), 113),
#  (('oraz', 'o'), 112),
#  (('ubezpieczeń', 'społecznych'), 111),
#  (('życie', 'ustawy'), 111),
#  (('administracji', 'publicznej'), 109),
#  (('się', 'na'), 108),
#  (('spraw', 'finansów'), 108),
#  (('w', 'czasie'), 106),
#  (('ministra', 'właściwego'), 106),
#  (('administracji', 'rządowej'), 106),
#  (('po', 'ust'), 104),
#  (('względu', 'na'), 104),
#  (('składek', 'na'), 103),
#  (('zasady', 'i'), 103),
#  (('skarbu', 'państwa'), 103),
#  (('finansów', 'publicznych'), 102),
#  (('jednostek', 'organizacyjnych'), 102),
#  (('zasięgnięciu', 'opinii'), 101),
#  (('i', 'w'), 100),
#  (('miesięcy', 'od'), 100),
#  (('o', 'zmianie'), 99),
#  (('minister', 'spraw'), 99),
#  (('ministrów', 'określi'), 99),
#  (('w', 'przepisach'), 98),
#  (('na', 'obszarze'), 98),
#  (('się', 'pkt'), 98),
#  (('wymienionych', 'w'), 97),
#  (('w', 'ramach'), 97),
#  (('po', 'zasięgnięciu'), 97),
#  (('ustawa', 'wchodzi'), 96),
#  (('na', 'czas'), 96),
#  (('w', 'postępowaniu'), 95),
#  (('oddziaływania', 'na'), 95),
#  (('przed', 'dniem'), 94),
#  (('działalności', 'gospodarczej'), 93),
#  (('pracy', 'w'), 92),
#  (('prawo', 'do'), 92),
#  (('i', 'art'), 92),
#  (('wraz', 'z'), 91),
#  (('z', 'zakresu'), 91),
#  (('obrony', 'narodowej'), 91),
#  (('spraw', 'środowiska'), 91),
#  (('informacji', 'o'), 90),
#  (('się', 'z'), 90),
#  (('rozumie', 'się'), 89),
#  (('pracy', 'i'), 88),
#  (('na', 'ubezpieczenie'), 88),
#  (('się', 'przez'), 88),
#  (('związanych', 'z'), 87),
#  (('stawek', 'dziennych'), 87),
#  (('w', 'wypadku'), 86),
#  (('jest', 'obowiązany'), 86),
#  (('niniejszej', 'ustawy'), 86),
#  (('jest', 'to'), 86),
#  (('po', 'art'), 85),
#  (('o', 'ochronie'), 84),
#  (('stają', 'się'), 83),
#  (('rozwoju', 'regionalnego'), 83),
#  (('krajowej', 'rady'), 83),
#  (('w', 'skład'), 82),
#  (('grzywny', 'do'), 82),
#  (('postępowania', 'w'), 81),
#  (('wykroczenie', 'skarbowe'), 81),
#  (('czynu', 'zabronionego'), 81),
#  (('zasadach', 'określonych'), 80),
#  (('i', 'ich'), 80),
#  (('w', 'dniu'), 80),
#  (('otrzymują', 'brzmienie'), 80),
#  (('i', 'sposób'), 80),
#  (('do', 'obrotu'), 80),
#  (('wniosku', 'o'), 79),
#  (('urzędu', 'ochrony'), 78),
#  (('ze', 'względu'), 77),
#  (('wymienione', 'w'), 76),
#  (('w', 'przypadkach'), 76),
#  (('nie', 'później'), 76),
#  (('na', 'ubezpieczenia'), 75),
#  (('stosunku', 'pracy'), 75),
#  (('straży', 'granicznej'), 75),
#  (('nie', 'jest'), 74),
#  (('w', 'tych'), 74),
#  (('życie', 'z'), 73),
#  (('czasu', 'pracy'), 73),
#  (('dnia', 'ogłoszenia'), 72),
#  (('budżetu', 'państwa'), 72),
#  (('w', 'formie'), 71),
#  (('podstawie', 'art'), 71),
#  (('przez', 'okres'), 71),
#  (('i', 'jego'), 71),
#  (('życie', 'po'), 70),
#  (('jednak', 'niż'), 70),
#  (('więcej', 'niż'), 70),
#  (('określony', 'w'), 70),
#  (('przepisów', 'ustawy'), 70),
#  (('przestępstwo', 'skarbowe'), 70),
#  (('związane', 'z'), 69),
#  (('rozumieniu', 'przepisów'), 69),
#  (('przez', 'ministra'), 69),
#  (('się', 'przepisy'), 69),
#  (('się', 'o'), 69),
#  (('przepisy', 'art'), 69),
#  (('oświaty', 'i'), 69),
#  (('składki', 'na'), 68),
#  (('podstawie', 'przepisów'), 68),
#  (('w', 'wodzie'), 68),
#  (('i', 'wychowania'), 68),
#  (('jeżeli', 'w'), 67),
#  (('ochrony', 'środowiska'), 67),
#  (('na', 'rzecz'), 66),
#  (('i', 'na'), 66),
#  (('dnia', 'wejścia'), 66),
#  (('po', 'wyrazach'), 65),
#  (('dłuższy', 'niż'), 65),
#  (('zmianie', 'ustawy'), 64),
#  (('pozbawienia', 'wolności'), 64),
#  (('z', 'art'), 64),
#  (('z', 'tym'), 64),
#  (('kodeksu', 'postępowania'), 64),
#  (('do', 'wykonywania'), 64),
#  (('zawartość', 'azotu'), 64),
#  (('później', 'niż'), 63),
#  (('w', 'roku'), 63),
#  (('przeliczeniu', 'na'), 63),
#  (('dniem', 'wejścia'), 63),
#  (('spraw', 'oświaty'), 63),
#  (('biegłych', 'rewidentów'), 63),
#  (('prawa', 'do'), 62),
#  (('postępowania', 'karnego'), 62),
#  (('oraz', 'tryb'), 61),
#  (('wniosek', 'o'), 61),
#  (('może', 'określić'), 61),
#  (('przepis', 'art'), 61),
#  (('wynikające', 'z'), 60),
#  (('odrębnych', 'przepisów'), 60),
#  (('zastrzeżeniem', 'art'), 60),
#  (('przepisy', 'ustawy'), 60),
#  (('sądu', 'apelacyjnego'), 60),
#  (('sprawach', 'o'), 60),
#  (('określonej', 'w'), 59),
#  (('do', 'ustawy'), 59),
#  (('zdrowia', 'określi'), 59),
#  (('zabronionego', 'określonego'), 59),
#  (('w', 'części'), 58),
#  (('na', 'okres'), 58),
#  (('oraz', 'ich'), 58),
#  (('za', 'granicą'), 57),
#  (('spraw', 'kultury'), 57),
#  (('przestępstwa', 'skarbowego'), 57),
#  (('przepisach', 'o'), 56),
#  (('oraz', 'innych'), 56),
#  (('oraz', 'art'), 56),
#  (('państwowej', 'straży'), 56),
#  (('odpowiednio', 'przepisy'), 56),
#  (('drodze', 'decyzji'), 56),
#  (('opieki', 'zdrowotnej'), 56),
#  (('roku', 'obrotowego'), 56),
#  (('za', 'wykroczenie'), 56),
#  (('do', 'pracy'), 55),
#  (('w', 'wyniku'), 55),
#  (('do', 'rejestru'), 55),
#  (('na', 'dzień'), 55),
#  (('lub', 'na'), 55),
#  (('warunki', 'i'), 55),
#  (('wynikających', 'z'), 54),
#  (('na', 'terenie'), 54),
#  (('krajowa', 'rada'), 54),
#  (('umowy', 'o'), 53),
#  (('odpowiednio', 'do'), 53),
#  (('co', 'do'), 53),
#  (('nadzór', 'nad'), 53),
#  (('z', 'działalności'), 53),
#  (('i', 'gospodarki'), 53),
#  (('odniesieniu', 'do'), 53),
#  (('oraz', 'sposób'), 53),
#  (('wymienionej', 'ustawy'), 53),
#  (('ustawy', 'zostały'), 53),
#  (('ogłoszone', 'w'), 53),
#  (('z', 'zagranicy'), 53),
#  (('przepisy', 'o'), 52),
#  (('służby', 'w'), 52),
#  (('podstawie', 'odrębnych'), 52),
#  (('ze', 'sprzedaży'), 52),
#  (('z', 'wyłączeniem'), 51),
#  (('w', 'dzienniku'), 51),
#  (('przez', 'niego'), 51),
#  (('towarów', 'i'), 51),
#  (('prezes', 'sądu'), 51),
#  (('sektora', 'publicznego'), 51),
#  (('grzywny', 'za'), 51),
#  (('w', 'całości'), 50),
#  (('trybie', 'określonym'), 50),
#  (('papierów', 'wartościowych'), 50),
#  (('z', 'późn'), 50),
#  (('informacji', 'sektora'), 50),
#  (('odpowiedzialności', 'zawodowej'), 50),
#  (('urzędnika', 'służby'), 50),
#  (('wyścigów', 'konnych'), 50),
#  (('oraz', 'zasady'), 49),
#  (('i', 'nie'), 49),
#  (('nie', 'dłuższy'), 49),
#  (('mając', 'na'), 49),
#  (('w', 'dz'), 49),
#  (('ponownego', 'wykorzystywania'), 49),
#  (('minister', 'obrony'), 49),
#  (('straży', 'pożarnej'), 48),
#  (('terytorium', 'rzeczypospolitej'), 48),
#  (('pracy', 'lub'), 48),
#  (('należności', 'z'), 48),
#  (('w', 'postaci'), 48),
#  (('może', 'nastąpić'), 48),
#  (('w', 'odniesieniu'), 48),
#  (('urzędu', 'pracy'), 48),
#  (('uważa', 'się'), 47),
#  (('następuje', 'w'), 47),
#  (('przepis', 'ust'), 47),
#  (('nie', 'dłużej'), 47),
#  (('zostały', 'ogłoszone'), 47),
#  (('wewnętrznych', 'i'), 47),
#  (('lub', 'jego'), 47),
#  (('sprawca', 'czynu'), 47),
#  (('minister', 'gospodarki'), 47),
#  (('i', 'administracji'), 46),
#  (('ze', 'środków'), 46),
#  (('do', 'sądu'), 46),
#  (('niż', 'do'), 46),
#  (('i', 'inne'), 46),
#  (('i', 'polityki'), 46),
#  (('się', 'wyrazem'), 46),
#  (('substancji', 'kontrolowanych'), 46),
#  (('z', 'powodu'), 45),
#  (('ubezpieczenia', 'emerytalne'), 45),
#  (('z', 'budżetu'), 45),
#  (('sprawozdań', 'finansowych'), 45),
#  (('pod', 'uwagę'), 45),
#  (('jednostki', 'samorządu'), 45),
#  (('w', 'jednostkach'), 45),
#  (('w', 'toku'), 45),
#  (('ustala', 'się'), 44),
#  (('przypadku', 'gdy'), 44),
#  (('nie', 'przekracza'), 44),
#  (('i', 'z'), 44),
#  (('przez', 'radę'), 44),
#  (('sądu', 'okręgowego'), 44),
#  (('państwa', 'lub'), 44),
#  (('polityki', 'socjalnej'), 44),
#  (('działań', 'ratowniczych'), 44),
#  (('ratownictwa', 'medycznego'), 44),
#  (('od', 'daty'), 43),
#  (('zabezpieczenia', 'społecznego'), 43),
#  (('informacje', 'o'), 43),
#  (('nie', 'można'), 43),
#  (('pracy', 'oraz'), 43),
#  (('tworzy', 'się'), 43),
#  (('się', 'przecinkiem'), 43),
#  (('to', 'rozumieć'), 43),
#  (('udział', 'w'), 43),
#  (('wykonywania', 'zawodu'), 43),
#  (('wewnętrznych', 'określi'), 43),
#  (('spraw', 'pracy'), 43),
#  (('i', 'dodaje'), 42),
#  (('wykonywania', 'zadań'), 42),
#  (('emerytalne', 'i'), 42),
#  (('właściwemu', 'do'), 42),
#  (('jeżeli', 'nie'), 42),
#  (('także', 'w'), 42),
#  (('niż', 'w'), 42),
#  (('na', 'piśmie'), 42),
#  (('przy', 'czym'), 42),
#  (('do', 'zadań'), 42),
#  (('osób', 'i'), 42),
#  (('na', 'stanowisko'), 42),
#  (('o', 'ile'), 42),
#  (('zezwolenie', 'na'), 42),
#  (('krajowej', 'izby'), 42),
#  (('sprawozdania', 'finansowego'), 42),
#  (('przestępstwa', 'skarbowe'), 42),
#  (('tryb', 'i'), 41),
#  (('na', 'terytorium'), 41),
#  (('dla', 'osób'), 41),
#  (('lub', 'innych'), 41),
#  (('z', 'wykonywaniem'), 41),
#  (('jednostek', 'samorządu'), 41),
#  (('do', 'którego'), 41),
#  (('o', 'wydanie'), 41),
#  (('medycznych', 'działań'), 41),
#  (('z', 'funduszu'), 40),
#  (('funduszu', 'pracy'), 40),
#  (('sposób', 'określony'), 40),
#  (('jednostki', 'organizacyjne'), 40),
#  (('do', 'ich'), 40),
#  (('należy', 'przez'), 40),
#  (('uchyla', 'się'), 40),
#  (('czas', 'określony'), 40),
#  (('ustawę', 'z'), 40),
#  (('kultury', 'i'), 40),
#  (('do', 'służby'), 40),
#  (('nawóz', 'otrzymywany'), 40),
#  (('się', 'jako'), 39),
#  (('terminie', 'do'), 39),
#  (('dzienniku', 'urzędowym'), 39),
#  (('tej', 'samej'), 39),
#  (('w', 'przeliczeniu'), 39),
#  (('z', 'mocy'), 39),
#  (('decyzji', 'o'), 39),
#  (('w', 'województwie'), 39),
#  (('spraw', 'administracji'), 39),
#  (('opłat', 'za'), 39),
#  (('lub', 'z'), 39),
#  (('drodze', 'zarządzenia'), 39),
#  (('rozpuszczalnego', 'w'), 39),
#  (('na', 'uszczuplenie'), 39),
#  (('oznacza', 'się'), 38),
#  (('oraz', 'inne'), 38),
#  (('spraw', 'zabezpieczenia'), 38),
#  (('stanowią', 'inaczej'), 38),
#  (('o', 'zasadach'), 38),
#  (('wyłącznie', 'w'), 38),
#  (('nie', 'mogą'), 38),
#  (('spraw', 'rolnictwa'), 38),
#  (('lat', 'od'), 38),
#  (('do', 'lat'), 38),
#  (('środka', 'ochronnego'), 38),
#  (('podstawie', 'umowy'), 37),
#  (('i', 'rentowe'), 37),
#  (('w', 'danym'), 37),
#  (('tym', 'że'), 37),
#  (('korzystania', 'z'), 37),
#  (('tryb', 'postępowania'), 37),
#  (('w', 'odrębnych'), 37),
#  (('oraz', 'na'), 37),
#  (('uprawnione', 'do'), 37),
#  (('i', 'ochrony'), 37),
#  (('karze', 'pozbawienia'), 37),
#  (('wolności', 'do'), 37),
#  (('w', 'obrocie'), 37),
#  (('ksiąg', 'rachunkowych'), 37),
#  (('płatnika', 'składek'), 36),
#  (('ubezpieczenie', 'społeczne'), 36),
#  (('podstawie', 'ustawy'), 36),
#  (('o', 'pracę'), 36),
#  (('określona', 'w'), 36),
#  (('do', 'prowadzenia'), 36),
#  (('nadzoru', 'nad'), 36),
#  (('nie', 'przysługuje'), 36),
#  (('wykonywania', 'czynności'), 36),
#  (('mocy', 'prawa'), 36),
#  (('sposób', 'i'), 36),
#  (('zakres', 'i'), 36),
#  (('uprawnionych', 'do'), 36),
#  (('do', 'pełnienia'), 36),
#  (('lub', 'innej'), 36),
#  (('zmienianej', 'w'), 36),
#  (('i', 'straży'), 36),
#  (('życia', 'lub'), 36),
#  (('załączniku', 'nr'), 36),
#  (('sąd', 'może'), 36),
#  (('wykroczenia', 'skarbowe'), 36),
#  (('lekarza', 'weterynarii'), 36),
#  (('w', 'służbie'), 35),
#  (('służby', 'wojskowej'), 35),
#  (('od', 'osób'), 35),
#  (('o', 'tym'), 35),
#  (('z', 'wnioskiem'), 35),
#  (('z', 'przyczyn'), 35),
#  (('przez', 'prezesa'), 35),
#  (('niniejszą', 'ustawą'), 35),
#  (('do', 'informacji'), 35),
#  (('na', 'ich'), 35),
#  (('nie', 'są'), 35),
#  (('skarb', 'państwa'), 35),
#  (('udziału', 'w'), 35),
#  (('zatrudnionych', 'w'), 35),
#  (('obszarze', 'województwa'), 35),
#  (('i', 'warunki'), 35),
#  (('przez', 'organy'), 35),
#  (('życie', 'niniejszej'), 35),
#  (('postępowanie', 'w'), 35),
#  (('tekstu', 'jednolitego'), 35),
#  (('i', 'budownictwa'), 35),
#  (('w', 'załączniku'), 35),
#  (('na', 'listę'), 35),
#  (('państwowej', 'inspekcji'), 35),
#  (('rolnictwa', 'i'), 35),
#  (('architektury', 'i'), 35),
#  (('i', 'mienia'), 35),
#  (('w', 'innych'), 34),
#  (('podstawy', 'wymiaru'), 34),
#  (('okres', 'nie'), 34),
#  (('przepisy', 'ust'), 34),
#  (('ma', 'prawo'), 34),
#  (('fundusz', 'pracy'), 34),
#  (('zawartych', 'w'), 34),
#  (('państwa', 'oraz'), 34),
#  (('nie', 'dotyczy'), 34),
#  (('które', 'mogą'), 34),
#  (('przepisy', 'kodeksu'), 34),
#  (('ponowne', 'wykorzystywanie'), 34),
#  (('lub', 'zdrowia'), 34),
#  (('krajowej', 'komisji'), 34),
#  (('polski', 'obszar'), 34),
#  (('opłaty', 'skarbowej'), 34),
#  (('izby', 'komorniczej'), 34),
#  (('wykroczenia', 'skarbowego'), 34),
#  (('spraw', 'architektury'), 34),
#  (('przeciętnego', 'wynagrodzenia'), 33),
#  (('ministrowi', 'właściwemu'), 33),
#  (('i', 'ust'), 33),
#  (('osób', 'prawnych'), 33),
#  (('się', 'za'), 33),
#  (('z', 'przepisami'), 33),
#  (('zalicza', 'się'), 33),
#  (('i', 'usług'), 33),
#  (('sprawozdanie', 'finansowe'), 33),
#  (('przez', 'osoby'), 33),
#  (('bezpieczeństwa', 'państwa'), 33),
#  (('szczegółowe', 'warunki'), 33),
#  (('sposób', 'prowadzenia'), 33),
#  (('lub', 'innego'), 33),
#  (('obszar', 'celny'), 33),
#  (('gospodarki', 'żywnościowej'), 33),
#  (('o', 'systemie'), 32),
#  (('osób', 'fizycznych'), 32),
#  (('jak', 'również'), 32),
#  (('stosunek', 'pracy'), 32),
#  (('pracy', 'z'), 32),
#  (('dłużej', 'jednak'), 32),
#  (('niezbędne', 'do'), 32),
#  (('w', 'kraju'), 32),
#  (('są', 'obowiązane'), 32),
#  (('kropkę', 'zastępuje'), 32),
#  (('za', 'rok'), 32),
#  (('oraz', 'ministrem'), 32),
#  (('sprawiedliwości', 'może'), 32),
#  (('ustawy', 'zmienianej'), 32),
#  (('przepisów', 'prawa'), 32),
#  (('i', 'strat'), 32),
#  (('komisji', 'egzaminacyjnej'), 32),
#  (('sprawiedliwości', 'określi'), 32),
#  (('inspekcji', 'i'), 32),
#  (('rady', 'powiatu'), 32),
#  (('nadzoru', 'budowlanego'), 32),
#  (('jeżeli', 'kwota'), 32),
#  (('czyn', 'zabroniony'), 32),
#  (('organ', 'dochodzenia'), 32),
#  (('ubezpieczenia', 'społeczne'), 31),
#  (('użyte', 'w'), 31),
#  (('nie', 'ma'), 31),
#  (('do', 'zasiłku'), 31),
#  (('za', 'okres'), 31),
#  (('osób', 'niepełnosprawnych'), 31),
#  (('lub', 'ich'), 31),
#  (('na', 'jego'), 31),
#  (('realizacji', 'zadań'), 31),
#  (('danych', 'osobowych'), 31),
#  (('z', 'urzędu'), 31),
#  (('z', 'zachowaniem'), 31),
#  (('oraz', 'zakres'), 31),
#  (('przecinkiem', 'i'), 31),
#  (('na', 'prawach'), 31),
#  (('środowiska', 'i'), 31),
#  (('gospodarki', 'wodnej'), 31),
#  (('powinny', 'być'), 31),
#  (('w', 'tej'), 31),
#  (('inne', 'niż'), 31),
#  (('nie', 'więcej'), 31),
#  (('postępowaniu', 'w'), 31),
#  (('jednolitego', 'wymienionej'), 31),
#  (('w', 'wypadkach'), 31),
#  (('na', 'polski'), 31),
#  (('azot', 'z'), 31),
#  (('izby', 'psychologów'), 31),
#  (('w', 'miastach'), 31),
#  (('powiadamiania', 'ratunkowego'), 31),
#  (('środki', 'pieniężne'), 30),
#  (('przy', 'wykonywaniu'), 30),
#  (('wymiaru', 'składek'), 30),
#  (('wnioskiem', 'o'), 30),
#  (('przewidzianych', 'w'), 30),
#  (('informację', 'o'), 30),
#  (('biegłego', 'rewidenta'), 30),
#  (('właściwego', 'sądu'), 30),
#  (('tych', 'sprawach'), 30),
#  (('samej', 'karze'), 30),
#  (('karze', 'podlega'), 30),
#  (('po', 'wyrazie'), 30),
#  (('ich', 'rodzin'), 30),
#  (('organów', 'administracji'), 30),
#  (('o', 'samorządzie'), 30),
#  (('spraw', 'rozwoju'), 30),
#  (('na', 'celu'), 30),
#  (('spraw', 'referendum'), 30),
#  (('zezwolenia', 'na'), 30),
#  (('komendant', 'główny'), 30),
#  (('pełnienia', 'służby'), 30),
#  (('rada', 'powiatu'), 30),
#  (('prawa', 'miejscowego'), 30),
#  (('w', 'szkole'), 30),
#  (('odpowiedzialności', 'posiłkowej'), 30),
#  (('obrotu', 'specjalnego'), 30),
#  (('wynagrodzenia', 'miesięcznego'), 29),
#  (('środków', 'pieniężnych'), 29),
#  (('o', 'podatku'), 29),
#  (('uzgodnieniu', 'z'), 29),
#  (('z', 'tych'), 29),
#  (('dokonuje', 'się'), 29),
#  (('odwołanie', 'do'), 29),
#  (('o', 'udzielenie'), 29),
#  (('wpisu', 'do'), 29),
#  (('umów', 'międzynarodowych'), 29),
#  (('rok', 'obrotowy'), 29),
#  (('na', 'żądanie'), 29),
#  (('lub', 'nie'), 29),
#  (('kontroli', 'zakładu'), 29),
#  (('się', 'od'), 29),
#  (('po', 'uzyskaniu'), 29),
#  (('prawach', 'powiatu'), 29),
#  (('dnia', 'otrzymania'), 29),
#  (('sił', 'zbrojnych'), 29),
#  (('do', 'głosowania'), 29),
#  (('może', 'przekroczyć'), 29),
#  (('wynagrodzenia', 'zasadniczego'), 29),
#  (('wydanych', 'na'), 29),
#  (('czynności', 'operacyjno'), 29),
#  (('oraz', 'szczegółowe'), 29),
#  (('sprawie', 'oceny'), 29),
#  (('organy', 'administracji'), 29),
#  (('przedsięwzięcia', 'na'), 29),
#  (('przez', 'organ'), 29),
#  (('pozwolenia', 'na'), 29),
#  (('zysków', 'i'), 29),
#  (('regionalnej', 'izby'), 29),
#  (('skarbowego', 'lub'), 29),
#  (('innej', 'pracy'), 29),
#  (('sprawie', 'o'), 29),
#  (('pracy', 'na'), 28),
#  (('jako', 'ust'), 28),
#  (('urząd', 'pracy'), 28),
#  (('z', 'nimi'), 28),
#  (('dniu', 'wejścia'), 28),
#  (('przez', 'zakład'), 28),
#  (('o', 'postępowaniu'), 28),
#  (('z', 'przepisów'), 28),
#  (('w', 'której'), 28),
#  (('w', 'stanie'), 28),
#  (('wyniku', 'finansowego'), 28),
#  (('z', 'jego'), 28),
#  (('określonymi', 'w'), 28),
#  (('obowiązany', 'jest'), 28),
#  (('wymienionej', 'w'), 28),
#  (('wchodzą', 'w'), 28),
#  (('wspierania', 'rozwoju'), 28),
#  (('polega', 'na'), 28),
#  (('zmianie', 'niektórych'), 28),
#  (('i', 'telewizji'), 28),
#  (('na', 'względzie'), 28),
#  (('przeznaczone', 'do'), 28),
#  (('podmiot', 'zobowiązany'), 28),
#  (('za', 'granicę'), 28),
#  (('oceny', 'oddziaływania'), 28),
#  (('lub', 'inne'), 28),
#  (('składników', 'majątku'), 28),
#  (('papiery', 'wartościowe'), 28),
#  (('służbie', 'cywilnej'), 28),
#  (('urzędnik', 'służby'), 28),
#  (('przepadku', 'przedmiotów'), 28),
#  (('fizycznej', 'i'), 28),
#  (('inspekcji', 'weterynaryjnej'), 28),
#  (('ochrony', 'osób'), 28),
#  (('organizacji', 'i'), 27),
#  (('ze', 'służby'), 27),
#  (('albo', 'w'), 27),
#  (('na', 'poczet'), 27),
#  (('całości', 'lub'), 27),
#  (('jeżeli', 'jest'), 27),
#  (('przyznawania', 'i'), 27),
#  (('innych', 'niż'), 27),
#  (('w', 'miejscu'), 27),
#  (('spraw', 'transportu'), 27),
#  (('ochrony', 'dziedzictwa'), 27),
#  (('subwencji', 'ogólnej'), 27),
#  (('na', 'końcu'), 27),
#  (('biorąc', 'pod'), 27),
#  (('szefa', 'urzędu'), 27),
#  (('organ', 'administracji'), 27),
#  (('zdrowia', 'ludzi'), 27),
#  (('w', 'procesie'), 27),
#  (('postępowania', 'ochronnego'), 27),
#  (('dnia', 'doręczenia'), 27),
#  (('krajowy', 'zjazd'), 27),
#  (('ograniczenia', 'wolności'), 27),
#  (('środków', 'trwałych'), 27),
#  (('albo', 'obu'), 27),
#  (('obu', 'tym'), 27),
#  (('tym', 'karom'), 27),
#  (('karom', 'łącznie'), 27),
#  (('albo', 'karze'), 27),
#  (('szef', 'służby'), 27),
#  (('lub', 'wykroczenia'), 27),
#  (('kary', 'grzywny'), 27),
#  (('specjalnego', 'z'), 27),
#  (('płatnik', 'składek'), 26),
#  (('do', 'osób'), 26),
#  (('głównego', 'urzędu'), 26),
#  (('do', 'tego'), 26),
#  (('miesiąca', 'od'), 26),
#  (('przy', 'użyciu'), 26),
#  (('jest', 'w'), 26),
#  (('ministrów', 'określa'), 26),
#  (('w', 'granicach'), 26),
#  (('i', 'odwołuje'), 26),
#  (('prezesa', 'rady'), 26),
#  (('obowiązany', 'do'), 26),
#  (('do', 'wydania'), 26),
#  (('w', 'wymiarze'), 26),
#  (('samorządu', 'województwa'), 26),
#  (('zwany', 'dalej'), 26),
#  (('na', 'rok'), 26),
#  (('innych', 'jednostek'), 26),
#  (('może', 'w'), 26),
#  (('o', 'przestępstwa'), 26),
#  (('właściwego', 'organu'), 26),
#  (('które', 'nie'), 26),
#  (('zgody', 'na'), 26),
#  (('ministra', 'spraw'), 26),
#  (('kodeksu', 'karnego'), 26),
#  (('broni', 'palnej'), 26),
#  (('postępowania', 'kwalifikacyjnego'), 26),
#  (('środowisku', 'i'), 26),
#  (('postępowania', 'z'), 26),
#  (('wymagania', 'dotyczące'), 26),
#  (('rozpuszczalny', 'w'), 26),
#  (('szkolnictwa', 'wyższego'), 26),
#  (('samorządu', 'zawodowego'), 26),
#  (('właściwej', 'izby'), 26),
#  (('może', 'przekraczać'), 26),
#  (('spółki', 'celowej'), 26),
#  (('pracy', 'zarobkowej'), 26),
#  (('należności', 'publicznoprawnej'), 26),
#  (('minister', 'rolnictwa'), 26),
#  (('substancje', 'kontrolowane'), 26),
#  (('zgodę', 'na'), 25),
#  (('dotychczasową', 'treść'), 25),
#  (('treść', 'oznacza'), 25),
#  (('przepisy', 'ogólne'), 25),
#  (('po', 'dniu'), 25),
#  (('uzasadnionych', 'przypadkach'), 25),
#  (('kontroli', 'skarbowej'), 25),
#  (('należy', 'w'), 25),
#  (('tym', 'zakresie'), 25),
#  (('w', 'czynnościach'), 25),
#  (('za', 'przestępstwo'), 25),
#  (('odrębnych', 'przepisach'), 25),
#  (('prawo', 'o'), 25),
#  (('wydaje', 'się'), 25),
#  (('świadectw', 'rekompensacyjnych'), 25),
#  (('złożenia', 'wniosku'), 25),
#  (('z', 'nich'), 25),
#  (('postępowania', 'administracyjnego'), 25),
#  (('następuje', 'na'), 25),
#  (('przestrzennej', 'i'), 25),
#  (('spraw', 'zagranicznych'), 25),
#  (('sposób', 'postępowania'), 25),
#  (('spraw', 'szkolnictwa'), 25),
#  (('pod', 'warunkiem'), 25),
#  (('przez', 'jednostkę'), 25),
#  (('uwzględnieniem', 'w'), 25),
#  (('godzin', 'na'), 25),
#  (('oznacza', 'to'), 25),
#  (('skarbowe', 'i'), 25),
#  (('lekarz', 'weterynarii'), 25),
#  (('kultury', 'fizycznej'), 25),
#  (('substancji', 'kontrolowanej'), 25),
#  (('z', 'tego'), 24),
#  (('się', 'także'), 24),
#  (('najniższego', 'wynagrodzenia'), 24),
#  (('wyższa', 'niż'), 24),
#  (('ustawy', 'nie'), 24),
#  (('monitor', 'polski'), 24),
#  (('tylko', 'w'), 24),
#  (('na', 'fundusz'), 24),
#  (('przypadkach', 'określonych'), 24),
#  (('na', 'koniec'), 24),
#  (('lub', 'do'), 24),
#  (('jednostki', 'organizacyjnej'), 24),
#  (('za', 'zgodą'), 24),
#  (('zadań', 'i'), 24),
#  (('w', 'języku'), 24),
#  (('sporządza', 'się'), 24),
#  (('warunków', 'określonych'), 24),
#  (('przez', 'te'), 24),
#  (('do', 'których'), 24),
#  (('zdanie', 'drugie'), 24),
#  (('nie', 'stanowią'), 24),
#  (('sądu', 'najwyższego'), 24),
#  (('unii', 'europejskiej'), 24),
#  (('sądu', 'rejonowego'), 24),
#  (('ministrowi', 'sprawiedliwości'), 24),
#  (('okręgowej', 'izby'), 24),
#  (('niezależnie', 'od'), 24),
#  (('dostępie', 'do'), 24),
#  (('opłaty', 'za'), 24),
#  (('prawa', 'i'), 24),
#  (('szkoły', 'lub'), 24),
#  (('jego', 'ochronie'), 24),
#  (('tym', 'również'), 24),
#  (('organ', 'prowadzący'), 24),
#  (('rada', 'izby'), 24),
#  (('do', 'badania'), 24),
#  (('do', 'lokalu'), 24),
#  (('jednostek', 'zależnych'), 24),
#  (('świadczeń', 'zdrowotnych'), 24),
#  (('do', 'spożycia'), 24),
#  (('nadzór', 'pedagogiczny'), 24),
#  (('dziennych', 'albo'), 24),
#  (('w', 'rzeszowie'), 24),
#  (('narodowej', 'określi'), 24),
#  (('zakładu', 'ubezpieczeń'), 23),
#  (('odrębne', 'przepisy'), 23),
#  (('o', 'osobie'), 23),
#  (('działalność', 'gospodarczą'), 23),
#  (('o', 'działalności'), 23),
#  (('w', 'dziedzinie'), 23),
#  (('z', 'innych'), 23),
#  (('na', 'raty'), 23),
#  (('należy', 'do'), 23),
#  (('zakresu', 'działania'), 23),
#  (('postępowania', 'cywilnego'), 23),
#  (('przez', 'osobę'), 23),
#  (('wydania', 'decyzji'), 23),
#  (('uprawnienia', 'do'), 23),
#  (('w', 'imieniu'), 23),
#  (('po', 'pkt'), 23),
#  (('stanowi', 'inaczej'), 23),
#  (('zakresu', 'administracji'), 23),
#  (('działających', 'na'), 23),
#  (('i', 'zakres'), 23),
#  (('ministrów', 'może'), 23),
#  (('oraz', 'jego'), 23),
#  (('do', 'sejmu'), 23),
#  (('dniem', 'ogłoszenia'), 23),
#  (('radiofonii', 'i'), 23),
#  (('minister', 'pracy'), 23),
#  (('oraz', 'warunki'), 23),
#  (('o', 'charakterze'), 23),
#  (('o', 'dostępie'), 23),
#  (('obowiązane', 'do'), 23),
#  (('oraz', 'do'), 23),
#  (('jego', 'zastępców'), 23),
#  (('w', 'wyznaczonym'), 23),
#  (('zdrowia', 'i'), 23),
#  (('dla', 'życia'), 23),
#  (('i', 'obowiązki'), 23),
#  (('bez', 'wymaganego'), 23),
#  (('o', 'środowisku'), 23),
#  (('ich', 'części'), 23),
#  (('pozwolenie', 'na'), 23),
#  (('w', 'rzeczypospolitej'), 23),
#  (('w', 'księgach'), 23),
#  (('zadania', 'i'), 23),
#  (('księgach', 'rachunkowych'), 23),
#  (('i', 'pasywów'), 23),
#  (('dzień', 'bilansowy'), 23),
#  (('tych', 'jednostek'), 23),
#  (('urzędników', 'służby'), 23),
#  (('powiatu', 'i'), 23),
#  (('równowartości', 'pieniężnej'), 23),
#  (('witolda', 'pileckiego'), 23),
#  (('centrum', 'powiadamiania'), 23),
#  (('do', 'której'), 22),
#  (('zwane', 'dalej'), 22),
#  (('ustawa', 'określa'), 22),
#  (('zatrudnieni', 'w'), 22),
#  (('oraz', 'osoby'), 22),
#  (('pozostających', 'w'), 22),
#  (('łącznie', 'z'), 22),
#  (('pobiera', 'się'), 22),
#  (('za', 'pośrednictwem'), 22),
#  (('od', 'decyzji'), 22),
#  (('do', 'tych'), 22),
#  (('dane', 'o'), 22),
#  (('rodzaj', 'i'), 22),
#  (('prowadzenia', 'działalności'), 22),
#  (('do', 'zakresu'), 22),
#  (('powołuje', 'i'), 22),
#  (('rady', 'nadzorczej'), 22),
#  (('państwa', 'w'), 22),
#  (('wyznaczonym', 'terminie'), 22),
#  (('rozumieniu', 'ustawy'), 22),
#  (('czasu', 'powołania'), 22),
#  (('przeprowadza', 'się'), 22),
#  (('z', 'upływem'), 22),
#  (('toku', 'postępowania'), 22),
#  (('zmiany', 'tekstu'), 22),
#  (('do', 'celów'), 22),
#  (('decyzja', 'o'), 22),
#  (('w', 'urzędzie'), 22),
#  (('do', 'postępowania'), 22),
#  (('wyjątkiem', 'art'), 22),
#  (('publicznego', 'w'), 22),
#  (('dziedzictwa', 'narodowego'), 22),
#  (('główny', 'policji'), 22),
#  (('postępowania', 'dyscyplinarnego'), 22),
#  (('i', 'materiałów'), 22),
#  (('członków', 'komisji'), 22),
#  (('y', 'w'), 22),
#  (('w', 'kolumnie'), 22),
#  (('szkół', 'i'), 22),
#  (('egzaminu', 'konkursowego'), 22),
#  (('księgi', 'rachunkowe'), 22),
#  (('aktywów', 'i'), 22),
#  (('załącznik', 'nr'), 22),
#  (('nauczyciela', 'mianowanego'), 22),
#  (('finansowy', 'organ'), 22),
#  (('zakładu', 'pracy'), 21),
#  (('należności', 'i'), 21),
#  (('kodeksu', 'pracy'), 21),
#  (('uprawnień', 'do'), 21),
#  (('na', 'dokonanie'), 21),
#  (('zadań', 'z'), 21),
#  (('tytułu', 'składek'), 21),
#  (('miesięcznego', 'wynagrodzenia'), 21),
#  (('odpowiednio', 'w'), 21),
#  (('w', 'trakcie'), 21),
#  (('przy', 'ustalaniu'), 21),
#  (('do', 'końca'), 21),
#  (('szczegółowy', 'zakres'), 21),
#  (('zawarcia', 'umowy'), 21),
#  (('zawarte', 'w'), 21),
#  (('państwa', 'i'), 21),
#  (('składa', 'się'), 21),
#  (('prowadzonych', 'przez'), 21),
#  (('roku', 'od'), 21),
#  (('się', 'zdanie'), 21),
#  (('przepisów', 'art'), 21),
#  (('wydane', 'na'), 21),
#  (('który', 'wchodzi'), 21),
#  (('na', 'miejsce'), 21),
#  (('członka', 'rady'), 21),
#  (('w', 'programie'), 21),
#  (('do', 'wniosku'), 21),
#  (('albo', 'na'), 21),
#  (('okresie', 'od'), 21),
#  (('naczelnego', 'sądu'), 21),
#  (('o', 'przestępstwo'), 21),
#  (('innych', 'osób'), 21),
#  (('minister', 'finansów'), 21),
#  (('w', 'pełnym'), 21),
#  (('pełnym', 'wymiarze'), 21),
#  (('dnia', 'złożenia'), 21),
#  (('organizację', 'i'), 21),
#  (('w', 'różnych'), 21),
#  (('do', 'stosowania'), 21),
#  (('zasobów', 'naturalnych'), 21),
#  (('oddziaływać', 'na'), 21),
#  (('na', 'których'), 21),
#  (('dla', 'środowiska'), 21),
#  (('prawo', 'budowlane'), 21),
#  (('wbrew', 'obowiązkowi'), 21),
#  (('komisji', 'dyscyplinarnej'), 21),
#  (('w', 'organach'), 21),
#  (('asesora', 'komorniczego'), 21),
#  (('wynik', 'finansowy'), 21),
#  (('zmiana', 'stanu'), 21),
#  (('urzędu', 'wojewódzkiego'), 21),
#  (('rejonowy', 'urząd'), 21),
#  (('stopień', 'nauczyciela'), 21),
#  (('lokalu', 'mieszkalnego'), 21),
#  (('i', 'wykroczenia'), 21),
#  (('przekracza', 'ustawowego'), 21),
#  (('prowadzenia', 'pojazdu'), 21),
#  (('i', 'sportu'), 21),
#  (('protokołu', 'montrealskiego'), 21),
#  (('grupa', 'ii'), 21),
#  (('który', 'nie'), 20),
#  (('nie', 'stanowi'), 20),
#  (('prezydenta', 'rzeczypospolitej'), 20),
#  (('tryb', 'ich'), 20),
#  (('zadania', 'z'), 20),
#  (('do', 'świadczeń'), 20),
#  (('określa', 'się'), 20),
#  (('w', 'uzasadnionych'), 20),
#  (('niezdolności', 'do'), 20),
#  (('są', 'w'), 20),
#  ...]

# %%
tokens_count = Counter(tokens)

# %%
valid_tokens = Counter({
    t: count for t, count in tokens_count.items() if token_valid(t)
})

# %%
valid_tokens.most_common()
# Out:
# [('w', 201201),
#  ('i', 90006),
#  ('art', 83804),
#  ('z', 82438),
#  ('o', 64776),
#  ('do', 60732),
#  ('ust', 53636),
#  ('na', 50643),
#  ('się', 45886),
#  ('lub', 45800),
#  ('poz', 45224),
#  ('nr', 44942),
#  ('oraz', 33558),
#  ('r', 33172),
#  ('mowa', 28783),
#  ('nie', 22988),
#  ('przez', 20951),
#  ('pkt', 19124),
#  ('dnia', 17954),
#  ('których', 17934),
#  ('a', 16969),
#  ('od', 16683),
#  ('po', 13546),
#  ('jest', 13197),
#  ('ustawy', 13099),
#  ('może', 12096),
#  ('jeżeli', 12038),
#  ('którym', 11790),
#  ('za', 11142),
#  ('brzmienie', 10576),
#  ('spraw', 10021),
#  ('otrzymuje', 9835),
#  ('albo', 8708),
#  ('dodaje', 8423),
#  ('ich', 8199),
#  ('dla', 7934),
#  ('pracy', 7631),
#  ('minister', 7578),
#  ('której', 7477),
#  ('brzmieniu', 7296),
#  ('drodze', 7179),
#  ('podstawie', 6852),
#  ('b', 6840),
#  ('stosuje', 6680),
#  ('przypadku', 6503),
#  ('niż', 6452),
#  ('tym', 6366),
#  ('jego', 6320),
#  ('są', 6156),
#  ('być', 6120),
#  ('zakresie', 6101),
#  ('właściwy', 6094),
#  ('państwa', 5840),
#  ('przepisy', 5838),
#  ('wyrazy', 5817),
#  ('ze', 5509),
#  ('ustawie', 5479),
#  ('także', 5445),
#  ('przepisów', 5347),
#  ('rozporządzenia', 5346),
#  ('tych', 5048),
#  ('określonych', 5046),
#  ('postępowania', 4909),
#  ('osób', 4904),
#  ('terminie', 4827),
#  ('zastępuje', 4818),
#  ('działalności', 4742),
#  ('przed', 4697),
#  ('ochrony', 4607),
#  ('osoby', 4599),
#  ('wniosek', 4596),
#  ('innych', 4593),
#  ('że', 4587),
#  ('urzędu', 4551),
#  ('sposób', 4538),
#  ('odpowiednio', 4452),
#  ('prawa', 4424),
#  ('życie', 4400),
#  ('środków', 4225),
#  ('które', 4105),
#  ('czynności', 4044),
#  ('rady', 4042),
#  ('polskiej', 4019),
#  ('zmiany', 4016),
#  ('tego', 4016),
#  ('prawo', 4015),
#  ('roku', 3966),
#  ('mogą', 3927),
#  ('informacji', 3851),
#  ('służby', 3847),
#  ('organ', 3833),
#  ('dni', 3767),
#  ('to', 3704),
#  ('jej', 3703),
#  ('przy', 3694),
#  ('określi', 3595),
#  ('rzeczypospolitej', 3567),
#  ('co', 3493),
#  ('szczególności', 3474),
#  ('dniem', 3466),
#  ('umowy', 3465),
#  ('decyzji', 3386),
#  ('u', 3380),
#  ('jednostki', 3379),
#  ('celu', 3376),
#  ('wysokości', 3368),
#  ('środowiska', 3335),
#  ('c', 3243),
#  ('ustawa', 3235),
#  ('kontroli', 3204),
#  ('wyrazami', 3158),
#  ('razie', 3150),
#  ('sądu', 3145),
#  ('lat', 3112),
#  ('który', 3082),
#  ('właściwego', 3076),
#  ('warunki', 3035),
#  ('sąd', 3002),
#  ('administracji', 2943),
#  ('tej', 2942),
#  ('tytułu', 2915),
#  ('okres', 2898),
#  ('dz', 2891),
#  ('gdy', 2878),
#  ('wykonywania', 2875),
#  ('komisji', 2862),
#  ('zasady', 2810),
#  ('zadań', 2801),
#  ('publicznych', 2797),
#  ('sprawach', 2792),
#  ('skreśla', 2736),
#  ('ministra', 2713),
#  ('podlega', 2701),
#  ('funduszu', 2679),
#  ('zdrowia', 2676),
#  ('inne', 2671),
#  ('miesięcy', 2640),
#  ('spółki', 2640),
#  ('zgodnie', 2609),
#  ('obrotu', 2606),
#  ('również', 2586),
#  ('gospodarki', 2582),
#  ('danych', 2549),
#  ('określone', 2534),
#  ('części', 2498),
#  ('prezes', 2495),
#  ('tryb', 2480),
#  ('rozdział', 2469),
#  ('wejścia', 2454),
#  ('najmniej', 2446),
#  ('zastrzeżeniem', 2441),
#  ('ministrów', 2425),
#  ('jednostek', 2413),
#  ('bez', 2394),
#  ('przepisach', 2380),
#  ('przysługuje', 2337),
#  ('wartości', 2316),
#  ('następujące', 2276),
#  ('określa', 2271),
#  ('wniosku', 2252),
#  ('sprawie', 2203),
#  ('związku', 2169),
#  ('stosunku', 2146),
#  ('którego', 2128),
#  ('działalność', 2128),
#  ('zostały', 2126),
#  ('należy', 2120),
#  ('grudnia', 2117),
#  ('finansów', 2112),
#  ('pomocy', 2103),
#  ('obowiązany', 2099),
#  ('kwoty', 2058),
#  ('podatku', 2048),
#  ('prowadzenia', 2043),
#  ('zezwolenia', 2035),
#  ('wysokość', 2002),
#  ('wprowadza', 1999),
#  ('rada', 1997),
#  ('samorządu', 1978),
#  ('ma', 1971),
#  ('ministrem', 1971),
#  ('rejestru', 1943),
#  ('lit', 1938),
#  ('informacje', 1937),
#  ('towarów', 1920),
#  ('zł', 1915),
#  ('świadczeń', 1908),
#  ('stycznia', 1894),
#  ('zasadach', 1886),
#  ('kosztów', 1884),
#  ('dane', 1884),
#  ('czasu', 1881),
#  ('właściwym', 1874),
#  ('wolności', 1872),
#  ('prezesa', 1867),
#  ('terytorium', 1865),
#  ('pod', 1849),
#  ('środki', 1848),
#  ('należności', 1845),
#  ('ogłoszenia', 1838),
#  ('osoba', 1825),
#  ('członków', 1822),
#  ('publicznej', 1820),
#  ('jako', 1814),
#  ('porozumieniu', 1800),
#  ('produktów', 1792),
#  ('warunków', 1791),
#  ('rozumieniu', 1789),
#  ('okresie', 1781),
#  ('działania', 1780),
#  ('te', 1774),
#  ('wynagrodzenia', 1772),
#  ('organy', 1767),
#  ('wydania', 1752),
#  ('organu', 1746),
#  ('dotyczące', 1742),
#  ('podmiot', 1737),
#  ('opinii', 1718),
#  ('terytorialnego', 1710),
#  ('przypadkach', 1705),
#  ('zwierząt', 1702),
#  ('dniu', 1701),
#  ('wewnętrznych', 1700),
#  ('zakres', 1691),
#  ('pracowników', 1688),
#  ('opieki', 1688),
#  ('województwa', 1679),
#  ('ubezpieczeń', 1678),
#  ('upływie', 1674),
#  ('wyjątkiem', 1670),
#  ('odpadów', 1656),
#  ('d', 1655),
#  ('przepis', 1652),
#  ('niniejszej', 1652),
#  ('postępowanie', 1651),
#  ('nadzoru', 1650),
#  ('bezpieczeństwa', 1650),
#  ('organów', 1648),
#  ('straży', 1647),
#  ('organizacji', 1644),
#  ('państwowej', 1640),
#  ('usług', 1629),
#  ('nieruchomości', 1622),
#  ('postępowaniu', 1613),
#  ('określonym', 1606),
#  ('budżetu', 1606),
#  ('kodeksu', 1603),
#  ('nad', 1589),
#  ('karze', 1588),
#  ('według', 1573),
#  ('świadczenia', 1569),
#  ('gminy', 1568),
#  ('czas', 1567),
#  ('ten', 1567),
#  ('wchodzi', 1566),
#  ('wraz', 1564),
#  ('dotyczących', 1550),
#  ('następuje', 1549),
#  ('ubezpieczenia', 1544),
#  ('zadania', 1532),
#  ('zmianie', 1518),
#  ('dalej', 1513),
#  ('zakładu', 1500),
#  ('europejskiej', 1498),
#  ('badań', 1497),
#  ('wartość', 1490),
#  ('kary', 1486),
#  ('realizacji', 1480),
#  ('trybie', 1474),
#  ('wyrobów', 1470),
#  ('czerwca', 1468),
#  ('narodowej', 1466),
#  ('we', 1466),
#  ('wojskowej', 1464),
#  ('szczegółowe', 1452),
#  ('ustala', 1447),
#  ('przepisami', 1440),
#  ('wyłącznie', 1439),
#  ('wykonania', 1438),
#  ('rok', 1429),
#  ('krajowego', 1418),
#  ('zarządu', 1417),
#  ('opłaty', 1416),
#  ('można', 1416),
#  ('uwzględniając', 1415),
#  ('względu', 1414),
#  ('miejsce', 1401),
#  ('dokumentów', 1399),
#  ('prawnych', 1396),
#  ('odrębnych', 1392),
#  ('sprzedaży', 1382),
#  ('kraju', 1379),
#  ('stanowi', 1371),
#  ('termin', 1362),
#  ('wydaje', 1360),
#  ('transportu', 1357),
#  ('uzyskania', 1349),
#  ('obowiązku', 1345),
#  ('lipca', 1339),
#  ('zakresu', 1336),
#  ('związanych', 1336),
#  ('wymienionej', 1334),
#  ('chyba', 1332),
#  ('stanu', 1319),
#  ('niezwłocznie', 1319),
#  ('która', 1318),
#  ('gospodarczej', 1317),
#  ('orzeczenia', 1317),
#  ('kto', 1314),
#  ('karnego', 1312),
#  ('formie', 1306),
#  ('obrony', 1303),
#  ('policji', 1296),
#  ('skarbu', 1296),
#  ('osobę', 1292),
#  ('cywilnej', 1292),
#  ('koszty', 1286),
#  ('dotyczy', 1285),
#  ('pozbawienia', 1273),
#  ('jednak', 1267),
#  ('rzecz', 1260),
#  ('skład', 1258),
#  ('prowadzenie', 1258),
#  ('określonego', 1251),
#  ('uwzględnieniem', 1251),
#  ('wydanie', 1245),
#  ('obowiązek', 1240),
#  ('izby', 1235),
#  ('składek', 1234),
#  ('obowiązków', 1225),
#  ('substancji', 1225),
#  ('akcji', 1215),
#  ('inspekcji', 1213),
#  ('czasie', 1212),
#  ('unii', 1209),
#  ('wobec', 1207),
#  ('praw', 1203),
#  ('agencji', 1199),
#  ('okresu', 1195),
#  ('ewidencji', 1193),
#  ('pozwolenia', 1182),
#  ('produkcji', 1175),
#  ('poza', 1164),
#  ('produktu', 1164),
#  ('obszarze', 1160),
#  ('opłat', 1160),
#  ('sprawiedliwości', 1156),
#  ('dokonuje', 1153),
#  ('urządzeń', 1153),
#  ('złożenia', 1149),
#  ('wyniku', 1143),
#  ('okoliczności', 1135),
#  ('społecznej', 1132),
#  ('innego', 1131),
#  ('podlegają', 1130),
#  ('sprawy', 1129),
#  ('stosowania', 1128),
#  ('ustawą', 1120),
#  ('otrzymują', 1119),
#  ('wymienionych', 1114),
#  ('banku', 1102),
#  ('terminu', 1097),
#  ('głównego', 1097),
#  ('rządowej', 1097),
#  ('fundusz', 1096),
#  ('sierpnia', 1091),
#  ('zdrowotnej', 1091),
#  ('społecznych', 1088),
#  ('związane', 1082),
#  ('określony', 1080),
#  ('ciągu', 1079),
#  ('ramach', 1076),
#  ('powiatu', 1076),
#  ('polski', 1075),
#  ('innej', 1073),
#  ('systemu', 1072),
#  ('oceny', 1072),
#  ('pracę', 1071),
#  ('publicznego', 1069),
#  ('wymagania', 1067),
#  ('przestępstwa', 1066),
#  ('późn', 1065),
#  ('wypadku', 1063),
#  ('wykonywanie', 1060),
#  ('podmiotu', 1058),
#  ('mają', 1056),
#  ('granicznej', 1055),
#  ('ochronie', 1054),
#  ('zawodowych', 1052),
#  ('umów', 1051),
#  ('stanowiska', 1048),
#  ('inspektor', 1045),
#  ('rolnictwa', 1044),
#  ('postanowienia', 1031),
#  ('prawnej', 1029),
#  ('lokalu', 1029),
#  ('został', 1027),
#  ('zgody', 1022),
#  ('miejsca', 1022),
#  ('tylko', 1020),
#  ('więcej', 1019),
#  ('finansowych', 1017),
#  ('zakład', 1016),
#  ('usługi', 1007),
#  ('celny', 1006),
#  ('zabezpieczenia', 1004),
#  ('zgłoszenia', 1002),
#  ('e', 997),
#  ('zezwolenie', 997),
#  ('rozumie', 995),
#  ('kwietnia', 993),
#  ('statku', 993),
#  ('rodzaju', 991),
#  ('między', 988),
#  ('organizacyjnych', 986),
#  ('prowadzi', 985),
#  ('zatrudnienia', 982),
#  ('września', 977),
#  ('instytucji', 977),
#  ('przekazuje', 976),
#  ('niego', 976),
#  ('określonej', 976),
#  ('m', 975),
#  ('uchwały', 975),
#  ('niektórych', 974),
#  ('ogłoszone', 973),
#  ('przychodów', 972),
#  ('kwotę', 966),
#  ('celnego', 964),
#  ('inspektora', 963),
#  ('nich', 962),
#  ('podmiotów', 959),
#  ('polskiego', 953),
#  ('listopada', 953),
#  ('wyrazach', 941),
#  ('komisja', 940),
#  ('miesiąca', 934),
#  ('osobie', 932),
#  ('zarząd', 932),
#  ('października', 930),
#  ('odpowiedzialności', 929),
#  ('warunkach', 925),
#  ('wymaga', 922),
#  ('jak', 919),
#  ('odniesieniu', 916),
#  ('wyraz', 916),
#  ('g', 915),
#  ('lekarza', 910),
#  ('podmioty', 909),
#  ('wojewódzkiego', 906),
#  ('wód', 901),
#  ('zamieszkania', 899),
#  ('dzień', 896),
#  ('przedsiębiorcy', 896),
#  ('rozwoju', 893),
#  ('materiałów', 890),
#  ('poszczególnych', 884),
#  ('uprawnienia', 882),
#  ('powinien', 880),
#  ('wynikających', 878),
#  ('została', 874),
#  ('udziału', 874),
#  ('dyscyplinarnego', 873),
#  ('państwowych', 872),
#  ('udział', 872),
#  ('stanowią', 871),
#  ('wydane', 870),
#  ('zasad', 869),
#  ('stanowisko', 868),
#  ('wydatków', 864),
#  ('mocy', 863),
#  ('później', 862),
#  ('go', 861),
#  ('postanowienie', 861),
#  ('wykonuje', 859),
#  ('dokumenty', 855),
#  ('wojewoda', 855),
#  ('zamówienia', 855),
#  ('towaru', 853),
#  ('ustaw', 852),
#  ('właściwemu', 851),
#  ('działań', 846),
#  ('leczniczego', 844),
#  ('wydanych', 842),
#  ('zawodowej', 841),
#  ('narodowego', 841),
#  ('spółdzielni', 839),
#  ('ograniczenia', 836),
#  ('główny', 836),
#  ('energii', 835),
#  ('zawierać', 834),
#  ('szkoły', 834),
#  ('badania', 833),
#  ('urządzenia', 833),
#  ('ilości', 831),
#  ('potrzeby', 830),
#  ('ustawę', 829),
#  ('uprawnień', 828),
#  ('weterynarii', 826),
#  ('krajowej', 821),
#  ('nabycia', 820),
#  ('dyrektor', 819),
#  ('rynku', 818),
#  ('zapewnienia', 815),
#  ('ustalenia', 814),
#  ('osobom', 812),
#  ('wyłączeniem', 811),
#  ('bądź', 808),
#  ('ministrowi', 805),
#  ('maja', 804),
#  ('rolnych', 803),
#  ('obowiązki', 798),
#  ('objętych', 798),
#  ('inaczej', 797),
#  ('bezpośrednio', 796),
#  ('numer', 794),
#  ('l', 790),
#  ('kultury', 789),
#  ('wpisu', 787),
#  ('jednego', 786),
#  ('jakości', 786),
#  ('wyrazem', 786),
#  ('marca', 783),
#  ('inny', 783),
#  ('charakterze', 783),
#  ('przestępstwo', 783),
#  ('terenie', 780),
#  ('informację', 779),
#  ('leczniczych', 779),
#  ('adres', 778),
#  ('zasięgnięciu', 778),
#  ('upływem', 778),
#  ('uchyla', 774),
#  ('decyzję', 773),
#  ('zobowiązania', 772),
#  ('celów', 772),
#  ('bank', 772),
#  ('finansowe', 771),
#  ('kropkę', 770),
#  ('nazwę', 769),
#  ('udzielenie', 767),
#  ('finansowego', 767),
#  ('grzywny', 762),
#  ('zawodu', 761),
#  ('środka', 760),
#  ('innym', 759),
#  ('strony', 759),
#  ('wymagań', 757),
#  ('zobowiązań', 756),
#  ('niezbędne', 756),
#  ('spółek', 755),
#  ('akcyzy', 755),
#  ('wartościowych', 753),
#  ('przeprowadzenia', 751),
#  ('nadzór', 751),
#  ('określenie', 748),
#  ('umowa', 747),
#  ('wykaz', 747),
#  ('każdego', 746),
#  ('którzy', 745),
#  ('zawiera', 745),
#  ('wymienione', 742),
#  ('zawodowego', 741),
#  ('właściwości', 739),
#  ('całości', 738),
#  ('dyrektora', 738),
#  ('udziałów', 738),
#  ('powinny', 734),
#  ('powinno', 732),
#  ('przepisu', 724),
#  ('papierów', 723),
#  ('posiada', 721),
#  ('danego', 719),
#  ('życia', 718),
#  ('wszystkich', 718),
#  ('urząd', 715),
#  ('otrzymania', 715),
#  ('grupy', 714),
#  ('cele', 713),
#  ('liczby', 711),
#  ('emisji', 710),
#  ('żołnierza', 709),
#  ('siedzibę', 708),
#  ('zasiłku', 705),
#  ('podstawę', 703),
#  ('wnioskiem', 703),
#  ('pierwszej', 703),
#  ('podatkowego', 702),
#  ('składa', 700),
#  ('karę', 700),
#  ('służbowych', 699),
#  ('zagranicznych', 697),
#  ('dotacji', 697),
#  ('żołnierzy', 694),
#  ('gmin', 692),
#  ('pieniężnych', 689),
#  ('rodzaj', 685),
#  ('sejmu', 685),
#  ('zakładów', 684),
#  ('organem', 684),
#  ('przedsiębiorców', 682),
#  ('sprawozdania', 681),
#  ('powołuje', 680),
#  ('będących', 680),
#  ('kodeks', 680),
#  ('wzór', 679),
#  ('określić', 678),
#  ('stwierdzenia', 677),
#  ('zdanie', 677),
#  ('udzielania', 676),
#  ('gruntów', 676),
#  ('głosowania', 675),
#  ('podatkowy', 674),
#  ('liczbę', 673),
#  ('zmian', 673),
#  ('wymiaru', 672),
#  ('mu', 672),
#  ('sądów', 671),
#  ('korzystania', 670),
#  ('żądanie', 669),
#  ('renty', 668),
#  ('niniejszą', 666),
#  ('kwota', 665),
#  ('wojskowych', 665),
#  ('przekracza', 664),
#  ('je', 662),
#  ('część', 662),
#  ('stopnia', 662),
#  ('łącznie', 661),
#  ('własności', 661),
#  ('wynosi', 660),
#  ('społecznego', 659),
#  ('obszar', 658),
#  ('zwrotu', 657),
#  ('przeznaczone', 657),
#  ('kandydatów', 656),
#  ('przedmiotem', 656),
#  ('możliwości', 656),
#  ('dokumentu', 656),
#  ('likwidacji', 651),
#  ('odwołanie', 651),
#  ('pracownika', 649),
#  ('tys', 649),
#  ('nazwisko', 648),
#  ('daty', 645),
#  ('ubezpieczenie', 645),
#  ('rodzaje', 645),
#  ('mając', 642),
#  ('przeciwko', 640),
#  ('pełnienia', 640),
#  ('systemie', 639),
#  ('budżetowej', 638),
#  ('planu', 637),
#  ('uważa', 636),
#  ('funduszy', 635),
#  ('dwóch', 635),
#  ('prowadzący', 632),
#  ('roślin', 632),
#  ('państw', 631),
#  ('ile', 630),
#  ('szkół', 629),
#  ('wydatki', 629),
#  ('prokuratora', 629),
#  ('programu', 628),
#  ('jednolitego', 627),
#  ('zagospodarowania', 625),
#  ('datę', 623),
#  ('pochodzenia', 623),
#  ('braku', 622),
#  ('ruchu', 621),
#  ('oznacza', 620),
#  ('członka', 620),
#  ('orzeczenie', 620),
#  ('odwołania', 619),
#  ('przeprowadzania', 618),
#  ('nim', 617),
#  ('tekstu', 617),
#  ('instancji', 617),
#  ('zwolnienia', 616),
#  ('rzeczy', 615),
#  ('składki', 614),
#  ('stanie', 614),
#  ('powinna', 613),
#  ('dokonania', 613),
#  ('komendanta', 613),
#  ('chorych', 612),
#  ('statut', 612),
#  ('przyczyn', 611),
#  ('dochodów', 611),
#  ('kredytów', 611),
#  ('zawartych', 610),
#  ('zgodności', 610),
#  ('przewidzianych', 609),
#  ('przedsiębiorstwa', 609),
#  ('lutego', 608),
#  ('zgodą', 608),
#  ('składu', 608),
#  ('zostało', 606),
#  ('warunkiem', 606),
#  ('służbę', 605),
#  ('cywilnego', 605),
#  ('celnej', 604),
#  ('moc', 603),
#  ('polityki', 603),
#  ('prac', 602),
#  ('zarządzenia', 602),
#  ('granicą', 599),
#  ('organizacyjnej', 597),
#  ('obowiązane', 597),
#  ('przecinkiem', 597),
#  ('podziału', 596),
#  ('wynagrodzenie', 596),
#  ('instalacji', 595),
#  ('podstawy', 594),
#  ('dzienniku', 594),
#  ('obejmuje', 594),
#  ('obrocie', 594),
#  ('komendant', 593),
#  ('f', 591),
#  ('mienia', 589),
#  ('towary', 589),
#  ('zagrożenia', 588),
#  ('udzielenia', 587),
#  ('organami', 585),
#  ('przeznaczonych', 584),
#  ('stan', 583),
#  ('wykonanie', 583),
#  ('ludzi', 583),
#  ('fizycznych', 582),
#  ('europejskiego', 582),
#  ('organizacyjne', 581),
#  ('nastąpić', 581),
#  ('medycznych', 580),
#  ('dłużej', 579),
#  ('zastosowanie', 579),
#  ('urlopu', 578),
#  ('służbie', 578),
#  ('wojewódzkich', 577),
#  ('szkody', 577),
#  ('międzynarodowych', 576),
#  ('rachunek', 575),
#  ('administracyjnego', 575),
#  ('zastosowania', 575),
#  ('wniosków', 573),
#  ('ii', 572),
#  ('pracodawcy', 571),
#  ('emerytury', 571),
#  ('jednostkach', 571),
#  ('spełnia', 570),
#  ('kasy', 570),
#  ('doręczenia', 569),
#  ('lata', 568),
#  ('czynu', 566),
#  ('uzasadnionych', 565),
#  ('niezbędnych', 565),
#  ('zmienianej', 565),
#  ('rachunku', 564),
#  ('czy', 564),
#  ('wyrazie', 563),
#  ('ue', 563),
#  ('szkolenia', 562),
#  ('wypłaty', 562),
#  ('sposobu', 562),
#  ('skarbowe', 561),
#  ('zgromadzenia', 560),
#  ('podatkowych', 560),
#  ('środowisko', 560),
#  ('wiadomości', 559),
#  ('miasta', 559),
#  ('funkcjonariuszy', 558),
#  ('siedziby', 558),
#  ('oświadczenie', 558),
#  ('oznaczenie', 557),
#  ('wyborów', 557),
#  ('technicznych', 556),
#  ('funkcji', 555),
#  ('stanowiących', 554),
#  ('pozostałe', 554),
#  ('majątku', 554),
#  ('wody', 554),
#  ('prezydenta', 553),
#  ('komitetu', 553),
#  ('obowiązujących', 551),
#  ('składników', 551),
#  ('miejscu', 549),
#  ('wyników', 549),
#  ('rozporządzenie', 549),
#  ('gospodarstwa', 548),
#  ('zawiadamia', 547),
#  ('wyboru', 547),
#  ('działalnością', 545),
#  ('imię', 544),
#  ('wojewódzki', 544),
#  ('przekazywania', 543),
#  ('przyrody', 542),
#  ('jeden', 541),
#  ('jednostkę', 540),
#  ('spośród', 539),
#  ('dokumentacji', 539),
#  ('sporządza', 537),
#  ('kolegium', 537),
#  ('przedmiotów', 537),
#  ('będzie', 536),
#  ('kapitału', 535),
#  ('świadczenie', 534),
#  ('dłuższy', 534),
#  ('sprawozdanie', 534),
#  ('podatnika', 533),
#  ('radę', 533),
#  ('obiektów', 533),
#  ('ustalania', 532),
#  ('rodziny', 532),
#  ('obowiązani', 532),
#  ('sieci', 532),
#  ('przedsiębiorca', 532),
#  ('funkcjonariusza', 531),
#  ('ceny', 531),
#  ('wierzytelności', 530),
#  ('urzędów', 530),
#  ('uposażenia', 529),
#  ('danym', 528),
#  ('używania', 528),
#  ('pieniężne', 526),
#  ('wykroczenia', 526),
#  ('porozumienia', 526),
#  ('fizycznej', 524),
#  ('prawne', 524),
#  ('paliw', 523),
#  ('innymi', 522),
#  ('ta', 522),
#  ('wynikające', 521),
#  ('pozostałych', 521),
#  ('skarbowej', 521),
#  ('wojskowego', 521),
#  ('wytwarzania', 520),
#  ('zakończenia', 520),
#  ('powodu', 519),
#  ('polskim', 519),
#  ('właściwe', 519),
#  ('stopień', 518),
#  ('oświadczenia', 518),
#  ('centrum', 518),
#  ('głosów', 518),
#  ('str', 516),
#  ('przychody', 515),
#  ('egzekucji', 515),
#  ('finansowej', 515),
#  ('przysługują', 515),
#  ('składania', 514),
#  ('zostać', 514),
#  ('spółka', 514),
#  ('okręgowego', 514),
#  ('szczegółowy', 512),
#  ('imieniu', 512),
#  ('każdy', 511),
#  ('oddziału', 510),
#  ('służbowe', 509),
#  ('morskiego', 508),
#  ('terminy', 507),
#  ('biura', 507),
#  ('powierzchni', 507),
#  ('trwałych', 506),
#  ('własność', 504),
#  ('właściwej', 504),
#  ('właściwych', 504),
#  ('wielkości', 504),
#  ('stawki', 504),
#  ('lekarz', 502),
#  ('opodatkowania', 502),
#  ('komisję', 501),
#  ('jakie', 501),
#  ('nauki', 501),
#  ('powyżej', 500),
#  ('sędziego', 500),
#  ('organizację', 499),
#  ('oświaty', 499),
#  ('pożarnej', 497),
#  ('urz', 497),
#  ('wymagane', 497),
#  ('kwalifikacji', 496),
#  ('rejestracji', 496),
#  ('zgodę', 495),
#  ('listę', 495),
#  ('środkami', 494),
#  ('pojazdów', 494),
#  ('wykorzystania', 493),
#  ('odpowiednich', 493),
#  ('gospodarczą', 492),
#  ('zawarcia', 492),
#  ('mających', 492),
#  ('zakładach', 491),
#  ('on', 491),
#  ('urzędowym', 489),
#  ('programów', 489),
#  ('protokołu', 488),
#  ('prawną', 488),
#  ('jednostka', 487),
#  ('produkty', 487),
#  ('tytuł', 487),
#  ('treść', 486),
#  ('przewodniczący', 486),
#  ('sędziów', 485),
#  ('pobytu', 484),
#  ('wchodzą', 484),
#  ('aktywów', 484),
#  ('im', 483),
#  ('dochodu', 483),
#  ('tę', 482),
#  ('toku', 482),
#  ('dotychczasowych', 481),
#  ('akcyzowych', 481),
#  ('piśmie', 480),
#  ('morskich', 479),
#  ('skarbowego', 479),
#  ('wyborczej', 478),
#  ('sądowego', 478),
#  ('umowę', 477),
#  ('ważności', 477),
#  ('przechowywania', 477),
#  ('wzory', 476),
#  ('dokonanie', 474),
#  ('płatności', 473),
#  ('okresy', 473),
#  ('prowadzonej', 473),
#  ('handlu', 473),
#  ('pracodawca', 471),
#  ('dokonywania', 471),
#  ('szczególne', 471),
#  ('państwowe', 471),
#  ('pieniężnej', 471),
#  ('rejestr', 469),
#  ('przewodniczącego', 469),
#  ('organowi', 469),
#  ('prokurator', 469),
#  ('użytkowania', 469),
#  ('wniesienia', 466),
#  ('pozwolenie', 465),
#  ('koncesji', 464),
#  ('kształcenia', 464),
#  ('latach', 463),
#  ('trzech', 463),
#  ('takich', 462),
#  ('podatkowej', 461),
#  ('uprawniony', 461),
#  ('skarb', 461),
#  ('inwestycji', 461),
#  ('kierownika', 460),
#  ('tworzy', 459),
#  ('dotychczasowe', 459),
#  ('pobierania', 458),
#  ('przekazania', 458),
#  ('kierownik', 458),
#  ('sił', 457),
#  ('starosta', 457),
#  ('godzin', 457),
#  ('wyroby', 457),
#  ('dzieci', 456),
#  ('zawierające', 456),
#  ('zwrot', 456),
#  ('naruszenia', 455),
#  ('euro', 455),
#  ('udziela', 454),
#  ('domu', 453),
#  ('rejestrze', 453),
#  ('majątkowych', 453),
#  ('zasiłek', 452),
#  ('wykonywaniu', 452),
#  ('dział', 452),
#  ('formy', 451),
#  ('źródeł', 451),
#  ('przeprowadza', 450),
#  ('konieczność', 450),
#  ('odwołuje', 450),
#  ('złotych', 448),
#  ('ziemi', 448),
#  ('zamawiający', 448),
#  ('stawek', 447),
#  ('zostanie', 447),
#  ('zażalenie', 447),
#  ('przewozu', 445),
#  ('objęte', 444),
#  ('wydawania', 444),
#  ('decyzja', 444),
#  ('polską', 444),
#  ('instytutu', 444),
#  ('szefa', 444),
#  ('pożyczek', 443),
#  ('naukowych', 443),
#  ('dochodowym', 442),
#  ('marszałek', 442),
#  ('nadanym', 441),
#  ('prowadzących', 440),
#  ('zawiadomienia', 440),
#  ('członkowskich', 440),
#  ('pojazdu', 439),
#  ('one', 438),
#  ('wodnej', 438),
#  ('wypadkach', 438),
#  ('orzeka', 438),
#  ('wodnych', 437),
#  ...]

# %%
tokens_len = sum(valid_tokens.values())
bigrams_len = sum(valid_bigrams.values())

# %% [markdown]
# # Task 4
# Use pointwise mutual information to compute the measure for all pairs of words.
#
# pmi(x, y) = log(p(x,y)/(p(x)*p(y)))

# %%
def p(x: str):
    return valid_tokens[x]/tokens_len

# %%
def p_xy(xy: tuple):
    return valid_bigrams[xy]/bigrams_len

# %%
def pmi(x, y):
    return math.log(p_xy((x, y))/(p(x)*p(y)))

# %%
pmi('w', 'art')
# Out:
# 2.2282193609686662

# %%
bigrams_pmi = {bigram: pmi(bigram[0], bigram[1]) for bigram in valid_bigrams.keys()}

# %% [markdown]
# # Task 5
# Sort the word pairs according to that measure in the descending order and determine top 10 entries.

# %%
bigrams_pmi_list = [b for b in bigrams_pmi.items()]
bigrams_pmi_list.sort(key = lambda a: (-a[1], a[0][0]))

# %% [markdown]
# As there are many bigrams with the same PMI I sort them also alphabetically if they have the same PMI

# %%
bigrams_pmi_list[:10]
# Out:
# [(('aegroti', 'suprema'), 15.45201719439111),
#  (('aerodynamicznej', 'szorstkości'), 15.45201719439111),
#  (('aethina', 'tumida'), 15.45201719439111),
#  (('agenci', 'ubezpieczeniowi'), 15.45201719439111),
#  (('agregatach', 'pralniczych'), 15.45201719439111),
#  (('agricoltura', 'biologica'), 15.45201719439111),
#  (('agriculture', 'biologique'), 15.45201719439111),
#  (('agrotechniki', 'nienaruszającej'), 15.45201719439111),
#  (('akapicie', 'preambuły'), 15.45201719439111),
#  (('aktowi', 'normatywnemu'), 15.45201719439111)]

# %% [markdown]
# Those are words the most depended on each other.

# %% [markdown]
# # Task 6
# Filter bigrams with number of occurrences lower than 5. Determine top 10 entries for the remaining dataset (>=5 occurrences).

# %%
valid_bigrams_min_5 = Counter({
    bigram: count for bigram, count in valid_bigrams.items() if count >= 5
})

# %%
pmi_bigrams_min_5 = {bigram: pmi(bigram[0], bigram[1]) for bigram in valid_bigrams_min_5.keys()}

# %%
bigrams_pmi_list_5 = [b for b in pmi_bigrams_min_5.items()]
bigrams_pmi_list_5.sort(key = lambda a: (-a[1], a[0][0]))

# %%
bigrams_pmi_list_5[:10]
# Out:
# [(('grzegorz', 'schetyna'), 13.84257928195701),
#  (('klęskami', 'żywiołowymi'), 13.84257928195701),
#  (('młynki', 'młotkowe'), 13.84257928195701),
#  (('młyny', 'kulowe'), 13.84257928195701),
#  (('obcowania', 'płciowego'), 13.84257928195701),
#  (('otworami', 'wiertniczymi'), 13.84257928195701),
#  (('ręcznego', 'miotacza'), 13.84257928195701),
#  (('stajnią', 'wyścigową'), 13.84257928195701),
#  (('zaszkodzić', 'wynikom'), 13.84257928195701),
#  (('środa', 'wlkp'), 13.84257928195701)]

# %% [markdown]
# Looks like all bigrams with highest PMI score were those which occured less than 5 times.

# %% [markdown]
# # Task 7
# Use log likelihood ratio (LLR) to compute the measure for all pairs of words.
# I use implementation of [Ted Dunning](https://github.com/tdunning/python-llr/blob/master/llr.py) but I change it to better suit my problems.

# %%
def denormEntropy(counts):
    '''Computes the entropy of a list of counts scaled by the sum of the counts. If the inputs sum to one, this is just the normal definition of entropy'''
    total = float(sum(counts))
    # Note tricky way to avoid 0*log(0)
    return -sum([k * math.log(k/total + (k==0)) for k in counts])

# %%
def llr_2x2(k11, k12, k21, k22):
    '''Special case of llr with a 2x2 table'''
    return 2 * (denormEntropy([k11+k12, k21+k22]) +
                denormEntropy([k11+k21, k12+k22]) -
                denormEntropy([k11, k12, k21, k22]))

# %%
def llr(word1, word2):
    k11 = valid_bigrams[(word1, word2)]
    k12 = valid_tokens[word2] - k11
    k21 = valid_tokens[word1] - k11
    k22 = tokens_len - k12 - k21 - k11
    return llr_2x2(k11, k12, k21, k22)

# %%
bigrams_llr = {(w1, w2): llr(w1, w2) for (w1, w2) in valid_bigrams.keys()}

# %% [markdown]
# # Task 8
# Sort the word pairs according to that measure in the descending order and display top 10 entries.

# %%
bigrams_llr_list = [b for b in bigrams_llr.items()]
bigrams_llr_list.sort(key = lambda a: (-a[1], a[0][0]))

# %%
bigrams_llr_list[:10]
# Out:
# [(('mowa', 'w'), 153335.6737453388),
#  (('otrzymuje', 'brzmienie'), 114515.41500918352),
#  (('których', 'mowa'), 110917.45014538564),
#  (('o', 'których'), 83815.47016940499),
#  (('w', 'art'), 75294.86544858338),
#  (('którym', 'mowa'), 73124.90741375525),
#  (('dodaje', 'się'), 67183.62798861822),
#  (('w', 'ust'), 61626.03745284141),
#  (('do', 'spraw'), 58703.95083395997),
#  (('o', 'którym'), 56626.197880905704)]

# %%
bigrams_llr_5 = {(w1, w2): llr(w1, w2) for (w1, w2) in valid_bigrams_min_5.keys()}

# %%
bigrams_llr_5_list = [b for b in bigrams_llr.items()]
bigrams_llr_5_list.sort(key = lambda a: (-a[1], a[0][0]))

# %%
bigrams_llr_5_list[:10]
# Out:
# [(('mowa', 'w'), 153335.6737453388),
#  (('otrzymuje', 'brzmienie'), 114515.41500918352),
#  (('których', 'mowa'), 110917.45014538564),
#  (('o', 'których'), 83815.47016940499),
#  (('w', 'art'), 75294.86544858338),
#  (('którym', 'mowa'), 73124.90741375525),
#  (('dodaje', 'się'), 67183.62798861822),
#  (('w', 'ust'), 61626.03745284141),
#  (('do', 'spraw'), 58703.95083395997),
#  (('o', 'którym'), 56626.197880905704)]

# %% [markdown]
# Looks like LLR is more stable when there are rarely used bigrams.

# %% [markdown]
# # Task 9
# Compute trigram counts for the whole corpus and perform the same filtering.

# %%
trigrams = [t for t in nltk.trigrams(tokens)]

# %%
trigrams
# Out:
# [('\n\n\n\n', 'dz.u', '.'),
#  ('dz.u', '.', 'z'),
#  ('.', 'z', '1998'),
#  ('z', '1998', 'r'),
#  ('1998', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '75'),
#  ('nr', '75', ','),
#  ('75', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '486'),
#  ('.',
#   '486',
#   '\n                                                                          \n                                                                          \n                                                                          \n                                     \n                                  '),
#  ('486',
#   '\n                                                                          \n                                                                          \n                                                                          \n                                     \n                                  ',
#   'ustawa'),
#  ('\n                                                                          \n                                                                          \n                                                                          \n                                     \n                                  ',
#   'ustawa',
#   '\n                           '),
#  ('ustawa', '\n                           ', 'z'),
#  ('\n                           ', 'z', 'dnia'),
#  ('z', 'dnia', '7'),
#  ('dnia', '7', 'maja'),
#  ('7', 'maja', '1998'),
#  ('maja', '1998', 'r'),
#  ('1998', 'r', '.'),
#  ('r', '.', '\n                                     \n        '),
#  ('.', '\n                                     \n        ', 'o'),
#  ('\n                                     \n        ', 'o', 'zmianie'),
#  ('o', 'zmianie', 'ustawy'),
#  ('zmianie', 'ustawy', 'o'),
#  ('ustawy', 'o', 'zakładowym'),
#  ('o', 'zakładowym', 'funduszu'),
#  ('zakładowym', 'funduszu', 'świadczeń'),
#  ('funduszu', 'świadczeń', 'socjalnych'),
#  ('świadczeń',
#   'socjalnych',
#   '\n                                     \n                                  '),
#  ('socjalnych',
#   '\n                                     \n                                  ',
#   'art'),
#  ('\n                                     \n                                  ',
#   'art',
#   '.'),
#  ('art', '.', '1'),
#  ('.', '1', '.'),
#  ('1', '.', '\n'),
#  ('.', '\n', 'w'),
#  ('\n', 'w', 'ustawie'),
#  ('w', 'ustawie', 'z'),
#  ('ustawie', 'z', 'dnia'),
#  ('z', 'dnia', '4'),
#  ('dnia', '4', 'marca'),
#  ('4', 'marca', '1994'),
#  ('marca', '1994', 'r'),
#  ('1994', 'r', '.'),
#  ('r', '.', 'o'),
#  ('.', 'o', 'zakładowym'),
#  ('o', 'zakładowym', 'funduszu'),
#  ('zakładowym', 'funduszu', 'świadczeń'),
#  ('funduszu', 'świadczeń', '\n'),
#  ('świadczeń', '\n', 'socjalnych'),
#  ('\n', 'socjalnych', '('),
#  ('socjalnych', '(', 'dz.u'),
#  ('(', 'dz.u', '.'),
#  ('dz.u', '.', 'z'),
#  ('.', 'z', '1996'),
#  ('z', '1996', 'r'),
#  ('1996', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '70'),
#  ('nr', '70', ','),
#  ('70', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '335'),
#  ('.', '335', ','),
#  ('335', ',', 'nr'),
#  (',', 'nr', '118'),
#  ('nr', '118', ','),
#  ('118', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '561'),
#  ('.', '561', ','),
#  ('561', ',', 'nr'),
#  (',', 'nr', '139'),
#  ('nr', '139', ','),
#  ('139', ',', '\n'),
#  (',', '\n', 'poz'),
#  ('\n', 'poz', '.'),
#  ('poz', '.', '647'),
#  ('.', '647', ','),
#  ('647', ',', 'nr'),
#  (',', 'nr', '147'),
#  ('nr', '147', ','),
#  ('147', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '686'),
#  ('.', '686', ','),
#  ('686', ',', 'z'),
#  (',', 'z', '1997'),
#  ('z', '1997', 'r'),
#  ('1997', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '82'),
#  ('nr', '82', ','),
#  ('82', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '518'),
#  ('.', '518', ','),
#  ('518', ',', 'nr'),
#  (',', 'nr', '121'),
#  ('nr', '121', ','),
#  ('121', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '770'),
#  ('.', '770', ')'),
#  ('770', ')', '\n'),
#  (')', '\n', 'wprowadza'),
#  ('\n', 'wprowadza', 'się'),
#  ('wprowadza', 'się', 'następujące'),
#  ('się', 'następujące', 'zmiany'),
#  ('następujące', 'zmiany', ':'),
#  ('zmiany', ':', '\n'),
#  (':', '\n', '1'),
#  ('\n', '1', ')'),
#  ('1', ')', 'w'),
#  (')', 'w', 'art'),
#  ('w', 'art', '.'),
#  ('art', '.', '1'),
#  ('.', '1', 'w'),
#  ('1', 'w', 'ust'),
#  ('w', 'ust', '.'),
#  ('ust', '.', '2'),
#  ('.', '2', 'po'),
#  ('2', 'po', 'wyrazach'),
#  ('po', 'wyrazach', '"'),
#  ('wyrazach', '"', 'minister'),
#  ('"', 'minister', 'spraw'),
#  ('minister', 'spraw', 'wewnętrznych'),
#  ('spraw', 'wewnętrznych', '"'),
#  ('wewnętrznych', '"', 'dodaje'),
#  ('"', 'dodaje', 'się'),
#  ('dodaje', 'się', '\n  '),
#  ('się', '\n  ', 'wyrazy'),
#  ('\n  ', 'wyrazy', '"'),
#  ('wyrazy', '"', 'i'),
#  ('"', 'i', 'administracji'),
#  ('i', 'administracji', '"'),
#  ('administracji', '"', ';'),
#  ('"', ';', '\n'),
#  (';', '\n', '2'),
#  ('\n', '2', ')'),
#  ('2', ')', 'w'),
#  (')', 'w', 'art'),
#  ('w', 'art', '.'),
#  ('art', '.', '5'),
#  ('.', '5', 'ust'),
#  ('5', 'ust', '.'),
#  ('ust', '.', '4'),
#  ('.', '4', 'otrzymuje'),
#  ('4', 'otrzymuje', 'brzmienie'),
#  ('otrzymuje', 'brzmienie', ':'),
#  ('brzmienie', ':', '\n         '),
#  (':', '\n         ', '"'),
#  ('\n         ', '"', '4'),
#  ('"', '4', '.'),
#  ('4', '.', 'wysokość'),
#  ('.', 'wysokość', 'odpisu'),
#  ('wysokość', 'odpisu', 'podstawowego'),
#  ('odpisu', 'podstawowego', 'może'),
#  ('podstawowego', 'może', 'być'),
#  ('może', 'być', 'zwiększona'),
#  ('być', 'zwiększona', 'o'),
#  ('zwiększona', 'o', '6,25'),
#  ('o', '6,25', '%'),
#  ('6,25', '%', '\n           '),
#  ('%', '\n           ', 'przeciętnego'),
#  ('\n           ', 'przeciętnego', 'wynagrodzenia'),
#  ('przeciętnego', 'wynagrodzenia', 'miesięcznego'),
#  ('wynagrodzenia', 'miesięcznego', ','),
#  ('miesięcznego', ',', 'o'),
#  (',', 'o', 'którym'),
#  ('o', 'którym', 'mowa'),
#  ('którym', 'mowa', 'w'),
#  ('mowa', 'w', 'ust'),
#  ('w', 'ust', '.'),
#  ('ust', '.', '\n           '),
#  ('.', '\n           ', '2'),
#  ('\n           ', '2', ','),
#  ('2', ',', 'na'),
#  (',', 'na', 'każdą'),
#  ('na', 'każdą', 'zatrudnioną'),
#  ('każdą', 'zatrudnioną', 'osobę'),
#  ('zatrudnioną', 'osobę', ','),
#  ('osobę', ',', 'w'),
#  (',', 'w', 'stosunku'),
#  ('w', 'stosunku', 'do'),
#  ('stosunku', 'do', 'której'),
#  ('do', 'której', 'orzeczono'),
#  ('której', 'orzeczono', '\n           '),
#  ('orzeczono', '\n           ', 'znaczny'),
#  ('\n           ', 'znaczny', 'lub'),
#  ('znaczny', 'lub', 'umiarkowany'),
#  ('lub', 'umiarkowany', 'stopień'),
#  ('umiarkowany', 'stopień', 'niepełnosprawności'),
#  ('stopień', 'niepełnosprawności', '.'),
#  ('niepełnosprawności', '.', '"'),
#  ('.', '"', ';'),
#  ('"', ';', '\n'),
#  (';', '\n', '3'),
#  ('\n', '3', ')'),
#  ('3', ')', 'w'),
#  (')', 'w', 'art'),
#  ('w', 'art', '.'),
#  ('art', '.', '7'),
#  ('.', '7', ':'),
#  ('7', ':', '\n   '),
#  (':', '\n   ', 'a'),
#  ('\n   ', 'a', ')'),
#  ('a', ')', 'ust'),
#  (')', 'ust', '.'),
#  ('ust', '.', '2'),
#  ('.', '2', 'otrzymuje'),
#  ('2', 'otrzymuje', 'brzmienie'),
#  ('otrzymuje', 'brzmienie', ':'),
#  ('brzmienie', ':', '\n         '),
#  (':', '\n         ', '"'),
#  ('\n         ', '"', '2'),
#  ('"', '2', '.'),
#  ('2', '.', 'zwiększenia'),
#  ('.', 'zwiększenia', ','),
#  ('zwiększenia', ',', 'o'),
#  (',', 'o', 'których'),
#  ('o', 'których', 'mowa'),
#  ('których', 'mowa', 'w'),
#  ('mowa', 'w', 'ust'),
#  ('w', 'ust', '.'),
#  ('ust', '.', '1'),
#  ('.', '1', 'pkt'),
#  ('1', 'pkt', '7'),
#  ('pkt', '7', 'i'),
#  ('7', 'i', '8'),
#  ('i', '8', ','),
#  ('8', ',', 'nie'),
#  (',', 'nie', 'dotyczą'),
#  ('nie', 'dotyczą', '\n           '),
#  ('dotyczą', '\n           ', 'pracodawców'),
#  ('\n           ', 'pracodawców', 'postawionych'),
#  ('pracodawców', 'postawionych', 'w'),
#  ('postawionych', 'w', 'stan'),
#  ('w', 'stan', 'upadłości'),
#  ('stan', 'upadłości', 'lub'),
#  ('upadłości', 'lub', 'likwidacji'),
#  ('lub', 'likwidacji', ','),
#  ('likwidacji', ',', 'z'),
#  (',', 'z', '\n           '),
#  ('z', '\n           ', 'wyłączeniem'),
#  ('\n           ', 'wyłączeniem', 'przedsiębiorstw'),
#  ('wyłączeniem', 'przedsiębiorstw', 'państwowych'),
#  ('przedsiębiorstw', 'państwowych', 'likwidowanych'),
#  ('państwowych', 'likwidowanych', 'w'),
#  ('likwidowanych', 'w', 'celu'),
#  ('w', 'celu', '\n           '),
#  ('celu', '\n           ', 'prywatyzacji'),
#  ('\n           ', 'prywatyzacji', '.'),
#  ('prywatyzacji', '.', '"'),
#  ('.', '"', ','),
#  ('"', ',', '\n   '),
#  (',', '\n   ', 'b'),
#  ('\n   ', 'b', ')'),
#  ('b', ')', 'ust'),
#  (')', 'ust', '.'),
#  ('ust', '.', '3'),
#  ('.', '3', 'otrzymuje'),
#  ('3', 'otrzymuje', 'brzmienie'),
#  ('otrzymuje', 'brzmienie', ':'),
#  ('brzmienie', ':', '\n         '),
#  (':', '\n         ', '"'),
#  ('\n         ', '"', '3'),
#  ('"', '3', '.'),
#  ('3', '.', 'w'),
#  ('.', 'w', 'razie'),
#  ('w', 'razie', 'przejścia'),
#  ('razie', 'przejścia', 'zakładu'),
#  ('przejścia', 'zakładu', 'pracy'),
#  ('zakładu', 'pracy', 'w'),
#  ('pracy', 'w', 'trybie'),
#  ('w', 'trybie', 'art'),
#  ('trybie', 'art', '.'),
#  ('art', '.', '231'),
#  ('.', '231', 'kodeksu'),
#  ('231', 'kodeksu', '\n           '),
#  ('kodeksu', '\n           ', 'pracy'),
#  ('\n           ', 'pracy', 'na'),
#  ('pracy', 'na', 'pracodawcę'),
#  ('na', 'pracodawcę', 'zobowiązanego'),
#  ('pracodawcę', 'zobowiązanego', 'do'),
#  ('zobowiązanego', 'do', 'tworzenia'),
#  ('do', 'tworzenia', 'funduszu'),
#  ('tworzenia', 'funduszu', ','),
#  ('funduszu', ',', '\n           '),
#  (',', '\n           ', 'fundusz'),
#  ('\n           ', 'fundusz', 'pracodawcy'),
#  ('fundusz', 'pracodawcy', 'przejmującego'),
#  ('pracodawcy', 'przejmującego', 'przejmuje'),
#  ('przejmującego', 'przejmuje', 'środki'),
#  ('przejmuje', 'środki', 'pieniężne'),
#  ('środki', 'pieniężne', ','),
#  ('pieniężne', ',', '\n           '),
#  (',', '\n           ', 'należności'),
#  ('\n           ', 'należności', 'i'),
#  ('należności', 'i', 'zobowiązania'),
#  ('i', 'zobowiązania', 'funduszu'),
#  ('zobowiązania', 'funduszu', 'pracodawcy'),
#  ('funduszu', 'pracodawcy', 'przekazującego'),
#  ('pracodawcy', 'przekazującego', '.'),
#  ('przekazującego', '.', '"'),
#  ('.', '"', ','),
#  ('"', ',', '\n   '),
#  (',', '\n   ', 'c'),
#  ('\n   ', 'c', ')'),
#  ('c', ')', 'dodaje'),
#  (')', 'dodaje', 'się'),
#  ('dodaje', 'się', 'ust'),
#  ('się', 'ust', '.'),
#  ('ust', '.', '3a'),
#  ('.', '3a', '-'),
#  ('3a', '-', '3d'),
#  ('-', '3d', 'w'),
#  ('3d', 'w', 'brzmieniu'),
#  ('w', 'brzmieniu', ':'),
#  ('brzmieniu', ':', '\n        '),
#  (':', '\n        ', '"'),
#  ('\n        ', '"', '3a'),
#  ('"', '3a', '.'),
#  ('3a', '.', 'w'),
#  ('.', 'w', 'razie'),
#  ('w', 'razie', 'przejścia'),
#  ('razie', 'przejścia', 'zakładu'),
#  ('przejścia', 'zakładu', 'pracy'),
#  ('zakładu', 'pracy', 'w'),
#  ('pracy', 'w', 'trybie'),
#  ('w', 'trybie', 'art'),
#  ('trybie', 'art', '.'),
#  ('art', '.', '231'),
#  ('.', '231', 'kodeksu'),
#  ('231', 'kodeksu', '\n           '),
#  ('kodeksu', '\n           ', 'pracy'),
#  ('\n           ', 'pracy', 'na'),
#  ('pracy', 'na', 'pracodawcę'),
#  ('na', 'pracodawcę', ','),
#  ('pracodawcę', ',', 'który'),
#  (',', 'który', 'nie'),
#  ('który', 'nie', 'jest'),
#  ('nie', 'jest', 'zobowiązany'),
#  ('jest', 'zobowiązany', 'do'),
#  ('zobowiązany', 'do', 'tworzenia'),
#  ('do', 'tworzenia', '\n           '),
#  ('tworzenia', '\n           ', 'funduszu'),
#  ('\n           ', 'funduszu', ','),
#  ('funduszu', ',', 'pracodawca'),
#  (',', 'pracodawca', 'przejmujący'),
#  ('pracodawca', 'przejmujący', 'przejmuje'),
#  ('przejmujący', 'przejmuje', 'środki'),
#  ('przejmuje', 'środki', 'pieniężne'),
#  ('środki', 'pieniężne', ','),
#  ('pieniężne', ',', '\n           '),
#  (',', '\n           ', 'należności'),
#  ('\n           ', 'należności', 'i'),
#  ('należności', 'i', 'zobowiązania'),
#  ('i', 'zobowiązania', 'funduszu'),
#  ('zobowiązania', 'funduszu', 'pracodawcy'),
#  ('funduszu', 'pracodawcy', 'przekazującego'),
#  ('pracodawcy', 'przekazującego', '.'),
#  ('przekazującego', '.', '\n           '),
#  ('.', '\n           ', 'nadwyżka'),
#  ('\n           ', 'nadwyżka', 'przejętych'),
#  ('nadwyżka', 'przejętych', 'środków'),
#  ('przejętych', 'środków', 'pieniężnych'),
#  ('środków', 'pieniężnych', 'wraz'),
#  ('pieniężnych', 'wraz', 'z'),
#  ('wraz', 'z', 'odsetkami'),
#  ('z', 'odsetkami', 'oraz'),
#  ('odsetkami', 'oraz', '\n           '),
#  ('oraz', '\n           ', 'przejętych'),
#  ('\n           ', 'przejętych', 'należności'),
#  ('przejętych', 'należności', 'wraz'),
#  ('należności', 'wraz', 'z'),
#  ('wraz', 'z', 'odsetkami'),
#  ('z', 'odsetkami', 'nad'),
#  ('odsetkami', 'nad', 'przejętymi'),
#  ('nad', 'przejętymi', '\n           '),
#  ('przejętymi', '\n           ', 'zobowiązaniami'),
#  ('\n           ', 'zobowiązaniami', 'wraz'),
#  ('zobowiązaniami', 'wraz', 'z'),
#  ('wraz', 'z', 'odsetkami'),
#  ('z', 'odsetkami', 'nie'),
#  ('odsetkami', 'nie', 'stanowi'),
#  ('nie', 'stanowi', 'przychodu'),
#  ('stanowi', 'przychodu', '\n           '),
#  ('przychodu', '\n           ', 'pracodawcy'),
#  ('\n           ', 'pracodawcy', 'przejmującego'),
#  ('pracodawcy', 'przejmującego', ','),
#  ('przejmującego', ',', 'jest'),
#  (',', 'jest', 'gromadzona'),
#  ('jest', 'gromadzona', 'na'),
#  ('gromadzona', 'na', 'odrębnym'),
#  ('na', 'odrębnym', 'rachunku'),
#  ('odrębnym', 'rachunku', '\n           '),
#  ('rachunku', '\n           ', 'bankowym'),
#  ('\n           ', 'bankowym', 'lub'),
#  ('bankowym', 'lub', 'wydzielonym'),
#  ('lub', 'wydzielonym', 'subkoncie'),
#  ('wydzielonym', 'subkoncie', 'i'),
#  ('subkoncie', 'i', 'podlega'),
#  ('i', 'podlega', 'wydatkowaniu'),
#  ('podlega', 'wydatkowaniu', 'na'),
#  ('wydatkowaniu', 'na', '\n           '),
#  ('na', '\n           ', 'zasadach'),
#  ('\n           ', 'zasadach', 'określonych'),
#  ('zasadach', 'określonych', 'ustawą'),
#  ('określonych', 'ustawą', 'dla'),
#  ('ustawą', 'dla', 'dokonywania'),
#  ('dla', 'dokonywania', 'wydatków'),
#  ('dokonywania', 'wydatków', 'z'),
#  ('wydatków', 'z', '\n           '),
#  ('z', '\n           ', 'funduszu'),
#  ('\n           ', 'funduszu', '.'),
#  ('funduszu', '.', 'art'),
#  ('.', 'art', '.'),
#  ('art', '.', '8'),
#  ('.', '8', 'ust'),
#  ('8', 'ust', '.'),
#  ('ust', '.', '2'),
#  ('.', '2', 'stosuje'),
#  ('2', 'stosuje', 'się'),
#  ('stosuje', 'się', 'odpowiednio'),
#  ('się', 'odpowiednio', '.'),
#  ('odpowiednio', '.', '\n         '),
#  ('.', '\n         ', '3b'),
#  ('\n         ', '3b', '.'),
#  ('3b', '.', 'w'),
#  ('.', 'w', 'razie'),
#  ('w', 'razie', 'przejścia'),
#  ('razie', 'przejścia', 'części'),
#  ('przejścia', 'części', 'zakładu'),
#  ('części', 'zakładu', 'pracy'),
#  ('zakładu', 'pracy', 'w'),
#  ('pracy', 'w', 'trybie'),
#  ('w', 'trybie', 'art'),
#  ('trybie', 'art', '.'),
#  ('art', '.', '231'),
#  ('.', '231', '\n           '),
#  ('231', '\n           ', 'kodeksu'),
#  ('\n           ', 'kodeksu', 'pracy'),
#  ('kodeksu', 'pracy', 'na'),
#  ('pracy', 'na', 'pracodawcę'),
#  ('na', 'pracodawcę', 'zobowiązanego'),
#  ('pracodawcę', 'zobowiązanego', 'do'),
#  ('zobowiązanego', 'do', 'tworzenia'),
#  ('do', 'tworzenia', '\n           '),
#  ('tworzenia', '\n           ', 'funduszu'),
#  ('\n           ', 'funduszu', ','),
#  ('funduszu', ',', 'fundusz'),
#  (',', 'fundusz', 'pracodawcy'),
#  ('fundusz', 'pracodawcy', 'przejmującego'),
#  ('pracodawcy', 'przejmującego', 'zwiększa'),
#  ('przejmującego', 'zwiększa', 'się'),
#  ('zwiększa', 'się', ','),
#  ('się', ',', 'w'),
#  (',', 'w', '\n           '),
#  ('w', '\n           ', 'części'),
#  ('\n           ', 'części', 'przypadającej'),
#  ('części', 'przypadającej', 'na'),
#  ('przypadającej', 'na', 'liczbę'),
#  ('na', 'liczbę', 'przejmowanych'),
#  ('liczbę', 'przejmowanych', 'pracowników'),
#  ('przejmowanych', 'pracowników', ','),
#  ('pracowników', ',', 'o'),
#  (',', 'o', '\n           '),
#  ('o', '\n           ', 'równowartość'),
#  ('\n           ', 'równowartość', 'środków'),
#  ('równowartość', 'środków', 'pieniężnych'),
#  ('środków', 'pieniężnych', 'funduszu'),
#  ('pieniężnych', 'funduszu', 'pracodawcy'),
#  ('funduszu', 'pracodawcy', '\n           '),
#  ('pracodawcy', '\n           ', 'przekazującego'),
#  ('\n           ', 'przekazującego', ','),
#  ('przekazującego', ',', 'skorygowanych'),
#  (',', 'skorygowanych', 'odpowiednio'),
#  ('skorygowanych', 'odpowiednio', 'o'),
#  ('odpowiednio', 'o', 'należności'),
#  ('o', 'należności', 'i'),
#  ('należności', 'i', '\n           '),
#  ('i', '\n           ', 'zobowiązania'),
#  ('\n           ', 'zobowiązania', 'funduszu'),
#  ('zobowiązania', 'funduszu', '-'),
#  ('funduszu', '-', 'według'),
#  ('-', 'według', 'stanu'),
#  ('według', 'stanu', 'na'),
#  ('stanu', 'na', 'ostatni'),
#  ('na', 'ostatni', 'dzień'),
#  ('ostatni', 'dzień', 'miesiąca'),
#  ('dzień', 'miesiąca', ','),
#  ('miesiąca', ',', '\n           '),
#  (',', '\n           ', 'w'),
#  ('\n           ', 'w', 'którym'),
#  ('w', 'którym', 'następuje'),
#  ('którym', 'następuje', 'przejście'),
#  ('następuje', 'przejście', '.'),
#  ('przejście', '.', '\n         '),
#  ('.', '\n         ', '3c'),
#  ('\n         ', '3c', '.'),
#  ('3c', '.', 'zasady'),
#  ('.', 'zasady', 'podziału'),
#  ('zasady', 'podziału', 'środków'),
#  ('podziału', 'środków', 'pieniężnych'),
#  ('środków', 'pieniężnych', 'stanowiących'),
#  ('pieniężnych', 'stanowiących', 'równowartość'),
#  ('stanowiących', 'równowartość', '\n           '),
#  ('równowartość', '\n           ', 'odpisu'),
#  ('\n           ', 'odpisu', 'podstawowego'),
#  ('odpisu', 'podstawowego', ','),
#  ('podstawowego', ',', 'obciążającego'),
#  (',', 'obciążającego', 'koszty'),
#  ('obciążającego', 'koszty', 'pracodawcy'),
#  ('koszty', 'pracodawcy', '\n           '),
#  ('pracodawcy', '\n           ', 'przekazującego'),
#  ('\n           ', 'przekazującego', ','),
#  ('przekazującego', ',', 'dotyczącego'),
#  (',', 'dotyczącego', 'roku'),
#  ('dotyczącego', 'roku', ','),
#  ('roku', ',', 'w'),
#  (',', 'w', 'którym'),
#  ('w', 'którym', 'następuje'),
#  ('którym', 'następuje', 'przejście'),
#  ('następuje', 'przejście', '\n           '),
#  ('przejście', '\n           ', 'części'),
#  ('\n           ', 'części', 'zakładu'),
#  ('części', 'zakładu', 'pracy'),
#  ('zakładu', 'pracy', ','),
#  ('pracy', ',', 'określa'),
#  (',', 'określa', 'porozumienie'),
#  ('określa', 'porozumienie', 'między'),
#  ('porozumienie', 'między', 'pracodawcami'),
#  ('między', 'pracodawcami', '.'),
#  ('pracodawcami', '.', '\n         '),
#  ('.', '\n         ', '3d'),
#  ('\n         ', '3d', '.'),
#  ('3d', '.', 'przekazanie'),
#  ('.', 'przekazanie', 'środków'),
#  ('przekazanie', 'środków', ','),
#  ('środków', ',', 'o'),
#  (',', 'o', 'których'),
#  ('o', 'których', 'mowa'),
#  ('których', 'mowa', 'w'),
#  ('mowa', 'w', 'ust'),
#  ('w', 'ust', '.'),
#  ('ust', '.', '3b'),
#  ('.', '3b', 'i'),
#  ('3b', 'i', '3c'),
#  ('i', '3c', ','),
#  ('3c', ',', 'następuje'),
#  (',', 'następuje', '\n           '),
#  ('następuje', '\n           ', 'w'),
#  ('\n           ', 'w', 'terminie'),
#  ('w', 'terminie', 'trzydziestu'),
#  ('terminie', 'trzydziestu', 'dni'),
#  ('trzydziestu', 'dni', 'od'),
#  ('dni', 'od', 'daty'),
#  ('od', 'daty', 'przejścia'),
#  ('daty', 'przejścia', 'części'),
#  ('przejścia', 'części', 'zakładu'),
#  ('części', 'zakładu', '\n           '),
#  ('zakładu', '\n           ', 'pracy'),
#  ('\n           ', 'pracy', ','),
#  ('pracy', ',', 'chyba'),
#  (',', 'chyba', 'że'),
#  ('chyba', 'że', 'porozumienie'),
#  ('że', 'porozumienie', ','),
#  ('porozumienie', ',', 'o'),
#  (',', 'o', 'którym'),
#  ('o', 'którym', 'mowa'),
#  ('którym', 'mowa', 'w'),
#  ('mowa', 'w', 'ust'),
#  ('w', 'ust', '.'),
#  ('ust', '.', '3c'),
#  ('.', '3c', 'stanowi'),
#  ('3c', 'stanowi', '\n           '),
#  ('stanowi', '\n           ', 'inaczej'),
#  ('\n           ', 'inaczej', '.'),
#  ('inaczej', '.', '"'),
#  ('.', '"', '.'),
#  ('"', '.', '\n     \n                                  '),
#  ('.', '\n     \n                                  ', 'art'),
#  ('\n     \n                                  ', 'art', '.'),
#  ('art', '.', '2'),
#  ('.', '2', '.'),
#  ('2', '.', '\n'),
#  ('.', '\n', 'ustawa'),
#  ('\n', 'ustawa', 'wchodzi'),
#  ('ustawa', 'wchodzi', 'w'),
#  ('wchodzi', 'w', 'życie'),
#  ('w', 'życie', 'w'),
#  ('życie', 'w', 'terminie'),
#  ('w', 'terminie', '14'),
#  ('terminie', '14', 'dni'),
#  ('14', 'dni', 'od'),
#  ('dni', 'od', 'dnia'),
#  ('od', 'dnia', 'ogłoszenia'),
#  ('dnia', 'ogłoszenia', '.'),
#  ('ogłoszenia', '.', '\n\n\n\n\n'),
#  ('.', '\n\n\n\n\n', 'dz.u'),
#  ('\n\n\n\n\n', 'dz.u', '.'),
#  ('dz.u', '.', 'z'),
#  ('.', 'z', '2004'),
#  ('z', '2004', 'r'),
#  ('2004', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '238'),
#  ('nr', '238', ','),
#  ('238', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '2387'),
#  ('.',
#   '2387',
#   '\n                                        \n               \n                                        \n                                        \n                                        \n                                   '),
#  ('2387',
#   '\n                                        \n               \n                                        \n                                        \n                                        \n                                   ',
#   'u'),
#  ('\n                                        \n               \n                                        \n                                        \n                                        \n                                   ',
#   'u',
#   's'),
#  ('u', 's', 't'),
#  ('s', 't', 'a'),
#  ('t', 'a', 'w'),
#  ('a', 'w', 'a'),
#  ('w', 'a', '\n                           '),
#  ('a', '\n                           ', 'z'),
#  ('\n                           ', 'z', 'dnia'),
#  ('z', 'dnia', '27'),
#  ('dnia', '27', 'sierpnia'),
#  ('27', 'sierpnia', '2004'),
#  ('sierpnia', '2004', 'r'),
#  ('2004', 'r', '.'),
#  ('r', '.', '\n                                        \n    '),
#  ('.', '\n                                        \n    ', 'o'),
#  ('\n                                        \n    ', 'o', 'ratyfikacji'),
#  ('o', 'ratyfikacji', 'konwencji'),
#  ('ratyfikacji', 'konwencji', 'o'),
#  ('konwencji', 'o', 'pozbawianiu'),
#  ('o', 'pozbawianiu', 'uprawnień'),
#  ('pozbawianiu', 'uprawnień', 'do'),
#  ('uprawnień', 'do', 'kierowania'),
#  ('do', 'kierowania', 'pojazdami'),
#  ('kierowania', 'pojazdami', ','),
#  ('pojazdami', ',', '\n               '),
#  (',', '\n               ', 'sporządzonej'),
#  ('\n               ', 'sporządzonej', 'w'),
#  ('sporządzonej', 'w', 'luksemburgu'),
#  ('w', 'luksemburgu', 'dnia'),
#  ('luksemburgu', 'dnia', '17'),
#  ('dnia', '17', 'czerwca'),
#  ('17', 'czerwca', '1998'),
#  ('czerwca', '1998', 'r'),
#  ('1998', 'r', '.'),
#  ('r',
#   '.',
#   '\n                                        \n                                        \n                                     '),
#  ('.',
#   '\n                                        \n                                        \n                                     ',
#   'art'),
#  ('\n                                        \n                                        \n                                     ',
#   'art',
#   '.'),
#  ('art', '.', '1'),
#  ('.', '1', '.'),
#  ('1', '.', '\n'),
#  ('.', '\n', 'wyraża'),
#  ('\n', 'wyraża', 'się'),
#  ('wyraża', 'się', 'zgodę'),
#  ('się', 'zgodę', 'na'),
#  ('zgodę', 'na', 'dokonanie'),
#  ('na', 'dokonanie', 'przez'),
#  ('dokonanie', 'przez', 'prezydenta'),
#  ('przez', 'prezydenta', 'rzeczypospolitej'),
#  ('prezydenta', 'rzeczypospolitej', 'polskiej'),
#  ('rzeczypospolitej', 'polskiej', '\n'),
#  ('polskiej', '\n', 'ratyfikacji'),
#  ('\n', 'ratyfikacji', 'konwencji'),
#  ('ratyfikacji', 'konwencji', 'o'),
#  ('konwencji', 'o', 'pozbawianiu'),
#  ('o', 'pozbawianiu', 'uprawnień'),
#  ('pozbawianiu', 'uprawnień', 'do'),
#  ('uprawnień', 'do', 'kierowania'),
#  ('do', 'kierowania', 'pojazdami'),
#  ('kierowania', 'pojazdami', ','),
#  ('pojazdami', ',', '\n'),
#  (',', '\n', 'sporządzonej'),
#  ('\n', 'sporządzonej', 'w'),
#  ('sporządzonej', 'w', 'luksemburgu'),
#  ('w', 'luksemburgu', 'dnia'),
#  ('luksemburgu', 'dnia', '17'),
#  ('dnia', '17', 'czerwca'),
#  ('17', 'czerwca', '1998'),
#  ('czerwca', '1998', 'r'),
#  ('1998', 'r', '.'),
#  ('r',
#   '.',
#   '\n                                        \n                                     '),
#  ('.',
#   '\n                                        \n                                     ',
#   'art'),
#  ('\n                                        \n                                     ',
#   'art',
#   '.'),
#  ('art', '.', '2'),
#  ('.', '2', '.'),
#  ('2', '.', '\n'),
#  ('.', '\n', 'ustawa'),
#  ('\n', 'ustawa', 'wchodzi'),
#  ('ustawa', 'wchodzi', 'w'),
#  ('wchodzi', 'w', 'życie'),
#  ('w', 'życie', 'po'),
#  ('życie', 'po', 'upływie'),
#  ('po', 'upływie', '14'),
#  ('upływie', '14', 'dni'),
#  ('14', 'dni', 'od'),
#  ('dni', 'od', 'dnia'),
#  ('od', 'dnia', 'ogłoszenia'),
#  ('dnia', 'ogłoszenia', '.'),
#  ('ogłoszenia', '.', '\n\n\n\n\n'),
#  ('.', '\n\n\n\n\n', 'dz.u'),
#  ('\n\n\n\n\n', 'dz.u', '.'),
#  ('dz.u', '.', 'z'),
#  ('.', 'z', '1998'),
#  ('z', '1998', 'r'),
#  ('1998', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '160'),
#  ('nr', '160', ','),
#  ('160', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '1058'),
#  ('.',
#   '1058',
#   '\n                                                                              \n                                                                              \n                                       \n                                    '),
#  ('1058',
#   '\n                                                                              \n                                                                              \n                                       \n                                    ',
#   'ustawa'),
#  ('\n                                                                              \n                                                                              \n                                       \n                                    ',
#   'ustawa',
#   '\n                           '),
#  ('ustawa', '\n                           ', 'z'),
#  ('\n                           ', 'z', 'dnia'),
#  ('z', 'dnia', '3'),
#  ('dnia', '3', 'grudnia'),
#  ('3', 'grudnia', '1998'),
#  ('grudnia', '1998', 'r'),
#  ('1998', 'r', '.'),
#  ('r', '.', '\n                                       \n               '),
#  ('.', '\n                                       \n               ', 'o'),
#  ('\n                                       \n               ',
#   'o',
#   'zmianie'),
#  ('o', 'zmianie', 'ustawy'),
#  ('zmianie', 'ustawy', 'o'),
#  ('ustawy', 'o', 'podatkach'),
#  ('o', 'podatkach', 'i'),
#  ('podatkach', 'i', 'opłatach'),
#  ('i', 'opłatach', 'lokalnych'),
#  ('opłatach',
#   'lokalnych',
#   '\n                                       \n                                       \n                                    '),
#  ('lokalnych',
#   '\n                                       \n                                       \n                                    ',
#   'art'),
#  ('\n                                       \n                                       \n                                    ',
#   'art',
#   '.'),
#  ('art', '.', '1'),
#  ('.', '1', '.'),
#  ('1', '.', '\n'),
#  ('.', '\n', 'w'),
#  ('\n', 'w', 'ustawie'),
#  ('w', 'ustawie', 'z'),
#  ('ustawie', 'z', 'dnia'),
#  ('z', 'dnia', '12'),
#  ('dnia', '12', 'stycznia'),
#  ('12', 'stycznia', '1991'),
#  ('stycznia', '1991', 'r'),
#  ('1991', 'r', '.'),
#  ('r', '.', 'o'),
#  ('.', 'o', 'podatkach'),
#  ('o', 'podatkach', 'i'),
#  ('podatkach', 'i', 'opłatach'),
#  ('i', 'opłatach', 'lokalnych'),
#  ('opłatach', 'lokalnych', '('),
#  ('lokalnych', '(', 'dz.u'),
#  ('(', 'dz.u', '.'),
#  ('dz.u', '.', '\n'),
#  ('.', '\n', 'nr'),
#  ('\n', 'nr', '9'),
#  ('nr', '9', ','),
#  ('9', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '31'),
#  ('.', '31', 'i'),
#  ('31', 'i', 'nr'),
#  ('i', 'nr', '101'),
#  ('nr', '101', ','),
#  ('101', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '444'),
#  ('.', '444', ','),
#  ('444', ',', 'z'),
#  (',', 'z', '1992'),
#  ('z', '1992', 'r'),
#  ('1992', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '21'),
#  ('nr', '21', ','),
#  ('21', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '86'),
#  ('.', '86', ','),
#  ('86', ',', 'z'),
#  (',', 'z', '1994'),
#  ('z', '1994', 'r'),
#  ('1994', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '123'),
#  ('nr', '123', ','),
#  ('123', ',', '\n'),
#  (',', '\n', 'poz'),
#  ('\n', 'poz', '.'),
#  ('poz', '.', '600'),
#  ('.', '600', ','),
#  ('600', ',', 'z'),
#  (',', 'z', '1996'),
#  ('z', '1996', 'r'),
#  ('1996', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '91'),
#  ('nr', '91', ','),
#  ('91', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '409'),
#  ('.', '409', 'i'),
#  ('409', 'i', 'nr'),
#  ('i', 'nr', '149'),
#  ('nr', '149', ','),
#  ('149', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '704'),
#  ('.', '704', ','),
#  ('704', ',', 'z'),
#  (',', 'z', '1997'),
#  ('z', '1997', 'r'),
#  ('1997', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '5'),
#  ('nr', '5', ','),
#  ('5', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '\n'),
#  ('.', '\n', '24'),
#  ('\n', '24', ','),
#  ('24', ',', 'nr'),
#  (',', 'nr', '107'),
#  ('nr', '107', ','),
#  ('107', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '689'),
#  ('.', '689', ','),
#  ('689', ',', 'nr'),
#  (',', 'nr', '121'),
#  ('nr', '121', ','),
#  ('121', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '770'),
#  ('.', '770', 'i'),
#  ('770', 'i', 'nr'),
#  ('i', 'nr', '123'),
#  ('nr', '123', ','),
#  ('123', ',', 'poz'),
#  (',', 'poz', '.'),
#  ('poz', '.', '780'),
#  ('.', '780', 'oraz'),
#  ('780', 'oraz', 'z'),
#  ('oraz', 'z', '1998'),
#  ('z', '1998', 'r'),
#  ('1998', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '\n'),
#  ('nr', '\n', '106'),
#  ('\n', '106', 'poz'),
#  ('106', 'poz', '.'),
#  ('poz', '.', '668'),
#  ('.', '668', ')'),
#  ('668', ')', 'wprowadza'),
#  (')', 'wprowadza', 'się'),
#  ('wprowadza', 'się', 'następujące'),
#  ('się', 'następujące', 'zmiany'),
#  ('następujące', 'zmiany', ':'),
#  ('zmiany', ':', '\n'),
#  (':', '\n', '1'),
#  ('\n', '1', ')'),
#  ('1', ')', 'w'),
#  (')', 'w', 'art'),
#  ('w', 'art', '.'),
#  ('art', '.', '8'),
#  ('.', '8', 'pkt'),
#  ('8', 'pkt', '4'),
#  ('pkt', '4', 'otrzymuje'),
#  ('4', 'otrzymuje', 'brzmienie'),
#  ('otrzymuje', 'brzmienie', ':'),
#  ('brzmienie', ':', '\n     '),
#  (':', '\n     ', '"'),
#  ('\n     ', '"', '4'),
#  ('"', '4', ')'),
#  ('4', ')', 'przyczepy'),
#  (')', 'przyczepy', 'i'),
#  ('przyczepy', 'i', 'naczepy'),
#  ('i', 'naczepy', 'o'),
#  ('naczepy', 'o', 'ładowności'),
#  ('o', 'ładowności', 'powyżej'),
#  ('ładowności', 'powyżej', '5'),
#  ('powyżej', '5', 'ton'),
#  ('5', 'ton', ','),
#  ('ton', ',', 'z'),
#  (',', 'z', 'wyjątkiem'),
#  ('z', 'wyjątkiem', '\n       '),
#  ('wyjątkiem', '\n       ', 'wykorzystywanych'),
#  ('\n       ', 'wykorzystywanych', 'na'),
#  ('wykorzystywanych', 'na', 'cele'),
#  ('na', 'cele', 'rolnicze'),
#  ('cele', 'rolnicze', 'przez'),
#  ('rolnicze', 'przez', 'podatnika'),
#  ('przez', 'podatnika', 'podatku'),
#  ('podatnika', 'podatku', 'rolnego'),
#  ('podatku', 'rolnego', ','),
#  ('rolnego', ',', '"'),
#  (',', '"', ';'),
#  ('"', ';', '\n'),
#  (';', '\n', '2'),
#  ('\n', '2', ')'),
#  ('2', ')', 'w'),
#  (')', 'w', 'art'),
#  ('w', 'art', '.'),
#  ('art', '.', '10'),
#  ('.', '10', 'dotychczasową'),
#  ('10', 'dotychczasową', 'treść'),
#  ('dotychczasową', 'treść', 'oznacza'),
#  ('treść', 'oznacza', 'się'),
#  ('oznacza', 'się', 'jako'),
#  ('się', 'jako', 'ust'),
#  ('jako', 'ust', '.'),
#  ('ust', '.', '1'),
#  ('.', '1', 'i'),
#  ('1', 'i', 'dodaje'),
#  ('i', 'dodaje', 'się'),
#  ('dodaje', 'się', 'ust'),
#  ('się', 'ust', '.'),
#  ('ust', '.', '2'),
#  ('.', '2', '\n  '),
#  ('2', '\n  ', 'w'),
#  ('\n  ', 'w', 'brzmieniu'),
#  ('w', 'brzmieniu', ':'),
#  ('brzmieniu', ':', '\n     '),
#  (':', '\n     ', '"'),
#  ('\n     ', '"', '2'),
#  ('"', '2', '.'),
#  ('2', '.', 'przy'),
#  ('.', 'przy', 'określaniu'),
#  ('przy', 'określaniu', 'stawek'),
#  ('określaniu', 'stawek', ','),
#  ('stawek', ',', 'o'),
#  (',', 'o', 'których'),
#  ('o', 'których', 'mowa'),
#  ('których', 'mowa', 'w'),
#  ('mowa', 'w', 'ust'),
#  ('w', 'ust', '.'),
#  ('ust', '.', '1'),
#  ('.', '1', ','),
#  ('1', ',', 'rada'),
#  (',', 'rada', 'gminy'),
#  ('rada', 'gminy', 'może'),
#  ('gminy', 'może', '\n       '),
#  ('może', '\n       ', 'uwzględniać'),
#  ('\n       ', 'uwzględniać', 'rodzaj'),
#  ('uwzględniać', 'rodzaj', 'środka'),
#  ('rodzaj', 'środka', 'transportowego'),
#  ('środka', 'transportowego', ','),
#  ('transportowego', ',', 'ładowność'),
#  (',', 'ładowność', ','),
#  ('ładowność', ',', 'masę'),
#  (',', 'masę', 'całkowitą'),
#  ('masę', 'całkowitą', ','),
#  ('całkowitą', ',', '\n       '),
#  (',', '\n       ', 'wiek'),
#  ('\n       ', 'wiek', ','),
#  ('wiek', ',', 'nacisk'),
#  (',', 'nacisk', 'na'),
#  ('nacisk', 'na', 'siodło'),
#  ('na', 'siodło', 'ciągnika'),
#  ('siodło', 'ciągnika', 'albo'),
#  ('ciągnika', 'albo', 'liczbę'),
#  ('albo', 'liczbę', 'miejsc'),
#  ('liczbę', 'miejsc', 'do'),
#  ('miejsc', 'do', 'siedzenia'),
#  ('do', 'siedzenia', '.'),
#  ('siedzenia', '.', '"'),
#  ('.', '"', '.'),
#  ('"',
#   '.',
#   '\n                                       \n                                       \n                                    '),
#  ('.',
#   '\n                                       \n                                       \n                                    ',
#   'art'),
#  ('\n                                       \n                                       \n                                    ',
#   'art',
#   '.'),
#  ('art', '.', '2'),
#  ('.', '2', '.'),
#  ('2', '.', '\n '),
#  ('.', '\n ', 'ustawa'),
#  ('\n ', 'ustawa', 'wchodzi'),
#  ('ustawa', 'wchodzi', 'w'),
#  ('wchodzi', 'w', 'życie'),
#  ('w', 'życie', 'z'),
#  ('życie', 'z', 'dniem'),
#  ('z', 'dniem', '1'),
#  ('dniem', '1', 'stycznia'),
#  ('1', 'stycznia', '1999'),
#  ('stycznia', '1999', 'r'),
#  ('1999', 'r', '.'),
#  ('r', '.', '\n\n\n\n\n'),
#  ('.', '\n\n\n\n\n', 'dz.u'),
#  ('\n\n\n\n\n', 'dz.u', '.'),
#  ('dz.u', '.', 'z'),
#  ('.', 'z', '1998'),
#  ('z', '1998', 'r'),
#  ('1998', 'r', '.'),
#  ('r', '.', 'nr'),
#  ('.', 'nr', '137'),
#  ('nr', '137', ','),
#  ('137', ',', 'poz'),
#  (',', 'poz', '.'),
#  ...]

# %%
trigrams_count = Counter(trigrams)

# %%
valid_trigrams = Counter({
    (t1, t2, t3): count for (t1, t2, t3), count in trigrams_count.items() if token_valid(t1) and token_valid(t2) and token_valid(t3)
})

# %%
valid_trigrams.most_common(10)
# Out:
# [(('których', 'mowa', 'w'), 12507),
#  (('mowa', 'w', 'ust'), 12487),
#  (('o', 'których', 'mowa'), 11883),
#  (('mowa', 'w', 'art'), 11146),
#  (('którym', 'mowa', 'w'), 8429),
#  (('o', 'którym', 'mowa'), 8123),
#  (('której', 'mowa', 'w'), 5021),
#  (('o', 'której', 'mowa'), 4782),
#  (('właściwy', 'do', 'spraw'), 4435),
#  (('minister', 'właściwy', 'do'), 4105)]

# %%
trigrams_len = sum(valid_trigrams.values())

# %%
valid_trigrams_min_5 = Counter({
    trigram: count for trigram, count in valid_trigrams.items() if count >= 5
})

# %% [markdown]
# # Task 10
# Use PMI (with 5 occurrence threshold) and LLR to compute top 10 results for the trigrams. Devise a method for computing the values, based on the results for bigrams.

# %%
def p_xyz(xyz: tuple):
    return valid_trigrams[xyz]/trigrams_len

# %%
def pmi_3(x, y, z):
    return math.log(p_xyz((x, y, z))/(p(x)*p(y)*p(z)))

# %%
pmi_trigrams = {trigram: pmi_3(trigram[0], trigram[1], trigram[2]) for trigram in valid_trigrams_min_5.keys()}

# %%
pmi_trigrams_list = [t for t in pmi_trigrams.items()]
pmi_trigrams_list.sort(key = lambda a: (-a[1], a[0][0]))

# %%
pmi_trigrams_list[:10]
# Out:
# [(('profilem', 'zaufanym', 'epuap'), 25.649236093505156),
#  (('finałowego', 'turnieju', 'mistrzostw'), 25.38550726207587),
#  (('przedwczesnego', 'wyrębu', 'drzewostanu'), 25.26520990745277),
#  (('potwierdzonym', 'profilem', 'zaufanym'), 25.182735094810624),
#  (('piłce', 'nożnej', 'uefa'), 25.142149814695546),
#  (('cienką', 'sierścią', 'zwierzęcą'), 24.900236160699343),
#  (('szybkiemu', 'postępowi', 'technicznemu'), 24.855290448995227),
#  (('turnieju', 'mistrzostw', 'europy'), 24.854879011013697),
#  (('grożącą', 'jemu', 'samemu'), 24.687894542417947),
#  (('wypalonym', 'paliwem', 'jądrowym'), 24.6366012480304)]

# %%
def llr_3(word1, word2, word3):
    k11 = valid_trigrams[(word1, word2, word3)]
    k12 = valid_bigrams[(word2, word3)] - k11
    k21 = valid_bigrams[(word1, word2)] - k11
    k22 = bigrams_len - k12 - k21 - k11
    return llr_2x2(k11, k12, k21, k22)

# %%
trigrams_llr = {(w1, w2, w3): llr_3(w1, w2, w3) for (w1, w2, w3) in valid_trigrams_min_5.keys()}

# %%
llr_trigrams_list = [t for t in trigrams_llr.items()]
llr_trigrams_list.sort(key = lambda a: (-a[1], a[0][0]))

# %%
llr_trigrams_list[:10]
# Out:
# [(('o', 'których', 'mowa'), 136612.24265674822),
#  (('których', 'mowa', 'w'), 115155.10043097363),
#  (('o', 'którym', 'mowa'), 101191.92286212163),
#  (('mowa', 'w', 'ust'), 88333.59156088077),
#  (('którym', 'mowa', 'w'), 76306.46249887679),
#  (('mowa', 'w', 'art'), 65669.03922712686),
#  (('o', 'której', 'mowa'), 63986.16318100954),
#  (('minister', 'właściwy', 'do'), 56271.02362326183),
#  (('właściwy', 'do', 'spraw'), 51190.362626632836),
#  (('której', 'mowa', 'w'), 44600.82812650548)]

# %% [markdown]
# # Task 11
# Create a table comparing the methods (separate table for bigrams and trigrams).

# %%
import pandas as pd
  
data = {'Bigrams top occurence': [a for a, b in valid_bigrams.most_common(10)],
        'Bigrams PMI': [a for a, b in bigrams_pmi_list[:10]],
        'Bigrams PMI (>=5)': [a for a, b in bigrams_pmi_list_5[:10]],
        'Bigrams LLR': [a for a, b in bigrams_llr_list[:10]],
        'Bigrams LLR (>=5)': [a for a, b in bigrams_llr_5_list[:10]]
        
       }
  
df = pd.DataFrame(data)

# %%
df
# Out:
#     Bigrams top occurence                      Bigrams PMI  \
# 0                (w, art)               (aegroti, suprema)
# 1               (mowa, w)   (aerodynamicznej, szorstkości)
# 2                (w, ust)                (aethina, tumida)
# 3         (których, mowa)        (agenci, ubezpieczeniowi)
# 4            (o, których)        (agregatach, pralniczych)
# 5  (otrzymuje, brzmienie)         (agricoltura, biologica)
# 6               (z, dnia)        (agriculture, biologique)
# 7          (którym, mowa)  (agrotechniki, nienaruszającej)
# 8             (o, którym)            (akapicie, preambuły)
# 9             (do, spraw)           (aktowi, normatywnemu)
#
#           Bigrams PMI (>=5)             Bigrams LLR       Bigrams LLR (>=5)
# 0      (grzegorz, schetyna)               (mowa, w)               (mowa, w)
# 1   (klęskami, żywiołowymi)  (otrzymuje, brzmienie)  (otrzymuje, brzmienie)
# 2        (młynki, młotkowe)         (których, mowa)         (których, mowa)
# 3           (młyny, kulowe)            (o, których)            (o, których)
# 4    (obcowania, płciowego)                (w, art)                (w, art)
# 5  (otworami, wiertniczymi)          (którym, mowa)          (którym, mowa)
# 6      (ręcznego, miotacza)           (dodaje, się)           (dodaje, się)
# 7      (stajnią, wyścigową)                (w, ust)                (w, ust)
# 8     (zaszkodzić, wynikom)             (do, spraw)             (do, spraw)
# 9             (środa, wlkp)             (o, którym)             (o, którym)

# %%
data = {'Trigrams top occurence': [a for a, b in valid_trigrams.most_common(10)],
        'Trigrams PMI (>=5)': [a for a, b in pmi_trigrams_list[:10]],
        'Trigrams LLR (>=5)': [a for a, b in llr_trigrams_list[:10]]
        
       }
  
df = pd.DataFrame(data)

# %%
df
# Out:
#      Trigrams top occurence                     Trigrams PMI (>=5)  \
# 0        (których, mowa, w)            (profilem, zaufanym, epuap)
# 1            (mowa, w, ust)     (finałowego, turnieju, mistrzostw)
# 2        (o, których, mowa)  (przedwczesnego, wyrębu, drzewostanu)
# 3            (mowa, w, art)    (potwierdzonym, profilem, zaufanym)
# 4         (którym, mowa, w)                  (piłce, nożnej, uefa)
# 5         (o, którym, mowa)          (cienką, sierścią, zwierzęcą)
# 6         (której, mowa, w)   (szybkiemu, postępowi, technicznemu)
# 7         (o, której, mowa)         (turnieju, mistrzostw, europy)
# 8     (właściwy, do, spraw)                (grożącą, jemu, samemu)
# 9  (minister, właściwy, do)         (wypalonym, paliwem, jądrowym)
#
#          Trigrams LLR (>=5)
# 0        (o, których, mowa)
# 1        (których, mowa, w)
# 2         (o, którym, mowa)
# 3            (mowa, w, ust)
# 4         (którym, mowa, w)
# 5            (mowa, w, art)
# 6         (o, której, mowa)
# 7  (minister, właściwy, do)
# 8     (właściwy, do, spraw)
# 9         (której, mowa, w)

# %% [markdown]
# # Task 12
# Answer the following questions:
#
# ## Why do we have to filter the bigrams, rather than the token sequence?
# Ex. phrase: "W art. 12 ust 3 zmieniono..."
# If I first clear tokens, there would be only "w, ust, zmieniono",
# so created bigrams would be 'w ust' and 'ust zmieniono', which is not valid, as they did not exist in original phrase.
#
# ## Which measure (PMI, PMI with filtering, LLR) works better for the bigrams and which for the trigrams?
#
# Bigrams:
#  - PMI gives multiword expresions which are rare and they often change their meaning together. When filtering was added, the most rare words co-existances were filtered but there still were valid multiword expressions (e.g. Grzegorz Schetyna means different 'object' than if it would be only 'Grzegorz' or only 'Schetyna'), not just words that tend to stand often near each other.
#  - LLR tends to give bigrams that are just most common word orderings in corpus. Smoetimes those are valid multiword expressions, sometimes just words that tend to stand near. Filtering did nothing to top scores - there were the same. So LLR tends to be more stable, but it doesn't really give much information than just sorting by most common bigrams.
#
# For bigrams I would choose PMI as it shows true nature of bigrams (if they are multiword exp or not).
#
# Trigrams:
# This is similar in this case, LLR gives almost the same scores as for most common trigrams. Those are mostly different variants of 'o których mowa'. PMI gives more interesting results.
#
# For bigrams it seems to be easier to find multiword expressions - this is just two words. When third word comes (in Polish language) there could be many variants of the same expression as it happened here:
#
# o, których, mowa
#
# o, której, mowa ...
#
# Also, there are found bi- and tri- grams that are part of 4-grams. When it takes two positions (minister właściwy do), (właściwy do spraw), it would take only one 4-gram and then it would be true multiword expression.
# ## What types of expressions are discovered by the methods.
# LLR: usually found just bigrams and trigrams that were words going in some order but there was no new meaning in them.
# PMI: often found multiword expressions that changed their meaning when together, like names (Grzegorz Schetyna), colocations (agregatach pralniczych, potwierdzonym profilem zaufanym, ręcznego miotacza), parts of latin sentences (salus aegroti suprema lex).
#
# ## Can you devise a different type of filtering that would yield better results?
#
# Maybe stemming would help, especially in case of trigrams, as there are many similar in top 10 after LLR, which would not happen it they were stemmed (o której mowa, o których mowa, o którym mowa).
